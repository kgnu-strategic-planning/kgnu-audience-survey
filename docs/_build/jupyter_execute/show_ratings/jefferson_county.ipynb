# %% [markdown]
# # Jefferson County

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import MaxNLocator
from IPython.display import display, Markdown
from functions import *

# %%
df = pd.read_excel('KGNU-Member-Data-07.15.22.xlsx', sheet_name='English')

# %%
show_ratings_cols = df.columns.tolist()[111:191]
#show_ratings_cols

# %%
filter_col = 'County'
filter_col_val = 'Jefferson'
filter_col_val_display = 'Filter: Jefferson County'

# %% [markdown]
# ## Show Rankings

# %%
create_ranked_table_of_shows(df, False, filter_col, filter_col_val, filter_col_val_display)
# Out:
# Overall      Show               #Ratings/    Median/Mean  Score   Music   News
# Ranking                        #Respondents                       Show    Show
#                                                                  Ranking Ranking
# --------------------------------------------------------------------------------
#  1    MSA                           17/23       10/9.5     162      1
#  2    ASA                           17/23       10/8.8     149      2
#  3    E Town                        16/23       10/8.4     135      3
#  4    African Roots                 16/22        7/7.2     115      4
#  5    Blues Legacy                  15/23        8/7.6     114      5
#  6    Democracy Now                 12/21       10/9.2     110              1
#  6    Jim Hightower                 12/20       10/9.2     110              1
#  7    BBC News Hour                 13/21       10/8.2     107              2
#  8    Reggae Bloodlines             14/22        8/7.4     104      6
#  8    BBC The Newsroom              12/21       10/8.7     104              3
#  9    Metro                         12/20        8/8.4     101              4
# 10    Alan Watts                    12/21       10/8.2      99              5
# 11    OGGG                          14/22        7/6.9      97      7
# 12    Roots and Branches            11/22        9/8.7      96      8
# 13    Morning Magazine              11/20        8/8.6      95              6
# 14    Counterspin                   10/21       10/9.3      93              7
# 14    HTH                           11/21       10/8.5      93      9
# 15    How on Earth                  10/21        9/9.2      92              8
# 16    Alternative Radio             11/21       10/8.2      90              9
# 16    Connections                   10/21       10/9.0      90              9
# 17    Jazz Lives                    12/23        7/7.1      85     10
# 18    Grateful Dead                 12/22        7/7.0      84     11
# 19    A Public Affair               10/21        9/8.2      82             10
# 19    Between the Lines              9/21       10/9.1      82             10
# 20    Naturally                      9/21       10/9.0      81             11
# 20    Its The Economy                9/21        9/9.0      81             11
# 21    Ralph Nader                   10/20        8/7.9      79             12
# 22    Terrasonic                    10/22        8/7.5      75     12
# 23    Economic Update                8/21       10/9.2      74             13
# 24    Labor Exchange                 9/20        8/8.0      72             14
# 25    Hemispheres                    8/21        9/8.6      69             15
# 26    Gospel Chime                   9/22        9/7.6      68     13
# 26    New Dimensions                 8/20       10/8.5      68             16
# 27    Dusty Grooves                  7/23       10/9.6      67     14
# 28    Bioneers                       7/21       10/9.3      65             17
# 29    Metro Arts                     8/20        9/8.0      64             18
# 30    La Lucha Sigue                 8/19        8/7.6      61             19
# 30    Local PM Headlines Spanish    10/20        6/6.1      61             19
# 31    Indian Voices                  8/21        8/7.5      60             20
# 32    Living Dialogues               7/20        9/8.4      59             21
# 33    Seolta Gael                    8/21        8/7.2      58     15
# 34    Kaberet                        7/23        9/8.1      57     16
# 35    Corriente                      7/23        8/7.6      53     17
# 35    Reggae Transfusions            8/22        6/6.6      53     17
# 35    Laura Flanders                 8/19        7/6.6      53             22
# 36    Making Contact                 6/20        9/8.7      52             23
# 36    A Classic Monday               9/22        7/5.8      52     18
# 37    The World                      7/20        8/7.1      50             24
# 37    Roots of Jazz                  7/22        7/7.1      50     19
# 38    Black Talk                     7/21       10/7.0      49             25
# 38    Project Censored               5/20       10/9.8      49             25
# 39    Peace Talks                    5/20       10/9.2      46             26
# 40    Eclipse                        6/23        8/7.3      44     20
# 41    The Heavy Set                  5/22       10/8.6      43     21
# 42    Shortwave Report               5/20        8/8.4      42             27
# 42    Under the Floorboards          5/20        8/8.4      42     22
# 43    HWY 322                        5/23        9/8.2      41     23
# 44    Dub Palace                     6/23        7/6.7      40     24
# 45    TUC Radio                      4/20       10/9.5      38             28
# 46    Rising Up with Sonali          4/20        9/8.8      35             29
# 47    Swing Shift                    5/22        6/6.8      34     25
# 47    Outsources                     4/20        9/8.5      34             30
# 48    Linea Abierta                  3/20       10/10.0      30             31
# 48    Tributaries                    4/20        8/7.5      30             31
# 49    Soundlab                       3/22       10/9.7      29     26
# 49    Musica Mundi                   4/21        7/7.2      29     26
# 50    Electronic Air                 4/23        8/7.0      28     27
# 50    Pasa La Voz                    4/20        8/7.0      28             32
# 50    Sleepless Nights               3/22       10/9.3      28     27
# 51    StoryTellers of Color          4/20        8/6.8      27             33
# 52    WINGS                          3/20        8/8.7      26             34
# 52    Weed between                   3/20        9/8.7      26             34
# 53    Restless Mornings              3/22        8/8.3      25     28
# 54    The Opera Box                  6/22        2/4.0      24     29
# 55    Smash It Back                  3/22        9/7.3      22     30
# 56    Ragtime America                3/22        7/6.7      20     31
# 57    Col Chinese Radio Network      3/21        1/4.0      12             35
# 58    Sprouts                        2/20        5/5.5      11             36
# 59    TRENDS                         1/20        6/6.0       6             37
# 60    Present Edge                   1/22        3/3.0       3     32

# %% [markdown]
# ## Music Shows

# %% [markdown]
# ### A Classic Monday

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'A_Classic_Monday_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 22
# Respondents Familiar with Show: 9
# Percent Familiar with Show: 40.9%
# Median: 7
# Mean: 5.78
# Overall Ranking: 36
# Music-Show Ranking: 18

# %% [markdown]
# ### African Roots

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'African_Roots_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 22
# Respondents Familiar with Show: 16
# Percent Familiar with Show: 72.7%
# Median: 7
# Mean: 7.19
# Overall Ranking: 4
# Music-Show Ranking: 4

# %% [markdown]
# ### Afternoon Sound Alternative

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'ASA_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 23
# Respondents Familiar with Show: 17
# Percent Familiar with Show: 73.9%
# Median: 10
# Mean: 8.76
# Overall Ranking: 2
# Music-Show Ranking: 2

# %% [markdown]
# ### Blues Legacy

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Blues_Legacy_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 23
# Respondents Familiar with Show: 15
# Percent Familiar with Show: 65.2%
# Median: 8
# Mean: 7.60
# Overall Ranking: 5
# Music-Show Ranking: 5

# %% [markdown]
# ### Corriente

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Corriente_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 23
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 30.4%
# Median: 8
# Mean: 7.57
# Overall Ranking: 35
# Music-Show Ranking: 17

# %% [markdown]
# ### Dub Palace

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Dub_Palace_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 23
# Respondents Familiar with Show: 6
# Percent Familiar with Show: 26.1%
# Median: 7
# Mean: 6.67
# Overall Ranking: 44
# Music-Show Ranking: 24

# %% [markdown]
# ### Dusty Grooves

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Dusty_Grooves_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 23
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 30.4%
# Median: 10
# Mean: 9.57
# Overall Ranking: 27
# Music-Show Ranking: 14

# %% [markdown]
# ### Eclipse

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Eclipse_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 23
# Respondents Familiar with Show: 6
# Percent Familiar with Show: 26.1%
# Median: 8
# Mean: 7.33
# Overall Ranking: 40
# Music-Show Ranking: 20

# %% [markdown]
# ### Electronic Air

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Electronic_Air_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 23
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 17.4%
# Median: 8
# Mean: 7.00
# Overall Ranking: 50
# Music-Show Ranking: 27

# %% [markdown]
# ### eTown

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'E_Town_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 23
# Respondents Familiar with Show: 16
# Percent Familiar with Show: 69.6%
# Median: 10
# Mean: 8.44
# Overall Ranking: 3
# Music-Show Ranking: 3

# %% [markdown]
# ### Gospel Chime

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Gospel_Chime_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 22
# Respondents Familiar with Show: 9
# Percent Familiar with Show: 40.9%
# Median: 9
# Mean: 7.56
# Overall Ranking: 26
# Music-Show Ranking: 13

# %% [markdown]
# ### Grateful Dead

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Grateful_Dead_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 22
# Respondents Familiar with Show: 12
# Percent Familiar with Show: 54.5%
# Median: 7
# Mean: 7.00
# Overall Ranking: 18
# Music-Show Ranking: 11

# %% [markdown]
# ### Hwy 322

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'HWY_322_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 23
# Respondents Familiar with Show: 5
# Percent Familiar with Show: 21.7%
# Median: 9
# Mean: 8.20
# Overall Ranking: 43
# Music-Show Ranking: 23

# %% [markdown]
# ### Honky Tonk Heroes

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'HTH_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 21
# Respondents Familiar with Show: 11
# Percent Familiar with Show: 52.4%
# Median: 10
# Mean: 8.45
# Overall Ranking: 14
# Music-Show Ranking: 9

# %% [markdown]
# ### Jazz Lives

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Jazz_Lives_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 23
# Respondents Familiar with Show: 12
# Percent Familiar with Show: 52.2%
# Median: 7
# Mean: 7.08
# Overall Ranking: 17
# Music-Show Ranking: 10

# %% [markdown]
# ### Kaberet

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Kaberet_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 23
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 30.4%
# Median: 9
# Mean: 8.14
# Overall Ranking: 34
# Music-Show Ranking: 16

# %% [markdown]
# ### Morning Sound Alternative

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'MSA_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 23
# Respondents Familiar with Show: 17
# Percent Familiar with Show: 73.9%
# Median: 10
# Mean: 9.53
# Overall Ranking: 1
# Music-Show Ranking: 1

# %% [markdown]
# ### Musica Mundi

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Musica_Mundi_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 21
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 19.0%
# Median: 7
# Mean: 7.25
# Overall Ranking: 49
# Music-Show Ranking: 26

# %% [markdown]
# ### Old Grass Gnu Grass

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'OGGG_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 22
# Respondents Familiar with Show: 14
# Percent Familiar with Show: 63.6%
# Median: 7
# Mean: 6.93
# Overall Ranking: 11
# Music-Show Ranking: 7

# %% [markdown]
# ### The Present Edge

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Present_Edge_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 22
# Respondents Familiar with Show: 1
# Percent Familiar with Show: 4.5%
# Median: 3
# Mean: 3.00
# Overall Ranking: 60
# Music-Show Ranking: 32

# %% [markdown]
# ### Ragtime America

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Ragtime_America_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 22
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 13.6%
# Median: 7
# Mean: 6.67
# Overall Ranking: 56
# Music-Show Ranking: 31

# %% [markdown]
# ### Reggae Bloodlines

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Reggae_Bloodlines_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 22
# Respondents Familiar with Show: 14
# Percent Familiar with Show: 63.6%
# Median: 8
# Mean: 7.43
# Overall Ranking: 8
# Music-Show Ranking: 6

# %% [markdown]
# ### Reggae Transfusions

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Reggae_Transfusions_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 22
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 36.4%
# Median: 6
# Mean: 6.62
# Overall Ranking: 35
# Music-Show Ranking: 17

# %% [markdown]
# ### Restless Mornings

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Restless_Mornings_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 22
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 13.6%
# Median: 8
# Mean: 8.33
# Overall Ranking: 53
# Music-Show Ranking: 28

# %% [markdown]
# ### Roots and Branches

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Roots_and_Branches_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 22
# Respondents Familiar with Show: 11
# Percent Familiar with Show: 50.0%
# Median: 9
# Mean: 8.73
# Overall Ranking: 12
# Music-Show Ranking: 8

# %% [markdown]
# ### Roots of Jazz

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Roots_of_Jazz_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 22
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 31.8%
# Median: 7
# Mean: 7.14
# Overall Ranking: 37
# Music-Show Ranking: 19

# %% [markdown]
# ### Seolta Gael

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Seolta_Gael_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 21
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 38.1%
# Median: 8
# Mean: 7.25
# Overall Ranking: 33
# Music-Show Ranking: 15

# %% [markdown]
# ### Sleepless Nights

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Sleepless_Nights_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 22
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 13.6%
# Median: 10
# Mean: 9.33
# Overall Ranking: 50
# Music-Show Ranking: 27

# %% [markdown]
# ### Smash It Back

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Smash_It_Back_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 22
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 13.6%
# Median: 9
# Mean: 7.33
# Overall Ranking: 55
# Music-Show Ranking: 30

# %% [markdown]
# ### SoundLab

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Soundlab_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 22
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 13.6%
# Median: 10
# Mean: 9.67
# Overall Ranking: 49
# Music-Show Ranking: 26

# %% [markdown]
# ### Swing Shift

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Swing_Shift_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 22
# Respondents Familiar with Show: 5
# Percent Familiar with Show: 22.7%
# Median: 6
# Mean: 6.80
# Overall Ranking: 47
# Music-Show Ranking: 25

# %% [markdown]
# ### Terrasonic

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Terrasonic_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 22
# Respondents Familiar with Show: 10
# Percent Familiar with Show: 45.5%
# Median: 8
# Mean: 7.50
# Overall Ranking: 22
# Music-Show Ranking: 12

# %% [markdown]
# ### The Heavy Set

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_Heavy_Set_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 22
# Respondents Familiar with Show: 5
# Percent Familiar with Show: 22.7%
# Median: 10
# Mean: 8.60
# Overall Ranking: 41
# Music-Show Ranking: 21

# %% [markdown]
# ### The Opera Box

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_Opera_Box_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 22
# Respondents Familiar with Show: 6
# Percent Familiar with Show: 27.3%
# Median: 2
# Mean: 4.00
# Overall Ranking: 54
# Music-Show Ranking: 29

# %% [markdown]
# ### Under the Floorboards

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Under_the_Floorboards_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 5
# Percent Familiar with Show: 25.0%
# Median: 8
# Mean: 8.40
# Overall Ranking: 42
# Music-Show Ranking: 22

# %% [markdown]
# ## News Shows

# %% [markdown]
# ### A Public Affairs

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'A_Public_Affair_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 21
# Respondents Familiar with Show: 10
# Percent Familiar with Show: 47.6%
# Median: 9
# Mean: 8.20
# Overall Ranking: 19
# News-Show Ranking: 10

# %% [markdown]
# ### Alan Watts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Alan_Watts_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 21
# Respondents Familiar with Show: 12
# Percent Familiar with Show: 57.1%
# Median: 10
# Mean: 8.25
# Overall Ranking: 10
# News-Show Ranking: 5

# %% [markdown]
# ### Alternative Radio

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Alternative_Radio_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 21
# Respondents Familiar with Show: 11
# Percent Familiar with Show: 52.4%
# Median: 10
# Mean: 8.18
# Overall Ranking: 16
# News-Show Ranking: 9

# %% [markdown]
# ### BBC News Hour

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'BBC_News_Hour_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 21
# Respondents Familiar with Show: 13
# Percent Familiar with Show: 61.9%
# Median: 10
# Mean: 8.23
# Overall Ranking: 7
# News-Show Ranking: 2

# %% [markdown]
# ### BBC The Newsroom

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'BBC_The_Newsroom_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 21
# Respondents Familiar with Show: 12
# Percent Familiar with Show: 57.1%
# Median: 10
# Mean: 8.67
# Overall Ranking: 8
# News-Show Ranking: 3

# %% [markdown]
# ### Between the Lines

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Between_the_Lines_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 21
# Respondents Familiar with Show: 9
# Percent Familiar with Show: 42.9%
# Median: 10
# Mean: 9.11
# Overall Ranking: 19
# News-Show Ranking: 10

# %% [markdown]
# ### Bioneers

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Bioneers_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 21
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 33.3%
# Median: 10
# Mean: 9.29
# Overall Ranking: 28
# News-Show Ranking: 17

# %% [markdown]
# ### Black Talk

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Black_Talk_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 21
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 33.3%
# Median: 10
# Mean: 7.00
# Overall Ranking: 38
# News-Show Ranking: 25

# %% [markdown]
# ### Colorado Chinese Radio Network

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Col_Chinese_Radio_Network_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 21
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 14.3%
# Median: 1
# Mean: 4.00
# Overall Ranking: 57
# News-Show Ranking: 35

# %% [markdown]
# ### Connections

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Connections_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 21
# Respondents Familiar with Show: 10
# Percent Familiar with Show: 47.6%
# Median: 10
# Mean: 9.00
# Overall Ranking: 16
# News-Show Ranking: 9

# %% [markdown]
# ### Counterspin

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Counterspin_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 21
# Respondents Familiar with Show: 10
# Percent Familiar with Show: 47.6%
# Median: 10
# Mean: 9.30
# Overall Ranking: 14
# News-Show Ranking: 7

# %% [markdown]
# ### Democracy Now

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Democracy_Now_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 21
# Respondents Familiar with Show: 12
# Percent Familiar with Show: 57.1%
# Median: 10
# Mean: 9.17
# Overall Ranking: 6
# News-Show Ranking: 1

# %% [markdown]
# ### Economic Update

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Economic_Update_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 21
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 38.1%
# Median: 10
# Mean: 9.25
# Overall Ranking: 23
# News-Show Ranking: 13

# %% [markdown]
# ### Hemispheres

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Hemispheres_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 21
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 38.1%
# Median: 9
# Mean: 8.62
# Overall Ranking: 25
# News-Show Ranking: 15

# %% [markdown]
# ### How on Earth

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'How_on_Earth_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 21
# Respondents Familiar with Show: 10
# Percent Familiar with Show: 47.6%
# Median: 9
# Mean: 9.20
# Overall Ranking: 15
# News-Show Ranking: 8

# %% [markdown]
# ### Indian Voices

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Indian_Voices_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 21
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 38.1%
# Median: 8
# Mean: 7.50
# Overall Ranking: 31
# News-Show Ranking: 20

# %% [markdown]
# ### It's the Economy

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Its_The_Economy_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 21
# Respondents Familiar with Show: 9
# Percent Familiar with Show: 42.9%
# Median: 9
# Mean: 9.00
# Overall Ranking: 20
# News-Show Ranking: 11

# %% [markdown]
# ### Jim Hightower

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Jim_Hightower_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 12
# Percent Familiar with Show: 60.0%
# Median: 10
# Mean: 9.17
# Overall Ranking: 6
# News-Show Ranking: 1

# %% [markdown]
# ### La Lucha Sigue

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'La_Lucha_Sigue_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 19
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 42.1%
# Median: 8
# Mean: 7.62
# Overall Ranking: 30
# News-Show Ranking: 19

# %% [markdown]
# ### Labor Exchange

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Labor_Exchange_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 9
# Percent Familiar with Show: 45.0%
# Median: 8
# Mean: 8.00
# Overall Ranking: 24
# News-Show Ranking: 14

# %% [markdown]
# ### Linea Abierta

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Linea_Abierta_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 15.0%
# Median: 10
# Mean: 10.00
# Overall Ranking: 48
# News-Show Ranking: 31

# %% [markdown]
# ### Living Dialogues

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Living_Dialogues_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 35.0%
# Median: 9
# Mean: 8.43
# Overall Ranking: 32
# News-Show Ranking: 21

# %% [markdown]
# ### Local PM Headlines Spanish

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Local_PM_Headlines_Spanish_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 10
# Percent Familiar with Show: 50.0%
# Median: 6
# Mean: 6.10
# Overall Ranking: 30
# News-Show Ranking: 19

# %% [markdown]
# ### Making Contact

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Making_Contact_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 6
# Percent Familiar with Show: 30.0%
# Median: 9
# Mean: 8.67
# Overall Ranking: 36
# News-Show Ranking: 23

# %% [markdown]
# ### Metro

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Metro_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 12
# Percent Familiar with Show: 60.0%
# Median: 8
# Mean: 8.42
# Overall Ranking: 9
# News-Show Ranking: 4

# %% [markdown]
# ### Metro Arts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Metro_Arts_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 40.0%
# Median: 9
# Mean: 8.00
# Overall Ranking: 29
# News-Show Ranking: 18

# %% [markdown]
# ### Morning Magazine

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Morning_Magazine_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 11
# Percent Familiar with Show: 55.0%
# Median: 8
# Mean: 8.64
# Overall Ranking: 13
# News-Show Ranking: 6

# %% [markdown]
# ### Naturally

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Naturally_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 21
# Respondents Familiar with Show: 9
# Percent Familiar with Show: 42.9%
# Median: 10
# Mean: 9.00
# Overall Ranking: 20
# News-Show Ranking: 11

# %% [markdown]
# ### New Dimensions

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'New_Dimensions_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 40.0%
# Median: 10
# Mean: 8.50
# Overall Ranking: 26
# News-Show Ranking: 16

# %% [markdown]
# ### Outsources

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Outsources_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 20.0%
# Median: 9
# Mean: 8.50
# Overall Ranking: 47
# News-Show Ranking: 30

# %% [markdown]
# ### Pasa La Voz

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Pasa_La_Voz_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 20.0%
# Median: 8
# Mean: 7.00
# Overall Ranking: 50
# News-Show Ranking: 32

# %% [markdown]
# ### Peace Talks

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Peace_Talks_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 5
# Percent Familiar with Show: 25.0%
# Median: 10
# Mean: 9.20
# Overall Ranking: 39
# News-Show Ranking: 26

# %% [markdown]
# ### Project Censored

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Project_Censored_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 5
# Percent Familiar with Show: 25.0%
# Median: 10
# Mean: 9.80
# Overall Ranking: 38
# News-Show Ranking: 25

# %% [markdown]
# ### Rising Up with Sonali

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Rising_Up_with_Sonali_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 20.0%
# Median: 9
# Mean: 8.75
# Overall Ranking: 46
# News-Show Ranking: 29

# %% [markdown]
# ### Sprouts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Sprouts_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 10.0%
# Median: 5
# Mean: 5.50
# Overall Ranking: 58
# News-Show Ranking: 36

# %% [markdown]
# ### StoryTellers of Color

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'StoryTellers_of_Color_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 20.0%
# Median: 8
# Mean: 6.75
# Overall Ranking: 51
# News-Show Ranking: 33

# %% [markdown]
# ### Laura Flanders

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Laura_Flanders_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 19
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 42.1%
# Median: 7
# Mean: 6.62
# Overall Ranking: 35
# News-Show Ranking: 22

# %% [markdown]
# ### Ralph Nader

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Ralph_Nader_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 10
# Percent Familiar with Show: 50.0%
# Median: 8
# Mean: 7.90
# Overall Ranking: 21
# News-Show Ranking: 12

# %% [markdown]
# ### Shortwave Report

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Shortwave_Report_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 5
# Percent Familiar with Show: 25.0%
# Median: 8
# Mean: 8.40
# Overall Ranking: 42
# News-Show Ranking: 27

# %% [markdown]
# ### The World

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_World_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 35.0%
# Median: 8
# Mean: 7.14
# Overall Ranking: 37
# News-Show Ranking: 24

# %% [markdown]
# ### TRENDS

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'TRENDS_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 1
# Percent Familiar with Show: 5.0%
# Median: 6
# Mean: 6.00
# Overall Ranking: 59
# News-Show Ranking: 37

# %% [markdown]
# ### Tributaries

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Tributaries_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 20.0%
# Median: 8
# Mean: 7.50
# Overall Ranking: 48
# News-Show Ranking: 31

# %% [markdown]
# ### TUC Radio

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'TUC_Radio_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 20.0%
# Median: 10
# Mean: 9.50
# Overall Ranking: 45
# News-Show Ranking: 28

# %% [markdown]
# ### WINGS

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'WINGS_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 15.0%
# Median: 8
# Mean: 8.67
# Overall Ranking: 52
# News-Show Ranking: 34

# %% [markdown]
# ### Weed Between

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Weed_between_Ratings')
# Out:
# Filter: Jefferson County
# Total Respondents: 20
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 15.0%
# Median: 9
# Mean: 8.67
# Overall Ranking: 52
# News-Show Ranking: 34
