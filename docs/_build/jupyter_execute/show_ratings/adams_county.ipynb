# %% [markdown]
# # Adams County

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import MaxNLocator
from IPython.display import display, Markdown
from functions import *

# %%
df = pd.read_excel('KGNU-Member-Data-07.15.22.xlsx', sheet_name='English')

# %%
show_ratings_cols = df.columns.tolist()[111:191]
#show_ratings_cols

# %%
filter_col = 'County'
filter_col_val = 'Adams'
filter_col_val_display = 'Filter: Adams County'

# %% [markdown]
# ## Show Rankings

# %%
create_ranked_table_of_shows(df, False, filter_col, filter_col_val, filter_col_val_display)
# Out:
# Overall      Show               #Ratings/    Median/Mean  Score   Music   News
# Ranking                        #Respondents                       Show    Show
#                                                                  Ranking Ranking
# --------------------------------------------------------------------------------
#  1    OGGG                          13/14       10/8.6     112      1
#  2    HTH                           13/14       10/8.2     106      2
#  3    Roots and Branches            11/13       10/8.5      93      3
#  4    Blues Legacy                  12/14        8/7.6      91      4
#  5    E Town                        12/14        7/7.4      89      5
#  6    Democracy Now                 12/14        9/7.2      87              1
#  6    Alan Watts                    10/14        9/8.7      87              1
#  6    BBC News Hour                 12/14        9/7.2      87              1
#  6    Jim Hightower                  9/14       10/9.7      87              1
#  7    Ralph Nader                   12/14        8/6.9      83              2
#  7    MSA                           10/14        8/8.3      83      6
#  8    Alternative Radio              9/14       10/9.1      82              3
#  9    ASA                           13/14        6/6.2      80      7
# 10    Labor Exchange                 9/14        8/8.6      77              4
# 11    HWY 322                        9/14        9/8.4      76      8
# 12    Dusty Grooves                 10/14        7/7.5      75      9
# 13    Its The Economy                9/14        8/8.2      74              5
# 14    Grateful Dead                 10/14        8/7.3      73     10
# 14    Indian Voices                 10/14        7/7.3      73              6
# 15    Counterspin                    8/14        9/9.0      72              7
# 15    Economic Update                8/14       10/9.0      72              7
# 16    BBC The Newsroom              10/14        9/7.1      71              8
# 17    How on Earth                   8/14        9/8.8      70              9
# 18    Project Censored               7/14       10/9.9      69             10
# 18    Shortwave Report               8/14        9/8.6      69             10
# 19    A Public Affair                9/14        9/7.4      67             11
# 20    Gospel Chime                  12/14        6/5.4      65     11
# 20    Hemispheres                    8/14        8/8.1      65             12
# 21    Reggae Bloodlines              8/14        7/8.0      64     12
# 22    Between the Lines              8/14        9/7.9      63             13
# 23    Morning Magazine               7/14        8/8.9      62             14
# 23    Reggae Transfusions            8/14        7/7.8      62     13
# 23    Tributaries                    7/14        9/8.9      62             14
# 23    Terrasonic                     7/14        9/8.9      62     13
# 24    Metro                         10/14        6/6.1      61             15
# 24    African Roots                 10/14        6/6.1      61     14
# 25    New Dimensions                 8/14        7/7.5      60             16
# 26    Bioneers                       7/14        9/8.4      59             17
# 27    Ragtime America                9/14        7/6.4      58     15
# 28    Connections                    7/14        8/8.1      57             18
# 28    TUC Radio                      6/14       10/9.5      57             18
# 29    Laura Flanders                 7/14        8/8.0      56             19
# 30    Seolta Gael                    7/14        8/7.9      55     16
# 30    Making Contact                 7/14        8/7.9      55             20
# 31    Metro Arts                     9/14        7/5.9      53             21
# 32    Rising Up with Sonali          6/14        9/8.7      52             22
# 33    Local PM Headlines Spanish     6/13        9/8.3      50             23
# 33    A Classic Monday               9/14        5/5.6      50     17
# 34    Living Dialogues               6/14        8/8.2      49             24
# 35    Peace Talks                    5/14       10/9.6      48             25
# 36    Smash It Back                  5/14       10/9.2      46     18
# 36    Dub Palace                     7/14        6/6.6      46     18
# 36    Jazz Lives                     8/14        6/5.8      46     18
# 36    Electronic Air                 7/14        7/6.6      46     18
# 36    Musica Mundi                   6/14        7/7.7      46     18
# 36    La Lucha Sigue                 6/14        7/7.7      46             26
# 37    WINGS                          5/14        9/9.0      45             27
# 38    Outsources                     6/14        8/7.2      43             28
# 39    Kaberet                        6/14        6/7.0      42     19
# 39    Naturally                      5/13        9/8.4      42             29
# 40    Sleepless Nights               5/13        8/8.2      41     20
# 40    Roots of Jazz                  6/14        7/6.8      41     20
# 40    Restless Mornings              5/14        8/8.2      41     20
# 40    Under the Floorboards          6/14        8/6.8      41     20
# 41    Corriente                      7/14        5/5.6      39     21
# 41    Black Talk                     5/14        9/7.8      39             30
# 42    Present Edge                   6/14        6/6.3      38     22
# 42    Sprouts                        5/14        7/7.6      38             31
# 43    Weed between                   4/14        9/9.2      37             32
# 43    Swing Shift                    5/14        7/7.4      37     23
# 44    Eclipse                        5/14        6/7.0      35     24
# 45    The World                      6/14        6/5.7      34             33
# 46    Pasa La Voz                    5/14        7/6.6      33             34
# 47    The Opera Box                  7/13        5/4.3      30     25
# 48    TRENDS                         4/14        9/7.2      29             35
# 48    The Heavy Set                  4/14        7/7.2      29     26
# 49    Soundlab                       4/13        5/5.2      21     27
# 49    Linea Abierta                  3/14        6/7.0      21             36
# 50    StoryTellers of Color          3/14        6/6.0      18             37
# 51    Col Chinese Radio Network      4/14        4/3.5      14             38

# %% [markdown]
# ## Music Shows

# %% [markdown]
# ### A Classic Monday

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'A_Classic_Monday_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 9
# Percent Familiar with Show: 64.3%
# Median: 5
# Mean: 5.56
# Overall Ranking: 33
# Music-Show Ranking: 17

# %% [markdown]
# ### African Roots

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'African_Roots_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 10
# Percent Familiar with Show: 71.4%
# Median: 6
# Mean: 6.10
# Overall Ranking: 24
# Music-Show Ranking: 14

# %% [markdown]
# ### Afternoon Sound Alternative

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'ASA_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 13
# Percent Familiar with Show: 92.9%
# Median: 6
# Mean: 6.15
# Overall Ranking: 9
# Music-Show Ranking: 7

# %% [markdown]
# ### Blues Legacy

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Blues_Legacy_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 12
# Percent Familiar with Show: 85.7%
# Median: 8
# Mean: 7.58
# Overall Ranking: 4
# Music-Show Ranking: 4

# %% [markdown]
# ### Corriente

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Corriente_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 50.0%
# Median: 5
# Mean: 5.57
# Overall Ranking: 41
# Music-Show Ranking: 21

# %% [markdown]
# ### Dub Palace

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Dub_Palace_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 50.0%
# Median: 6
# Mean: 6.57
# Overall Ranking: 36
# Music-Show Ranking: 18

# %% [markdown]
# ### Dusty Grooves

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Dusty_Grooves_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 10
# Percent Familiar with Show: 71.4%
# Median: 7
# Mean: 7.50
# Overall Ranking: 12
# Music-Show Ranking: 9

# %% [markdown]
# ### Eclipse

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Eclipse_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 5
# Percent Familiar with Show: 35.7%
# Median: 6
# Mean: 7.00
# Overall Ranking: 44
# Music-Show Ranking: 24

# %% [markdown]
# ### Electronic Air

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Electronic_Air_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 50.0%
# Median: 7
# Mean: 6.57
# Overall Ranking: 36
# Music-Show Ranking: 18

# %% [markdown]
# ### eTown

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'E_Town_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 12
# Percent Familiar with Show: 85.7%
# Median: 7
# Mean: 7.42
# Overall Ranking: 5
# Music-Show Ranking: 5

# %% [markdown]
# ### Gospel Chime

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Gospel_Chime_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 12
# Percent Familiar with Show: 85.7%
# Median: 6
# Mean: 5.42
# Overall Ranking: 20
# Music-Show Ranking: 11

# %% [markdown]
# ### Grateful Dead

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Grateful_Dead_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 10
# Percent Familiar with Show: 71.4%
# Median: 8
# Mean: 7.30
# Overall Ranking: 14
# Music-Show Ranking: 10

# %% [markdown]
# ### Hwy 322

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'HWY_322_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 9
# Percent Familiar with Show: 64.3%
# Median: 9
# Mean: 8.44
# Overall Ranking: 11
# Music-Show Ranking: 8

# %% [markdown]
# ### Honky Tonk Heroes

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'HTH_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 13
# Percent Familiar with Show: 92.9%
# Median: 10
# Mean: 8.15
# Overall Ranking: 2
# Music-Show Ranking: 2

# %% [markdown]
# ### Jazz Lives

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Jazz_Lives_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 57.1%
# Median: 6
# Mean: 5.75
# Overall Ranking: 36
# Music-Show Ranking: 18

# %% [markdown]
# ### Kaberet

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Kaberet_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 6
# Percent Familiar with Show: 42.9%
# Median: 6
# Mean: 7.00
# Overall Ranking: 39
# Music-Show Ranking: 19

# %% [markdown]
# ### Morning Sound Alternative

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'MSA_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 10
# Percent Familiar with Show: 71.4%
# Median: 8
# Mean: 8.30
# Overall Ranking: 7
# Music-Show Ranking: 6

# %% [markdown]
# ### Musica Mundi

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Musica_Mundi_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 6
# Percent Familiar with Show: 42.9%
# Median: 7
# Mean: 7.67
# Overall Ranking: 36
# Music-Show Ranking: 18

# %% [markdown]
# ### Old Grass Gnu Grass

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'OGGG_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 13
# Percent Familiar with Show: 92.9%
# Median: 10
# Mean: 8.62
# Overall Ranking: 1
# Music-Show Ranking: 1

# %% [markdown]
# ### The Present Edge

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Present_Edge_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 6
# Percent Familiar with Show: 42.9%
# Median: 6
# Mean: 6.33
# Overall Ranking: 42
# Music-Show Ranking: 22

# %% [markdown]
# ### Ragtime America

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Ragtime_America_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 9
# Percent Familiar with Show: 64.3%
# Median: 7
# Mean: 6.44
# Overall Ranking: 27
# Music-Show Ranking: 15

# %% [markdown]
# ### Reggae Bloodlines

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Reggae_Bloodlines_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 57.1%
# Median: 7
# Mean: 8.00
# Overall Ranking: 21
# Music-Show Ranking: 12

# %% [markdown]
# ### Reggae Transfusions

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Reggae_Transfusions_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 57.1%
# Median: 7
# Mean: 7.75
# Overall Ranking: 23
# Music-Show Ranking: 13

# %% [markdown]
# ### Restless Mornings

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Restless_Mornings_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 5
# Percent Familiar with Show: 35.7%
# Median: 8
# Mean: 8.20
# Overall Ranking: 40
# Music-Show Ranking: 20

# %% [markdown]
# ### Roots and Branches

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Roots_and_Branches_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 13
# Respondents Familiar with Show: 11
# Percent Familiar with Show: 84.6%
# Median: 10
# Mean: 8.45
# Overall Ranking: 3
# Music-Show Ranking: 3

# %% [markdown]
# ### Roots of Jazz

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Roots_of_Jazz_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 6
# Percent Familiar with Show: 42.9%
# Median: 7
# Mean: 6.83
# Overall Ranking: 40
# Music-Show Ranking: 20

# %% [markdown]
# ### Seolta Gael

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Seolta_Gael_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 50.0%
# Median: 8
# Mean: 7.86
# Overall Ranking: 30
# Music-Show Ranking: 16

# %% [markdown]
# ### Sleepless Nights

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Sleepless_Nights_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 13
# Respondents Familiar with Show: 5
# Percent Familiar with Show: 38.5%
# Median: 8
# Mean: 8.20
# Overall Ranking: 40
# Music-Show Ranking: 20

# %% [markdown]
# ### Smash It Back

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Smash_It_Back_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 5
# Percent Familiar with Show: 35.7%
# Median: 10
# Mean: 9.20
# Overall Ranking: 36
# Music-Show Ranking: 18

# %% [markdown]
# ### SoundLab

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Soundlab_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 13
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 30.8%
# Median: 5
# Mean: 5.25
# Overall Ranking: 49
# Music-Show Ranking: 27

# %% [markdown]
# ### Swing Shift

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Swing_Shift_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 5
# Percent Familiar with Show: 35.7%
# Median: 7
# Mean: 7.40
# Overall Ranking: 43
# Music-Show Ranking: 23

# %% [markdown]
# ### Terrasonic

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Terrasonic_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 50.0%
# Median: 9
# Mean: 8.86
# Overall Ranking: 23
# Music-Show Ranking: 13

# %% [markdown]
# ### The Heavy Set

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_Heavy_Set_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 28.6%
# Median: 7
# Mean: 7.25
# Overall Ranking: 48
# Music-Show Ranking: 26

# %% [markdown]
# ### The Opera Box

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_Opera_Box_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 13
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 53.8%
# Median: 5
# Mean: 4.29
# Overall Ranking: 47
# Music-Show Ranking: 25

# %% [markdown]
# ### Under the Floorboards

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Under_the_Floorboards_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 6
# Percent Familiar with Show: 42.9%
# Median: 8
# Mean: 6.83
# Overall Ranking: 40
# Music-Show Ranking: 20

# %% [markdown]
# ## News Shows

# %% [markdown]
# ### A Public Affairs

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'A_Public_Affair_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 9
# Percent Familiar with Show: 64.3%
# Median: 9
# Mean: 7.44
# Overall Ranking: 19
# News-Show Ranking: 11

# %% [markdown]
# ### Alan Watts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Alan_Watts_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 10
# Percent Familiar with Show: 71.4%
# Median: 9
# Mean: 8.70
# Overall Ranking: 6
# News-Show Ranking: 1

# %% [markdown]
# ### Alternative Radio

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Alternative_Radio_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 9
# Percent Familiar with Show: 64.3%
# Median: 10
# Mean: 9.11
# Overall Ranking: 8
# News-Show Ranking: 3

# %% [markdown]
# ### BBC News Hour

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'BBC_News_Hour_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 12
# Percent Familiar with Show: 85.7%
# Median: 9
# Mean: 7.25
# Overall Ranking: 6
# News-Show Ranking: 1

# %% [markdown]
# ### BBC The Newsroom

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'BBC_The_Newsroom_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 10
# Percent Familiar with Show: 71.4%
# Median: 9
# Mean: 7.10
# Overall Ranking: 16
# News-Show Ranking: 8

# %% [markdown]
# ### Between the Lines

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Between_the_Lines_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 57.1%
# Median: 9
# Mean: 7.88
# Overall Ranking: 22
# News-Show Ranking: 13

# %% [markdown]
# ### Bioneers

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Bioneers_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 50.0%
# Median: 9
# Mean: 8.43
# Overall Ranking: 26
# News-Show Ranking: 17

# %% [markdown]
# ### Black Talk

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Black_Talk_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 5
# Percent Familiar with Show: 35.7%
# Median: 9
# Mean: 7.80
# Overall Ranking: 41
# News-Show Ranking: 30

# %% [markdown]
# ### Colorado Chinese Radio Network

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Col_Chinese_Radio_Network_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 28.6%
# Median: 4
# Mean: 3.50
# Overall Ranking: 51
# News-Show Ranking: 38

# %% [markdown]
# ### Connections

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Connections_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 50.0%
# Median: 8
# Mean: 8.14
# Overall Ranking: 28
# News-Show Ranking: 18

# %% [markdown]
# ### Counterspin

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Counterspin_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 57.1%
# Median: 9
# Mean: 9.00
# Overall Ranking: 15
# News-Show Ranking: 7

# %% [markdown]
# ### Democracy Now

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Democracy_Now_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 12
# Percent Familiar with Show: 85.7%
# Median: 9
# Mean: 7.25
# Overall Ranking: 6
# News-Show Ranking: 1

# %% [markdown]
# ### Economic Update

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Economic_Update_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 57.1%
# Median: 10
# Mean: 9.00
# Overall Ranking: 15
# News-Show Ranking: 7

# %% [markdown]
# ### Hemispheres

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Hemispheres_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 57.1%
# Median: 8
# Mean: 8.12
# Overall Ranking: 20
# News-Show Ranking: 12

# %% [markdown]
# ### How on Earth

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'How_on_Earth_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 57.1%
# Median: 9
# Mean: 8.75
# Overall Ranking: 17
# News-Show Ranking: 9

# %% [markdown]
# ### Indian Voices

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Indian_Voices_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 10
# Percent Familiar with Show: 71.4%
# Median: 7
# Mean: 7.30
# Overall Ranking: 14
# News-Show Ranking: 6

# %% [markdown]
# ### It's the Economy

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Its_The_Economy_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 9
# Percent Familiar with Show: 64.3%
# Median: 8
# Mean: 8.22
# Overall Ranking: 13
# News-Show Ranking: 5

# %% [markdown]
# ### Jim Hightower

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Jim_Hightower_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 9
# Percent Familiar with Show: 64.3%
# Median: 10
# Mean: 9.67
# Overall Ranking: 6
# News-Show Ranking: 1

# %% [markdown]
# ### La Lucha Sigue

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'La_Lucha_Sigue_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 6
# Percent Familiar with Show: 42.9%
# Median: 7
# Mean: 7.67
# Overall Ranking: 36
# News-Show Ranking: 26

# %% [markdown]
# ### Labor Exchange

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Labor_Exchange_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 9
# Percent Familiar with Show: 64.3%
# Median: 8
# Mean: 8.56
# Overall Ranking: 10
# News-Show Ranking: 4

# %% [markdown]
# ### Linea Abierta

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Linea_Abierta_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 21.4%
# Median: 6
# Mean: 7.00
# Overall Ranking: 49
# News-Show Ranking: 36

# %% [markdown]
# ### Living Dialogues

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Living_Dialogues_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 6
# Percent Familiar with Show: 42.9%
# Median: 8
# Mean: 8.17
# Overall Ranking: 34
# News-Show Ranking: 24

# %% [markdown]
# ### Local PM Headlines Spanish

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Local_PM_Headlines_Spanish_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 13
# Respondents Familiar with Show: 6
# Percent Familiar with Show: 46.2%
# Median: 9
# Mean: 8.33
# Overall Ranking: 33
# News-Show Ranking: 23

# %% [markdown]
# ### Making Contact

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Making_Contact_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 50.0%
# Median: 8
# Mean: 7.86
# Overall Ranking: 30
# News-Show Ranking: 20

# %% [markdown]
# ### Metro

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Metro_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 10
# Percent Familiar with Show: 71.4%
# Median: 6
# Mean: 6.10
# Overall Ranking: 24
# News-Show Ranking: 15

# %% [markdown]
# ### Metro Arts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Metro_Arts_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 9
# Percent Familiar with Show: 64.3%
# Median: 7
# Mean: 5.89
# Overall Ranking: 31
# News-Show Ranking: 21

# %% [markdown]
# ### Morning Magazine

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Morning_Magazine_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 50.0%
# Median: 8
# Mean: 8.86
# Overall Ranking: 23
# News-Show Ranking: 14

# %% [markdown]
# ### Naturally

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Naturally_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 13
# Respondents Familiar with Show: 5
# Percent Familiar with Show: 38.5%
# Median: 9
# Mean: 8.40
# Overall Ranking: 39
# News-Show Ranking: 29

# %% [markdown]
# ### New Dimensions

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'New_Dimensions_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 57.1%
# Median: 7
# Mean: 7.50
# Overall Ranking: 25
# News-Show Ranking: 16

# %% [markdown]
# ### Outsources

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Outsources_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 6
# Percent Familiar with Show: 42.9%
# Median: 8
# Mean: 7.17
# Overall Ranking: 38
# News-Show Ranking: 28

# %% [markdown]
# ### Pasa La Voz

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Pasa_La_Voz_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 5
# Percent Familiar with Show: 35.7%
# Median: 7
# Mean: 6.60
# Overall Ranking: 46
# News-Show Ranking: 34

# %% [markdown]
# ### Peace Talks

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Peace_Talks_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 5
# Percent Familiar with Show: 35.7%
# Median: 10
# Mean: 9.60
# Overall Ranking: 35
# News-Show Ranking: 25

# %% [markdown]
# ### Project Censored

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Project_Censored_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 50.0%
# Median: 10
# Mean: 9.86
# Overall Ranking: 18
# News-Show Ranking: 10

# %% [markdown]
# ### Rising Up with Sonali

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Rising_Up_with_Sonali_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 6
# Percent Familiar with Show: 42.9%
# Median: 9
# Mean: 8.67
# Overall Ranking: 32
# News-Show Ranking: 22

# %% [markdown]
# ### Sprouts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Sprouts_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 5
# Percent Familiar with Show: 35.7%
# Median: 7
# Mean: 7.60
# Overall Ranking: 42
# News-Show Ranking: 31

# %% [markdown]
# ### StoryTellers of Color

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'StoryTellers_of_Color_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 21.4%
# Median: 6
# Mean: 6.00
# Overall Ranking: 50
# News-Show Ranking: 37

# %% [markdown]
# ### Laura Flanders

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Laura_Flanders_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 50.0%
# Median: 8
# Mean: 8.00
# Overall Ranking: 29
# News-Show Ranking: 19

# %% [markdown]
# ### Ralph Nader

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Ralph_Nader_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 12
# Percent Familiar with Show: 85.7%
# Median: 8
# Mean: 6.92
# Overall Ranking: 7
# News-Show Ranking: 2

# %% [markdown]
# ### Shortwave Report

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Shortwave_Report_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 57.1%
# Median: 9
# Mean: 8.62
# Overall Ranking: 18
# News-Show Ranking: 10

# %% [markdown]
# ### The World

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_World_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 6
# Percent Familiar with Show: 42.9%
# Median: 6
# Mean: 5.67
# Overall Ranking: 45
# News-Show Ranking: 33

# %% [markdown]
# ### TRENDS

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'TRENDS_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 28.6%
# Median: 9
# Mean: 7.25
# Overall Ranking: 48
# News-Show Ranking: 35

# %% [markdown]
# ### Tributaries

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Tributaries_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 50.0%
# Median: 9
# Mean: 8.86
# Overall Ranking: 23
# News-Show Ranking: 14

# %% [markdown]
# ### TUC Radio

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'TUC_Radio_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 6
# Percent Familiar with Show: 42.9%
# Median: 10
# Mean: 9.50
# Overall Ranking: 28
# News-Show Ranking: 18

# %% [markdown]
# ### WINGS

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'WINGS_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 5
# Percent Familiar with Show: 35.7%
# Median: 9
# Mean: 9.00
# Overall Ranking: 37
# News-Show Ranking: 27

# %% [markdown]
# ### Weed Between

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Weed_between_Ratings')
# Out:
# Filter: Adams County
# Total Respondents: 14
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 28.6%
# Median: 9
# Mean: 9.25
# Overall Ranking: 43
# News-Show Ranking: 32
