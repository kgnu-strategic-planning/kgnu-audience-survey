# %% [markdown]
# # All Respondents - Random

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import MaxNLocator
from IPython.display import display, Markdown
from functions import *

# %%
df = pd.read_excel('Client Data English-07.15.22.xlsx', sheet_name='English')

# %%
show_ratings_cols = df.columns.tolist()[111:191]
#show_ratings_cols

# %%
filter_col = 'all_respondents'
filter_col_val = ''
filter_col_val_display = 'Filter: None'

# %% [markdown]
# ## Show Rankings

# %%
create_ranked_table_of_shows(df, True, filter_col, filter_col_val, filter_col_val_display)
# Out:
# Overall      Show               #Ratings/    Median/Mean  Score   Music   News
# Ranking                        #Respondents                       Show    Show
#                                                                  Ranking Ranking
# --------------------------------------------------------------------------------
#  1    Blues Legacy                 69/116        7/6.6     453      1
#  2    BBC News Hour                63/112        7/6.9     435              1
#  3    ASA                          63/117        7/6.3     398      2
#  4    E Town                       66/116        6/6.0     396      3
#  5    Connections                  55/110        7/7.0     385              2
#  6    Roots and Branches           54/116        8/7.1     382      4
#  7    African Roots                63/114        6/6.0     377      5
#  8    Bioneers                     53/109        8/7.1     375              3
#  9    HTH                          57/115        7/6.3     360      6
# 10    HWY 322                      52/114        7/6.8     351      7
# 11    Corriente                    58/117        7/6.0     349      8
# 12    Reggae Bloodlines            54/114        7/6.3     340      9
# 12    Ragtime America              60/113        6/5.7     340      9
# 13    Dusty Grooves                51/116        7/6.6     335     10
# 14    Jazz Lives                   55/113        7/6.0     331     11
# 15    Grateful Dead                59/116        6/5.6     330     12
# 16    Gospel Chime                 56/115        6/5.9     329     13
# 17    MSA                          49/117        7/6.7     327     14
# 18    Kaberet                      50/112        6/6.3     316     15
# 19    The Opera Box                52/114        6/6.0     311     16
# 20    A Public Affair              47/110        7/6.6     308              4
# 21    BBC The Newsroom             45/111        7/6.8     307              5
# 21    Soundlab                     47/113        7/6.5     307     17
# 22    Jim Hightower                43/112        7/7.1     304              6
# 23    Swing Shift                  45/114        7/6.7     302     18
# 24    A Classic Monday             52/115        6/5.8     300     19
# 24    Democracy Now                43/111        7/7.0     300              7
# 25    OGGG                         53/116        6/5.6     297     20
# 26    Ralph Nader                  47/111        6/6.3     294              8
# 27    Alan Watts                   47/111        7/6.2     292              9
# 28    Morning Magazine             41/106        7/7.0     289             10
# 29    Counterspin                  41/110        7/7.0     288             11
# 30    Reggae Transfusions          44/114        7/6.5     287     21
# 31    Metro                        43/107        7/6.6     283             12
# 31    Tributaries                  41/111        7/6.9     283             12
# 32    Terrasonic                   42/114        7/6.7     282     22
# 33    Living Dialogues             44/108        7/6.4     281             13
# 34    Alternative Radio            42/109        7/6.6     277             14
# 35    Its The Economy              43/110        7/6.3     272             15
# 35    Laura Flanders               42/109        7/6.5     272             15
# 36    Seolta Gael                  46/114        6/5.9     271     23
# 37    Roots of Jazz                41/110        7/6.6     269     24
# 38    Hemispheres                  39/111        7/6.7     263             16
# 39    The World                    39/110        7/6.7     261             17
# 40    Electronic Air               46/116        6/5.7     260     25
# 41    Indian Voices                38/109        7/6.8     258             18
# 42    How on Earth                 36/110        8/7.1     256             19
# 43    Musica Mundi                 40/113        7/6.4     255     26
# 44    New Dimensions               39/109        7/6.5     253             20
# 45    Dub Palace                   43/115        6/5.8     250     27
# 46    Rising Up with Sonali        34/110        8/7.3     247             21
# 47    Between the Lines            36/109        7/6.8     245             22
# 48    Making Contact               36/104        7/6.8     244             23
# 48    Restless Mornings            37/111        7/6.6     244     28
# 49    Economic Update              32/109        8/7.2     229             24
# 50    Metro Arts                   34/104        7/6.7     228             25
# 51    La Lucha Sigue               33/108        7/6.8     223             26
# 52    Under the Floorboards        34/113        7/6.5     222     29
# 52    Naturally                    34/107        7/6.5     222             27
# 52    WINGS                        32/109        7/6.9     222             27
# 52    Sleepless Nights             34/113        7/6.5     222     29
# 53    Project Censored             28/107        8/7.8     217             28
# 54    Black Talk                   35/110        6/6.2     216             29
# 55    Shortwave Report             32/110        6/6.5     209             30
# 56    Local PM Headlines Spanish   31/106        7/6.5     203             31
# 56    Sprouts                      32/109        6/6.3     203             31
# 57    TUC Radio                    27/108        8/7.4     199             32
# 58    Eclipse                      37/115        5/5.4     198     30
# 59    Labor Exchange               32/107        6/6.2     197             33
# 60    Outsources                   30/107        7/6.4     193             34
# 60    Present Edge                 31/113        6/6.2     193     31
# 61    Smash It Back                30/114        6/6.4     192     32
# 62    Weed between                 28/111        8/6.6     186             35
# 63    Peace Talks                  27/106        7/6.3     169             36
# 64    The Heavy Set                26/112        7/6.3     165     33
# 65    StoryTellers of Color        21/108        7/6.6     138             37
# 66    TRENDS                       18/108        6/7.1     128             38
# 67    Col Chinese Radio Network    22/109        5/5.4     119             39
# 68    Pasa La Voz                  16/105        7/6.4     103             40
# 69    Linea Abierta                15/105        6/5.9      88             41

# %% [markdown]
# ## Music Shows

# %% [markdown]
# ### A Classic Monday

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'A_Classic_Monday_Ratings')
# Out:
# Filter: None
# Total Respondents: 115
# Respondents Familiar with Show: 52
# Percent Familiar with Show: 45.2%
# Median: 6
# Mean: 5.77
# Overall Ranking: 24
# Music-Show Ranking: 19

# %% [markdown]
# ### African Roots

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'African_Roots_Ratings')
# Out:
# Filter: None
# Total Respondents: 114
# Respondents Familiar with Show: 63
# Percent Familiar with Show: 55.3%
# Median: 6
# Mean: 5.98
# Overall Ranking: 7
# Music-Show Ranking: 5

# %% [markdown]
# ### Afternoon Sound Alternative

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'ASA_Ratings')
# Out:
# Filter: None
# Total Respondents: 117
# Respondents Familiar with Show: 63
# Percent Familiar with Show: 53.8%
# Median: 7
# Mean: 6.32
# Overall Ranking: 3
# Music-Show Ranking: 2

# %% [markdown]
# ### Blues Legacy

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Blues_Legacy_Ratings')
# Out:
# Filter: None
# Total Respondents: 116
# Respondents Familiar with Show: 69
# Percent Familiar with Show: 59.5%
# Median: 7
# Mean: 6.57
# Overall Ranking: 1
# Music-Show Ranking: 1

# %% [markdown]
# ### Corriente

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Corriente_Ratings')
# Out:
# Filter: None
# Total Respondents: 117
# Respondents Familiar with Show: 58
# Percent Familiar with Show: 49.6%
# Median: 7
# Mean: 6.02
# Overall Ranking: 11
# Music-Show Ranking: 8

# %% [markdown]
# ### Dub Palace

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Dub_Palace_Ratings')
# Out:
# Filter: None
# Total Respondents: 115
# Respondents Familiar with Show: 43
# Percent Familiar with Show: 37.4%
# Median: 6
# Mean: 5.81
# Overall Ranking: 45
# Music-Show Ranking: 27

# %% [markdown]
# ### Dusty Grooves

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Dusty_Grooves_Ratings')
# Out:
# Filter: None
# Total Respondents: 116
# Respondents Familiar with Show: 51
# Percent Familiar with Show: 44.0%
# Median: 7
# Mean: 6.57
# Overall Ranking: 13
# Music-Show Ranking: 10

# %% [markdown]
# ### Eclipse

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Eclipse_Ratings')
# Out:
# Filter: None
# Total Respondents: 115
# Respondents Familiar with Show: 37
# Percent Familiar with Show: 32.2%
# Median: 5
# Mean: 5.35
# Overall Ranking: 58
# Music-Show Ranking: 30

# %% [markdown]
# ### Electronic Air

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Electronic_Air_Ratings')
# Out:
# Filter: None
# Total Respondents: 116
# Respondents Familiar with Show: 46
# Percent Familiar with Show: 39.7%
# Median: 6
# Mean: 5.65
# Overall Ranking: 40
# Music-Show Ranking: 25

# %% [markdown]
# ### eTown

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'E_Town_Ratings')
# Out:
# Filter: None
# Total Respondents: 116
# Respondents Familiar with Show: 66
# Percent Familiar with Show: 56.9%
# Median: 6
# Mean: 6.00
# Overall Ranking: 4
# Music-Show Ranking: 3

# %% [markdown]
# ### Gospel Chime

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Gospel_Chime_Ratings')
# Out:
# Filter: None
# Total Respondents: 115
# Respondents Familiar with Show: 56
# Percent Familiar with Show: 48.7%
# Median: 6
# Mean: 5.88
# Overall Ranking: 16
# Music-Show Ranking: 13

# %% [markdown]
# ### Grateful Dead

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Grateful_Dead_Ratings')
# Out:
# Filter: None
# Total Respondents: 116
# Respondents Familiar with Show: 59
# Percent Familiar with Show: 50.9%
# Median: 6
# Mean: 5.59
# Overall Ranking: 15
# Music-Show Ranking: 12

# %% [markdown]
# ### Hwy 322

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'HWY_322_Ratings')
# Out:
# Filter: None
# Total Respondents: 114
# Respondents Familiar with Show: 52
# Percent Familiar with Show: 45.6%
# Median: 7
# Mean: 6.75
# Overall Ranking: 10
# Music-Show Ranking: 7

# %% [markdown]
# ### Honky Tonk Heroes

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'HTH_Ratings')
# Out:
# Filter: None
# Total Respondents: 115
# Respondents Familiar with Show: 57
# Percent Familiar with Show: 49.6%
# Median: 7
# Mean: 6.32
# Overall Ranking: 9
# Music-Show Ranking: 6

# %% [markdown]
# ### Jazz Lives

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Jazz_Lives_Ratings')
# Out:
# Filter: None
# Total Respondents: 113
# Respondents Familiar with Show: 55
# Percent Familiar with Show: 48.7%
# Median: 7
# Mean: 6.02
# Overall Ranking: 14
# Music-Show Ranking: 11

# %% [markdown]
# ### Kaberet

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Kaberet_Ratings')
# Out:
# Filter: None
# Total Respondents: 112
# Respondents Familiar with Show: 50
# Percent Familiar with Show: 44.6%
# Median: 6
# Mean: 6.32
# Overall Ranking: 18
# Music-Show Ranking: 15

# %% [markdown]
# ### Morning Sound Alternative

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'MSA_Ratings')
# Out:
# Filter: None
# Total Respondents: 117
# Respondents Familiar with Show: 49
# Percent Familiar with Show: 41.9%
# Median: 7
# Mean: 6.67
# Overall Ranking: 17
# Music-Show Ranking: 14

# %% [markdown]
# ### Musica Mundi

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Musica_Mundi_Ratings')
# Out:
# Filter: None
# Total Respondents: 113
# Respondents Familiar with Show: 40
# Percent Familiar with Show: 35.4%
# Median: 7
# Mean: 6.38
# Overall Ranking: 43
# Music-Show Ranking: 26

# %% [markdown]
# ### Old Grass Gnu Grass

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'OGGG_Ratings')
# Out:
# Filter: None
# Total Respondents: 116
# Respondents Familiar with Show: 53
# Percent Familiar with Show: 45.7%
# Median: 6
# Mean: 5.60
# Overall Ranking: 25
# Music-Show Ranking: 20

# %% [markdown]
# ### The Present Edge

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Present_Edge_Ratings')
# Out:
# Filter: None
# Total Respondents: 113
# Respondents Familiar with Show: 31
# Percent Familiar with Show: 27.4%
# Median: 6
# Mean: 6.23
# Overall Ranking: 60
# Music-Show Ranking: 31

# %% [markdown]
# ### Ragtime America

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Ragtime_America_Ratings')
# Out:
# Filter: None
# Total Respondents: 113
# Respondents Familiar with Show: 60
# Percent Familiar with Show: 53.1%
# Median: 6
# Mean: 5.67
# Overall Ranking: 12
# Music-Show Ranking: 9

# %% [markdown]
# ### Reggae Bloodlines

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Reggae_Bloodlines_Ratings')
# Out:
# Filter: None
# Total Respondents: 114
# Respondents Familiar with Show: 54
# Percent Familiar with Show: 47.4%
# Median: 7
# Mean: 6.30
# Overall Ranking: 12
# Music-Show Ranking: 9

# %% [markdown]
# ### Reggae Transfusions

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Reggae_Transfusions_Ratings')
# Out:
# Filter: None
# Total Respondents: 114
# Respondents Familiar with Show: 44
# Percent Familiar with Show: 38.6%
# Median: 7
# Mean: 6.52
# Overall Ranking: 30
# Music-Show Ranking: 21

# %% [markdown]
# ### Restless Mornings

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Restless_Mornings_Ratings')
# Out:
# Filter: None
# Total Respondents: 111
# Respondents Familiar with Show: 37
# Percent Familiar with Show: 33.3%
# Median: 7
# Mean: 6.59
# Overall Ranking: 48
# Music-Show Ranking: 28

# %% [markdown]
# ### Roots and Branches

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Roots_and_Branches_Ratings')
# Out:
# Filter: None
# Total Respondents: 116
# Respondents Familiar with Show: 54
# Percent Familiar with Show: 46.6%
# Median: 8
# Mean: 7.07
# Overall Ranking: 6
# Music-Show Ranking: 4

# %% [markdown]
# ### Roots of Jazz

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Roots_of_Jazz_Ratings')
# Out:
# Filter: None
# Total Respondents: 110
# Respondents Familiar with Show: 41
# Percent Familiar with Show: 37.3%
# Median: 7
# Mean: 6.56
# Overall Ranking: 37
# Music-Show Ranking: 24

# %% [markdown]
# ### Seolta Gael

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Seolta_Gael_Ratings')
# Out:
# Filter: None
# Total Respondents: 114
# Respondents Familiar with Show: 46
# Percent Familiar with Show: 40.4%
# Median: 6
# Mean: 5.89
# Overall Ranking: 36
# Music-Show Ranking: 23

# %% [markdown]
# ### Sleepless Nights

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Sleepless_Nights_Ratings')
# Out:
# Filter: None
# Total Respondents: 113
# Respondents Familiar with Show: 34
# Percent Familiar with Show: 30.1%
# Median: 7
# Mean: 6.53
# Overall Ranking: 52
# Music-Show Ranking: 29

# %% [markdown]
# ### Smash It Back

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Smash_It_Back_Ratings')
# Out:
# Filter: None
# Total Respondents: 114
# Respondents Familiar with Show: 30
# Percent Familiar with Show: 26.3%
# Median: 6
# Mean: 6.40
# Overall Ranking: 61
# Music-Show Ranking: 32

# %% [markdown]
# ### SoundLab

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Soundlab_Ratings')
# Out:
# Filter: None
# Total Respondents: 113
# Respondents Familiar with Show: 47
# Percent Familiar with Show: 41.6%
# Median: 7
# Mean: 6.53
# Overall Ranking: 21
# Music-Show Ranking: 17

# %% [markdown]
# ### Swing Shift

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Swing_Shift_Ratings')
# Out:
# Filter: None
# Total Respondents: 114
# Respondents Familiar with Show: 45
# Percent Familiar with Show: 39.5%
# Median: 7
# Mean: 6.71
# Overall Ranking: 23
# Music-Show Ranking: 18

# %% [markdown]
# ### Terrasonic

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Terrasonic_Ratings')
# Out:
# Filter: None
# Total Respondents: 114
# Respondents Familiar with Show: 42
# Percent Familiar with Show: 36.8%
# Median: 7
# Mean: 6.71
# Overall Ranking: 32
# Music-Show Ranking: 22

# %% [markdown]
# ### The Heavy Set

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_Heavy_Set_Ratings')
# Out:
# Filter: None
# Total Respondents: 112
# Respondents Familiar with Show: 26
# Percent Familiar with Show: 23.2%
# Median: 7
# Mean: 6.35
# Overall Ranking: 64
# Music-Show Ranking: 33

# %% [markdown]
# ### The Opera Box

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_Opera_Box_Ratings')
# Out:
# Filter: None
# Total Respondents: 114
# Respondents Familiar with Show: 52
# Percent Familiar with Show: 45.6%
# Median: 6
# Mean: 5.98
# Overall Ranking: 19
# Music-Show Ranking: 16

# %% [markdown]
# ### Under the Floorboards

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Under_the_Floorboards_Ratings')
# Out:
# Filter: None
# Total Respondents: 113
# Respondents Familiar with Show: 34
# Percent Familiar with Show: 30.1%
# Median: 7
# Mean: 6.53
# Overall Ranking: 52
# Music-Show Ranking: 29

# %% [markdown]
# ## News Shows

# %% [markdown]
# ### A Public Affairs

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'A_Public_Affair_Ratings')
# Out:
# Filter: None
# Total Respondents: 110
# Respondents Familiar with Show: 47
# Percent Familiar with Show: 42.7%
# Median: 7
# Mean: 6.55
# Overall Ranking: 20
# News-Show Ranking: 4

# %% [markdown]
# ### Alan Watts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Alan_Watts_Ratings')
# Out:
# Filter: None
# Total Respondents: 111
# Respondents Familiar with Show: 47
# Percent Familiar with Show: 42.3%
# Median: 7
# Mean: 6.21
# Overall Ranking: 27
# News-Show Ranking: 9

# %% [markdown]
# ### Alternative Radio

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Alternative_Radio_Ratings')
# Out:
# Filter: None
# Total Respondents: 109
# Respondents Familiar with Show: 42
# Percent Familiar with Show: 38.5%
# Median: 7
# Mean: 6.60
# Overall Ranking: 34
# News-Show Ranking: 14

# %% [markdown]
# ### BBC News Hour

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'BBC_News_Hour_Ratings')
# Out:
# Filter: None
# Total Respondents: 112
# Respondents Familiar with Show: 63
# Percent Familiar with Show: 56.2%
# Median: 7
# Mean: 6.90
# Overall Ranking: 2
# News-Show Ranking: 1

# %% [markdown]
# ### BBC The Newsroom

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'BBC_The_Newsroom_Ratings')
# Out:
# Filter: None
# Total Respondents: 111
# Respondents Familiar with Show: 45
# Percent Familiar with Show: 40.5%
# Median: 7
# Mean: 6.82
# Overall Ranking: 21
# News-Show Ranking: 5

# %% [markdown]
# ### Between the Lines

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Between_the_Lines_Ratings')
# Out:
# Filter: None
# Total Respondents: 109
# Respondents Familiar with Show: 36
# Percent Familiar with Show: 33.0%
# Median: 7
# Mean: 6.81
# Overall Ranking: 47
# News-Show Ranking: 22

# %% [markdown]
# ### Bioneers

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Bioneers_Ratings')
# Out:
# Filter: None
# Total Respondents: 109
# Respondents Familiar with Show: 53
# Percent Familiar with Show: 48.6%
# Median: 8
# Mean: 7.08
# Overall Ranking: 8
# News-Show Ranking: 3

# %% [markdown]
# ### Black Talk

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Black_Talk_Ratings')
# Out:
# Filter: None
# Total Respondents: 110
# Respondents Familiar with Show: 35
# Percent Familiar with Show: 31.8%
# Median: 6
# Mean: 6.17
# Overall Ranking: 54
# News-Show Ranking: 29

# %% [markdown]
# ### Colorado Chinese Radio Network

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Col_Chinese_Radio_Network_Ratings')
# Out:
# Filter: None
# Total Respondents: 109
# Respondents Familiar with Show: 22
# Percent Familiar with Show: 20.2%
# Median: 5
# Mean: 5.41
# Overall Ranking: 67
# News-Show Ranking: 39

# %% [markdown]
# ### Connections

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Connections_Ratings')
# Out:
# Filter: None
# Total Respondents: 110
# Respondents Familiar with Show: 55
# Percent Familiar with Show: 50.0%
# Median: 7
# Mean: 7.00
# Overall Ranking: 5
# News-Show Ranking: 2

# %% [markdown]
# ### Counterspin

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Counterspin_Ratings')
# Out:
# Filter: None
# Total Respondents: 110
# Respondents Familiar with Show: 41
# Percent Familiar with Show: 37.3%
# Median: 7
# Mean: 7.02
# Overall Ranking: 29
# News-Show Ranking: 11

# %% [markdown]
# ### Democracy Now

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Democracy_Now_Ratings')
# Out:
# Filter: None
# Total Respondents: 111
# Respondents Familiar with Show: 43
# Percent Familiar with Show: 38.7%
# Median: 7
# Mean: 6.98
# Overall Ranking: 24
# News-Show Ranking: 7

# %% [markdown]
# ### Economic Update

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Economic_Update_Ratings')
# Out:
# Filter: None
# Total Respondents: 109
# Respondents Familiar with Show: 32
# Percent Familiar with Show: 29.4%
# Median: 8
# Mean: 7.16
# Overall Ranking: 49
# News-Show Ranking: 24

# %% [markdown]
# ### Hemispheres

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Hemispheres_Ratings')
# Out:
# Filter: None
# Total Respondents: 111
# Respondents Familiar with Show: 39
# Percent Familiar with Show: 35.1%
# Median: 7
# Mean: 6.74
# Overall Ranking: 38
# News-Show Ranking: 16

# %% [markdown]
# ### How on Earth

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'How_on_Earth_Ratings')
# Out:
# Filter: None
# Total Respondents: 110
# Respondents Familiar with Show: 36
# Percent Familiar with Show: 32.7%
# Median: 8
# Mean: 7.11
# Overall Ranking: 42
# News-Show Ranking: 19

# %% [markdown]
# ### Indian Voices

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Indian_Voices_Ratings')
# Out:
# Filter: None
# Total Respondents: 109
# Respondents Familiar with Show: 38
# Percent Familiar with Show: 34.9%
# Median: 7
# Mean: 6.79
# Overall Ranking: 41
# News-Show Ranking: 18

# %% [markdown]
# ### It's the Economy

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Its_The_Economy_Ratings')
# Out:
# Filter: None
# Total Respondents: 110
# Respondents Familiar with Show: 43
# Percent Familiar with Show: 39.1%
# Median: 7
# Mean: 6.33
# Overall Ranking: 35
# News-Show Ranking: 15

# %% [markdown]
# ### Jim Hightower

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Jim_Hightower_Ratings')
# Out:
# Filter: None
# Total Respondents: 112
# Respondents Familiar with Show: 43
# Percent Familiar with Show: 38.4%
# Median: 7
# Mean: 7.07
# Overall Ranking: 22
# News-Show Ranking: 6

# %% [markdown]
# ### La Lucha Sigue

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'La_Lucha_Sigue_Ratings')
# Out:
# Filter: None
# Total Respondents: 108
# Respondents Familiar with Show: 33
# Percent Familiar with Show: 30.6%
# Median: 7
# Mean: 6.76
# Overall Ranking: 51
# News-Show Ranking: 26

# %% [markdown]
# ### Labor Exchange

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Labor_Exchange_Ratings')
# Out:
# Filter: None
# Total Respondents: 107
# Respondents Familiar with Show: 32
# Percent Familiar with Show: 29.9%
# Median: 6
# Mean: 6.16
# Overall Ranking: 59
# News-Show Ranking: 33

# %% [markdown]
# ### Linea Abierta

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Linea_Abierta_Ratings')
# Out:
# Filter: None
# Total Respondents: 105
# Respondents Familiar with Show: 15
# Percent Familiar with Show: 14.3%
# Median: 6
# Mean: 5.87
# Overall Ranking: 69
# News-Show Ranking: 41

# %% [markdown]
# ### Living Dialogues

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Living_Dialogues_Ratings')
# Out:
# Filter: None
# Total Respondents: 108
# Respondents Familiar with Show: 44
# Percent Familiar with Show: 40.7%
# Median: 7
# Mean: 6.39
# Overall Ranking: 33
# News-Show Ranking: 13

# %% [markdown]
# ### Local PM Headlines Spanish

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Local_PM_Headlines_Spanish_Ratings')
# Out:
# Filter: None
# Total Respondents: 106
# Respondents Familiar with Show: 31
# Percent Familiar with Show: 29.2%
# Median: 7
# Mean: 6.55
# Overall Ranking: 56
# News-Show Ranking: 31

# %% [markdown]
# ### Making Contact

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Making_Contact_Ratings')
# Out:
# Filter: None
# Total Respondents: 104
# Respondents Familiar with Show: 36
# Percent Familiar with Show: 34.6%
# Median: 7
# Mean: 6.78
# Overall Ranking: 48
# News-Show Ranking: 23

# %% [markdown]
# ### Metro

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Metro_Ratings')
# Out:
# Filter: None
# Total Respondents: 107
# Respondents Familiar with Show: 43
# Percent Familiar with Show: 40.2%
# Median: 7
# Mean: 6.58
# Overall Ranking: 31
# News-Show Ranking: 12

# %% [markdown]
# ### Metro Arts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Metro_Arts_Ratings')
# Out:
# Filter: None
# Total Respondents: 104
# Respondents Familiar with Show: 34
# Percent Familiar with Show: 32.7%
# Median: 7
# Mean: 6.71
# Overall Ranking: 50
# News-Show Ranking: 25

# %% [markdown]
# ### Morning Magazine

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Morning_Magazine_Ratings')
# Out:
# Filter: None
# Total Respondents: 106
# Respondents Familiar with Show: 41
# Percent Familiar with Show: 38.7%
# Median: 7
# Mean: 7.05
# Overall Ranking: 28
# News-Show Ranking: 10

# %% [markdown]
# ### Naturally

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Naturally_Ratings')
# Out:
# Filter: None
# Total Respondents: 107
# Respondents Familiar with Show: 34
# Percent Familiar with Show: 31.8%
# Median: 7
# Mean: 6.53
# Overall Ranking: 52
# News-Show Ranking: 27

# %% [markdown]
# ### New Dimensions

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'New_Dimensions_Ratings')
# Out:
# Filter: None
# Total Respondents: 109
# Respondents Familiar with Show: 39
# Percent Familiar with Show: 35.8%
# Median: 7
# Mean: 6.49
# Overall Ranking: 44
# News-Show Ranking: 20

# %% [markdown]
# ### Outsources

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Outsources_Ratings')
# Out:
# Filter: None
# Total Respondents: 107
# Respondents Familiar with Show: 30
# Percent Familiar with Show: 28.0%
# Median: 7
# Mean: 6.43
# Overall Ranking: 60
# News-Show Ranking: 34

# %% [markdown]
# ### Pasa La Voz

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Pasa_La_Voz_Ratings')
# Out:
# Filter: None
# Total Respondents: 105
# Respondents Familiar with Show: 16
# Percent Familiar with Show: 15.2%
# Median: 7
# Mean: 6.44
# Overall Ranking: 68
# News-Show Ranking: 40

# %% [markdown]
# ### Peace Talks

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Peace_Talks_Ratings')
# Out:
# Filter: None
# Total Respondents: 106
# Respondents Familiar with Show: 27
# Percent Familiar with Show: 25.5%
# Median: 7
# Mean: 6.26
# Overall Ranking: 63
# News-Show Ranking: 36

# %% [markdown]
# ### Project Censored

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Project_Censored_Ratings')
# Out:
# Filter: None
# Total Respondents: 107
# Respondents Familiar with Show: 28
# Percent Familiar with Show: 26.2%
# Median: 8
# Mean: 7.75
# Overall Ranking: 53
# News-Show Ranking: 28

# %% [markdown]
# ### Rising Up with Sonali

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Rising_Up_with_Sonali_Ratings')
# Out:
# Filter: None
# Total Respondents: 110
# Respondents Familiar with Show: 34
# Percent Familiar with Show: 30.9%
# Median: 8
# Mean: 7.26
# Overall Ranking: 46
# News-Show Ranking: 21

# %% [markdown]
# ### Sprouts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Sprouts_Ratings')
# Out:
# Filter: None
# Total Respondents: 109
# Respondents Familiar with Show: 32
# Percent Familiar with Show: 29.4%
# Median: 6
# Mean: 6.34
# Overall Ranking: 56
# News-Show Ranking: 31

# %% [markdown]
# ### StoryTellers of Color

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'StoryTellers_of_Color_Ratings')
# Out:
# Filter: None
# Total Respondents: 108
# Respondents Familiar with Show: 21
# Percent Familiar with Show: 19.4%
# Median: 7
# Mean: 6.57
# Overall Ranking: 65
# News-Show Ranking: 37

# %% [markdown]
# ### Laura Flanders

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Laura_Flanders_Ratings')
# Out:
# Filter: None
# Total Respondents: 109
# Respondents Familiar with Show: 42
# Percent Familiar with Show: 38.5%
# Median: 7
# Mean: 6.48
# Overall Ranking: 35
# News-Show Ranking: 15

# %% [markdown]
# ### Ralph Nader

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Ralph_Nader_Ratings')
# Out:
# Filter: None
# Total Respondents: 111
# Respondents Familiar with Show: 47
# Percent Familiar with Show: 42.3%
# Median: 6
# Mean: 6.26
# Overall Ranking: 26
# News-Show Ranking: 8

# %% [markdown]
# ### Shortwave Report

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Shortwave_Report_Ratings')
# Out:
# Filter: None
# Total Respondents: 110
# Respondents Familiar with Show: 32
# Percent Familiar with Show: 29.1%
# Median: 6
# Mean: 6.53
# Overall Ranking: 55
# News-Show Ranking: 30

# %% [markdown]
# ### The World

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_World_Ratings')
# Out:
# Filter: None
# Total Respondents: 110
# Respondents Familiar with Show: 39
# Percent Familiar with Show: 35.5%
# Median: 7
# Mean: 6.69
# Overall Ranking: 39
# News-Show Ranking: 17

# %% [markdown]
# ### TRENDS

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'TRENDS_Ratings')
# Out:
# Filter: None
# Total Respondents: 108
# Respondents Familiar with Show: 18
# Percent Familiar with Show: 16.7%
# Median: 6
# Mean: 7.11
# Overall Ranking: 66
# News-Show Ranking: 38

# %% [markdown]
# ### Tributaries

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Tributaries_Ratings')
# Out:
# Filter: None
# Total Respondents: 111
# Respondents Familiar with Show: 41
# Percent Familiar with Show: 36.9%
# Median: 7
# Mean: 6.90
# Overall Ranking: 31
# News-Show Ranking: 12

# %% [markdown]
# ### TUC Radio

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'TUC_Radio_Ratings')
# Out:
# Filter: None
# Total Respondents: 108
# Respondents Familiar with Show: 27
# Percent Familiar with Show: 25.0%
# Median: 8
# Mean: 7.37
# Overall Ranking: 57
# News-Show Ranking: 32

# %% [markdown]
# ### WINGS

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'WINGS_Ratings')
# Out:
# Filter: None
# Total Respondents: 109
# Respondents Familiar with Show: 32
# Percent Familiar with Show: 29.4%
# Median: 7
# Mean: 6.94
# Overall Ranking: 52
# News-Show Ranking: 27

# %% [markdown]
# ### Weed Between

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Weed_between_Ratings')
# Out:
# Filter: None
# Total Respondents: 111
# Respondents Familiar with Show: 28
# Percent Familiar with Show: 25.2%
# Median: 8
# Mean: 6.64
# Overall Ranking: 62
# News-Show Ranking: 35
