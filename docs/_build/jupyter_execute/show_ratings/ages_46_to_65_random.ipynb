# %% [markdown]
# # Ages 46 - 65 - Random

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import MaxNLocator
from IPython.display import display, Markdown
from functions import *

# %%
df = pd.read_excel('Client Data English-07.15.22.xlsx', sheet_name='English')

# %%
show_ratings_cols = df.columns.tolist()[111:191]
#show_ratings_cols

# %%
filter_col = 'Age'
filter_col_val = 4
filter_col_val_display = 'Filter: Ages 46 - 65'

# %% [markdown]
# ## Show Rankings

# %%
create_ranked_table_of_shows(df, True, filter_col, filter_col_val, filter_col_val_display)
# Out:
# Overall      Show               #Ratings/    Median/Mean  Score   Music   News
# Ranking                        #Respondents                       Show    Show
#                                                                  Ranking Ranking
# --------------------------------------------------------------------------------
#  1    ASA                           28/47        7/6.2     174      1
#  1    Bioneers                      22/46        8/7.9     174              1
#  2    Reggae Bloodlines             27/47        7/6.4     173      2
#  3    Soundlab                      25/46        7/6.9     172      3
#  3    Blues Legacy                  26/47        7/6.6     172      3
#  3    E Town                        27/46        7/6.4     172      3
#  4    Connections                   24/46        7/6.8     163              2
#  5    BBC News Hour                 23/47        7/6.7     154              3
#  6    MSA                           21/47        8/7.1     149      4
#  7    Reggae Transfusions           23/47        7/6.4     148      5
#  8    Under the Floorboards         21/47        7/7.0     146      6
#  8    Ragtime America               25/47        6/5.8     146      6
#  9    Kaberet                       22/46        6/6.5     144      7
#  9    Swing Shift                   20/47        7/7.2     144      7
# 10    Gospel Chime                  25/45        6/5.7     143      8
# 11    Alan Watts                    21/47        7/6.8     142              4
# 12    Ralph Nader                   23/46        6/6.0     137              5
# 12    The Opera Box                 20/47        8/6.8     137      9
# 13    African Roots                 24/46        6/5.7     136     10
# 14    Roots and Branches            20/48        7/6.8     135     11
# 15    Grateful Dead                 23/46        5/5.8     134     12
# 15    Jazz Lives                    22/45        6/6.1     134     12
# 16    Electronic Air                21/46        6/6.2     130     13
# 16    Corriente                     23/47        7/5.7     130     13
# 17    HTH                           20/45        6/6.4     128     14
# 18    HWY 322                       19/46        7/6.6     125     15
# 18    Jim Hightower                 18/46        7/6.9     125              6
# 18    Terrasonic                    19/47        8/6.6     125     15
# 19    A Classic Monday              21/46        6/5.9     123     16
# 20    A Public Affair               20/46        6/6.0     121              7
# 21    Counterspin                   17/46        7/7.1     120              8
# 21    Dusty Grooves                 17/46        8/7.1     120     17
# 22    Musica Mundi                  20/45        7/6.0     119     18
# 23    Smash It Back                 18/47        7/6.6     118     19
# 24    Hemispheres                   19/47        6/6.1     116              9
# 25    Indian Voices                 17/47        7/6.7     114             10
# 25    The World                     17/46        7/6.7     114             10
# 26    OGGG                          23/48        4/4.9     112     20
# 27    Making Contact                16/45        7/6.9     111             11
# 28    Shortwave Report              17/47        6/6.5     110             12
# 28    Alternative Radio             17/47        6/6.5     110             12
# 29    New Dimensions                16/45        7/6.8     109             13
# 30    Morning Magazine              16/44        7/6.7     107             14
# 31    Restless Mornings             17/46        6/6.2     105     21
# 31    Laura Flanders                17/47        6/6.2     105             15
# 31    Seolta Gael                   18/47        5/5.8     105     21
# 31    Democracy Now                 17/47        7/6.2     105             15
# 32    TUC Radio                     14/46        8/7.4     104             16
# 33    Dub Palace                    17/46        6/6.1     103     22
# 34    BBC The Newsroom              15/46        7/6.8     102             17
# 34    Present Edge                  15/46        7/6.8     102     23
# 34    Outsources                    14/46        8/7.3     102             17
# 35    WINGS                         15/46        7/6.6      99             18
# 36    Metro                         14/46        7/7.0      98             19
# 37    Living Dialogues              16/45        6/6.1      97             20
# 38    Tributaries                   14/47        7/6.9      96             21
# 38    Its The Economy               16/47        6/6.0      96             21
# 39    Sleepless Nights              15/47        7/6.3      95     24
# 40    How on Earth                  13/46        8/7.2      94             22
# 41    Rising Up with Sonali         13/47        8/7.2      93             23
# 42    Project Censored              12/46        8/7.7      92             24
# 43    Roots of Jazz                 14/47        7/6.5      91     25
# 44    Local PM Headlines Spanish    13/45        7/6.7      87             25
# 44    Sprouts                       15/46        5/5.8      87             25
# 45    Naturally                     12/45        7/6.9      83             26
# 46    Black Talk                    13/47        6/6.2      81             27
# 47    Metro Arts                    11/45        7/7.1      78             28
# 47    La Lucha Sigue                11/46        8/7.1      78             28
# 47    The Heavy Set                 12/46        8/6.5      78     26
# 48    Between the Lines             12/46        7/6.4      77             29
# 49    StoryTellers of Color         11/46        8/6.8      75             30
# 50    Weed between                  11/47        8/6.7      74             31
# 51    Labor Exchange                10/46        8/6.9      69             32
# 52    Eclipse                       13/46        5/5.2      67     27
# 53    Peace Talks                   11/45        7/5.9      65             33
# 54    TRENDS                         9/47        7/7.0      63             34
# 55    Col Chinese Radio Network      9/47        5/5.8      52             35
# 56    Economic Update                8/47        5/5.8      46             36
# 57    Linea Abierta                  6/44        7/6.5      39             37
# 58    Pasa La Voz                    4/45        7/7.8      31             38

# %% [markdown]
# ## Music Shows

# %% [markdown]
# ### A Classic Monday

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'A_Classic_Monday_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 21
# Percent Familiar with Show: 45.7%
# Median: 6
# Mean: 5.86
# Overall Ranking: 19
# Music-Show Ranking: 16

# %% [markdown]
# ### African Roots

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'African_Roots_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 24
# Percent Familiar with Show: 52.2%
# Median: 6
# Mean: 5.67
# Overall Ranking: 13
# Music-Show Ranking: 10

# %% [markdown]
# ### Afternoon Sound Alternative

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'ASA_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 28
# Percent Familiar with Show: 59.6%
# Median: 7
# Mean: 6.21
# Overall Ranking: 1
# Music-Show Ranking: 1

# %% [markdown]
# ### Blues Legacy

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Blues_Legacy_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 26
# Percent Familiar with Show: 55.3%
# Median: 7
# Mean: 6.62
# Overall Ranking: 3
# Music-Show Ranking: 3

# %% [markdown]
# ### Corriente

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Corriente_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 23
# Percent Familiar with Show: 48.9%
# Median: 7
# Mean: 5.65
# Overall Ranking: 16
# Music-Show Ranking: 13

# %% [markdown]
# ### Dub Palace

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Dub_Palace_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 17
# Percent Familiar with Show: 37.0%
# Median: 6
# Mean: 6.06
# Overall Ranking: 33
# Music-Show Ranking: 22

# %% [markdown]
# ### Dusty Grooves

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Dusty_Grooves_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 17
# Percent Familiar with Show: 37.0%
# Median: 8
# Mean: 7.06
# Overall Ranking: 21
# Music-Show Ranking: 17

# %% [markdown]
# ### Eclipse

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Eclipse_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 13
# Percent Familiar with Show: 28.3%
# Median: 5
# Mean: 5.15
# Overall Ranking: 52
# Music-Show Ranking: 27

# %% [markdown]
# ### Electronic Air

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Electronic_Air_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 21
# Percent Familiar with Show: 45.7%
# Median: 6
# Mean: 6.19
# Overall Ranking: 16
# Music-Show Ranking: 13

# %% [markdown]
# ### eTown

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'E_Town_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 27
# Percent Familiar with Show: 58.7%
# Median: 7
# Mean: 6.37
# Overall Ranking: 3
# Music-Show Ranking: 3

# %% [markdown]
# ### Gospel Chime

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Gospel_Chime_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 45
# Respondents Familiar with Show: 25
# Percent Familiar with Show: 55.6%
# Median: 6
# Mean: 5.72
# Overall Ranking: 10
# Music-Show Ranking: 8

# %% [markdown]
# ### Grateful Dead

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Grateful_Dead_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 23
# Percent Familiar with Show: 50.0%
# Median: 5
# Mean: 5.83
# Overall Ranking: 15
# Music-Show Ranking: 12

# %% [markdown]
# ### Hwy 322

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'HWY_322_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 19
# Percent Familiar with Show: 41.3%
# Median: 7
# Mean: 6.58
# Overall Ranking: 18
# Music-Show Ranking: 15

# %% [markdown]
# ### Honky Tonk Heroes

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'HTH_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 45
# Respondents Familiar with Show: 20
# Percent Familiar with Show: 44.4%
# Median: 6
# Mean: 6.40
# Overall Ranking: 17
# Music-Show Ranking: 14

# %% [markdown]
# ### Jazz Lives

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Jazz_Lives_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 45
# Respondents Familiar with Show: 22
# Percent Familiar with Show: 48.9%
# Median: 6
# Mean: 6.09
# Overall Ranking: 15
# Music-Show Ranking: 12

# %% [markdown]
# ### Kaberet

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Kaberet_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 22
# Percent Familiar with Show: 47.8%
# Median: 6
# Mean: 6.55
# Overall Ranking: 9
# Music-Show Ranking: 7

# %% [markdown]
# ### Morning Sound Alternative

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'MSA_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 21
# Percent Familiar with Show: 44.7%
# Median: 8
# Mean: 7.10
# Overall Ranking: 6
# Music-Show Ranking: 4

# %% [markdown]
# ### Musica Mundi

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Musica_Mundi_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 45
# Respondents Familiar with Show: 20
# Percent Familiar with Show: 44.4%
# Median: 7
# Mean: 5.95
# Overall Ranking: 22
# Music-Show Ranking: 18

# %% [markdown]
# ### Old Grass Gnu Grass

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'OGGG_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 48
# Respondents Familiar with Show: 23
# Percent Familiar with Show: 47.9%
# Median: 4
# Mean: 4.87
# Overall Ranking: 26
# Music-Show Ranking: 20

# %% [markdown]
# ### The Present Edge

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Present_Edge_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 15
# Percent Familiar with Show: 32.6%
# Median: 7
# Mean: 6.80
# Overall Ranking: 34
# Music-Show Ranking: 23

# %% [markdown]
# ### Ragtime America

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Ragtime_America_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 25
# Percent Familiar with Show: 53.2%
# Median: 6
# Mean: 5.84
# Overall Ranking: 8
# Music-Show Ranking: 6

# %% [markdown]
# ### Reggae Bloodlines

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Reggae_Bloodlines_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 27
# Percent Familiar with Show: 57.4%
# Median: 7
# Mean: 6.41
# Overall Ranking: 2
# Music-Show Ranking: 2

# %% [markdown]
# ### Reggae Transfusions

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Reggae_Transfusions_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 23
# Percent Familiar with Show: 48.9%
# Median: 7
# Mean: 6.43
# Overall Ranking: 7
# Music-Show Ranking: 5

# %% [markdown]
# ### Restless Mornings

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Restless_Mornings_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 17
# Percent Familiar with Show: 37.0%
# Median: 6
# Mean: 6.18
# Overall Ranking: 31
# Music-Show Ranking: 21

# %% [markdown]
# ### Roots and Branches

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Roots_and_Branches_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 48
# Respondents Familiar with Show: 20
# Percent Familiar with Show: 41.7%
# Median: 7
# Mean: 6.75
# Overall Ranking: 14
# Music-Show Ranking: 11

# %% [markdown]
# ### Roots of Jazz

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Roots_of_Jazz_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 14
# Percent Familiar with Show: 29.8%
# Median: 7
# Mean: 6.50
# Overall Ranking: 43
# Music-Show Ranking: 25

# %% [markdown]
# ### Seolta Gael

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Seolta_Gael_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 18
# Percent Familiar with Show: 38.3%
# Median: 5
# Mean: 5.83
# Overall Ranking: 31
# Music-Show Ranking: 21

# %% [markdown]
# ### Sleepless Nights

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Sleepless_Nights_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 15
# Percent Familiar with Show: 31.9%
# Median: 7
# Mean: 6.33
# Overall Ranking: 39
# Music-Show Ranking: 24

# %% [markdown]
# ### Smash It Back

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Smash_It_Back_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 18
# Percent Familiar with Show: 38.3%
# Median: 7
# Mean: 6.56
# Overall Ranking: 23
# Music-Show Ranking: 19

# %% [markdown]
# ### SoundLab

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Soundlab_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 25
# Percent Familiar with Show: 54.3%
# Median: 7
# Mean: 6.88
# Overall Ranking: 3
# Music-Show Ranking: 3

# %% [markdown]
# ### Swing Shift

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Swing_Shift_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 20
# Percent Familiar with Show: 42.6%
# Median: 7
# Mean: 7.20
# Overall Ranking: 9
# Music-Show Ranking: 7

# %% [markdown]
# ### Terrasonic

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Terrasonic_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 19
# Percent Familiar with Show: 40.4%
# Median: 8
# Mean: 6.58
# Overall Ranking: 18
# Music-Show Ranking: 15

# %% [markdown]
# ### The Heavy Set

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_Heavy_Set_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 12
# Percent Familiar with Show: 26.1%
# Median: 8
# Mean: 6.50
# Overall Ranking: 47
# Music-Show Ranking: 26

# %% [markdown]
# ### The Opera Box

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_Opera_Box_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 20
# Percent Familiar with Show: 42.6%
# Median: 8
# Mean: 6.85
# Overall Ranking: 12
# Music-Show Ranking: 9

# %% [markdown]
# ### Under the Floorboards

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Under_the_Floorboards_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 21
# Percent Familiar with Show: 44.7%
# Median: 7
# Mean: 6.95
# Overall Ranking: 8
# Music-Show Ranking: 6

# %% [markdown]
# ## News Shows

# %% [markdown]
# ### A Public Affairs

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'A_Public_Affair_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 20
# Percent Familiar with Show: 43.5%
# Median: 6
# Mean: 6.05
# Overall Ranking: 20
# News-Show Ranking: 7

# %% [markdown]
# ### Alan Watts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Alan_Watts_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 21
# Percent Familiar with Show: 44.7%
# Median: 7
# Mean: 6.76
# Overall Ranking: 11
# News-Show Ranking: 4

# %% [markdown]
# ### Alternative Radio

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Alternative_Radio_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 17
# Percent Familiar with Show: 36.2%
# Median: 6
# Mean: 6.47
# Overall Ranking: 28
# News-Show Ranking: 12

# %% [markdown]
# ### BBC News Hour

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'BBC_News_Hour_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 23
# Percent Familiar with Show: 48.9%
# Median: 7
# Mean: 6.70
# Overall Ranking: 5
# News-Show Ranking: 3

# %% [markdown]
# ### BBC The Newsroom

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'BBC_The_Newsroom_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 15
# Percent Familiar with Show: 32.6%
# Median: 7
# Mean: 6.80
# Overall Ranking: 34
# News-Show Ranking: 17

# %% [markdown]
# ### Between the Lines

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Between_the_Lines_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 12
# Percent Familiar with Show: 26.1%
# Median: 7
# Mean: 6.42
# Overall Ranking: 48
# News-Show Ranking: 29

# %% [markdown]
# ### Bioneers

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Bioneers_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 22
# Percent Familiar with Show: 47.8%
# Median: 8
# Mean: 7.91
# Overall Ranking: 1
# News-Show Ranking: 1

# %% [markdown]
# ### Black Talk

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Black_Talk_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 13
# Percent Familiar with Show: 27.7%
# Median: 6
# Mean: 6.23
# Overall Ranking: 46
# News-Show Ranking: 27

# %% [markdown]
# ### Colorado Chinese Radio Network

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Col_Chinese_Radio_Network_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 9
# Percent Familiar with Show: 19.1%
# Median: 5
# Mean: 5.78
# Overall Ranking: 55
# News-Show Ranking: 35

# %% [markdown]
# ### Connections

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Connections_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 24
# Percent Familiar with Show: 52.2%
# Median: 7
# Mean: 6.79
# Overall Ranking: 4
# News-Show Ranking: 2

# %% [markdown]
# ### Counterspin

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Counterspin_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 17
# Percent Familiar with Show: 37.0%
# Median: 7
# Mean: 7.06
# Overall Ranking: 21
# News-Show Ranking: 8

# %% [markdown]
# ### Democracy Now

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Democracy_Now_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 17
# Percent Familiar with Show: 36.2%
# Median: 7
# Mean: 6.18
# Overall Ranking: 31
# News-Show Ranking: 15

# %% [markdown]
# ### Economic Update

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Economic_Update_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 17.0%
# Median: 5
# Mean: 5.75
# Overall Ranking: 56
# News-Show Ranking: 36

# %% [markdown]
# ### Hemispheres

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Hemispheres_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 19
# Percent Familiar with Show: 40.4%
# Median: 6
# Mean: 6.11
# Overall Ranking: 24
# News-Show Ranking: 9

# %% [markdown]
# ### How on Earth

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'How_on_Earth_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 13
# Percent Familiar with Show: 28.3%
# Median: 8
# Mean: 7.23
# Overall Ranking: 40
# News-Show Ranking: 22

# %% [markdown]
# ### Indian Voices

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Indian_Voices_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 17
# Percent Familiar with Show: 36.2%
# Median: 7
# Mean: 6.71
# Overall Ranking: 25
# News-Show Ranking: 10

# %% [markdown]
# ### It's the Economy

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Its_The_Economy_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 16
# Percent Familiar with Show: 34.0%
# Median: 6
# Mean: 6.00
# Overall Ranking: 38
# News-Show Ranking: 21

# %% [markdown]
# ### Jim Hightower

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Jim_Hightower_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 18
# Percent Familiar with Show: 39.1%
# Median: 7
# Mean: 6.94
# Overall Ranking: 18
# News-Show Ranking: 6

# %% [markdown]
# ### La Lucha Sigue

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'La_Lucha_Sigue_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 11
# Percent Familiar with Show: 23.9%
# Median: 8
# Mean: 7.09
# Overall Ranking: 47
# News-Show Ranking: 28

# %% [markdown]
# ### Labor Exchange

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Labor_Exchange_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 10
# Percent Familiar with Show: 21.7%
# Median: 8
# Mean: 6.90
# Overall Ranking: 51
# News-Show Ranking: 32

# %% [markdown]
# ### Linea Abierta

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Linea_Abierta_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 44
# Respondents Familiar with Show: 6
# Percent Familiar with Show: 13.6%
# Median: 7
# Mean: 6.50
# Overall Ranking: 57
# News-Show Ranking: 37

# %% [markdown]
# ### Living Dialogues

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Living_Dialogues_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 45
# Respondents Familiar with Show: 16
# Percent Familiar with Show: 35.6%
# Median: 6
# Mean: 6.06
# Overall Ranking: 37
# News-Show Ranking: 20

# %% [markdown]
# ### Local PM Headlines Spanish

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Local_PM_Headlines_Spanish_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 45
# Respondents Familiar with Show: 13
# Percent Familiar with Show: 28.9%
# Median: 7
# Mean: 6.69
# Overall Ranking: 44
# News-Show Ranking: 25

# %% [markdown]
# ### Making Contact

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Making_Contact_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 45
# Respondents Familiar with Show: 16
# Percent Familiar with Show: 35.6%
# Median: 7
# Mean: 6.94
# Overall Ranking: 27
# News-Show Ranking: 11

# %% [markdown]
# ### Metro

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Metro_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 14
# Percent Familiar with Show: 30.4%
# Median: 7
# Mean: 7.00
# Overall Ranking: 36
# News-Show Ranking: 19

# %% [markdown]
# ### Metro Arts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Metro_Arts_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 45
# Respondents Familiar with Show: 11
# Percent Familiar with Show: 24.4%
# Median: 7
# Mean: 7.09
# Overall Ranking: 47
# News-Show Ranking: 28

# %% [markdown]
# ### Morning Magazine

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Morning_Magazine_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 44
# Respondents Familiar with Show: 16
# Percent Familiar with Show: 36.4%
# Median: 7
# Mean: 6.69
# Overall Ranking: 30
# News-Show Ranking: 14

# %% [markdown]
# ### Naturally

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Naturally_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 45
# Respondents Familiar with Show: 12
# Percent Familiar with Show: 26.7%
# Median: 7
# Mean: 6.92
# Overall Ranking: 45
# News-Show Ranking: 26

# %% [markdown]
# ### New Dimensions

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'New_Dimensions_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 45
# Respondents Familiar with Show: 16
# Percent Familiar with Show: 35.6%
# Median: 7
# Mean: 6.81
# Overall Ranking: 29
# News-Show Ranking: 13

# %% [markdown]
# ### Outsources

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Outsources_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 14
# Percent Familiar with Show: 30.4%
# Median: 8
# Mean: 7.29
# Overall Ranking: 34
# News-Show Ranking: 17

# %% [markdown]
# ### Pasa La Voz

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Pasa_La_Voz_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 45
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 8.9%
# Median: 7
# Mean: 7.75
# Overall Ranking: 58
# News-Show Ranking: 38

# %% [markdown]
# ### Peace Talks

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Peace_Talks_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 45
# Respondents Familiar with Show: 11
# Percent Familiar with Show: 24.4%
# Median: 7
# Mean: 5.91
# Overall Ranking: 53
# News-Show Ranking: 33

# %% [markdown]
# ### Project Censored

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Project_Censored_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 12
# Percent Familiar with Show: 26.1%
# Median: 8
# Mean: 7.67
# Overall Ranking: 42
# News-Show Ranking: 24

# %% [markdown]
# ### Rising Up with Sonali

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Rising_Up_with_Sonali_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 13
# Percent Familiar with Show: 27.7%
# Median: 8
# Mean: 7.15
# Overall Ranking: 41
# News-Show Ranking: 23

# %% [markdown]
# ### Sprouts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Sprouts_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 15
# Percent Familiar with Show: 32.6%
# Median: 5
# Mean: 5.80
# Overall Ranking: 44
# News-Show Ranking: 25

# %% [markdown]
# ### StoryTellers of Color

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'StoryTellers_of_Color_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 11
# Percent Familiar with Show: 23.9%
# Median: 8
# Mean: 6.82
# Overall Ranking: 49
# News-Show Ranking: 30

# %% [markdown]
# ### Laura Flanders

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Laura_Flanders_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 17
# Percent Familiar with Show: 36.2%
# Median: 6
# Mean: 6.18
# Overall Ranking: 31
# News-Show Ranking: 15

# %% [markdown]
# ### Ralph Nader

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Ralph_Nader_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 23
# Percent Familiar with Show: 50.0%
# Median: 6
# Mean: 5.96
# Overall Ranking: 12
# News-Show Ranking: 5

# %% [markdown]
# ### Shortwave Report

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Shortwave_Report_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 17
# Percent Familiar with Show: 36.2%
# Median: 6
# Mean: 6.47
# Overall Ranking: 28
# News-Show Ranking: 12

# %% [markdown]
# ### The World

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_World_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 17
# Percent Familiar with Show: 37.0%
# Median: 7
# Mean: 6.71
# Overall Ranking: 25
# News-Show Ranking: 10

# %% [markdown]
# ### TRENDS

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'TRENDS_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 9
# Percent Familiar with Show: 19.1%
# Median: 7
# Mean: 7.00
# Overall Ranking: 54
# News-Show Ranking: 34

# %% [markdown]
# ### Tributaries

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Tributaries_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 14
# Percent Familiar with Show: 29.8%
# Median: 7
# Mean: 6.86
# Overall Ranking: 38
# News-Show Ranking: 21

# %% [markdown]
# ### TUC Radio

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'TUC_Radio_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 14
# Percent Familiar with Show: 30.4%
# Median: 8
# Mean: 7.43
# Overall Ranking: 32
# News-Show Ranking: 16

# %% [markdown]
# ### WINGS

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'WINGS_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 46
# Respondents Familiar with Show: 15
# Percent Familiar with Show: 32.6%
# Median: 7
# Mean: 6.60
# Overall Ranking: 35
# News-Show Ranking: 18

# %% [markdown]
# ### Weed Between

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Weed_between_Ratings')
# Out:
# Filter: Ages 46 - 65
# Total Respondents: 47
# Respondents Familiar with Show: 11
# Percent Familiar with Show: 23.4%
# Median: 8
# Mean: 6.73
# Overall Ranking: 50
# News-Show Ranking: 31
