# %% [markdown]
# # Ages 31 - 45 - Random

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import MaxNLocator
from IPython.display import display, Markdown
from functions import *

# %%
df = pd.read_excel('Client Data English-07.15.22.xlsx', sheet_name='English')

# %%
show_ratings_cols = df.columns.tolist()[111:191]
#show_ratings_cols

# %%
filter_col = 'Age'
filter_col_val = 3
filter_col_val_display = 'Filter: Ages 31 - 45'

# %% [markdown]
# ## Show Rankings

# %%
create_ranked_table_of_shows(df, True, filter_col, filter_col_val, filter_col_val_display)
# Out:
# Overall      Show               #Ratings/    Median/Mean  Score   Music   News
# Ranking                        #Respondents                       Show    Show
#                                                                  Ranking Ranking
# --------------------------------------------------------------------------------
#  1    ASA                            9/12        8/7.4      67      1
#  2    Blues Legacy                   9/12        7/6.9      62      2
#  3    BBC News Hour                  8/10        7/7.0      56              1
#  4    Corriente                      8/11        7/6.9      55      3
#  4    Dusty Grooves                  8/12        7/6.9      55      3
#  5    African Roots                  7/12        7/6.9      48      4
#  5    Kaberet                        8/11        6/6.0      48      4
#  6    Roots and Branches             7/11        7/6.7      47      5
#  7    Dub Palace                     6/11        8/7.3      44      6
#  8    The Opera Box                  7/10        7/6.0      42      7
#  8    MSA                            7/11        6/6.0      42      7
#  9    Soundlab                       6/10        6/6.8      41      8
# 10    HWY 322                        6/11        7/6.7      40      9
# 11    BBC The Newsroom               6/10        7/6.5      39              2
# 12    Grateful Dead                  7/12        6/5.4      38     10
# 12    Democracy Now                   5/9        7/7.6      38              3
# 12    Ragtime America                8/10        4/4.8      38     10
# 12    A Classic Monday               6/11        6/6.3      38     10
# 13    HTH                            7/12        7/5.3      37     11
# 14    Jazz Lives                     6/11        7/6.0      36     12
# 14    Jim Hightower                  6/10        6/6.0      36              4
# 15    E Town                         8/12        3/4.4      35     13
# 15    OGGG                           6/11        6/5.8      35     13
# 16    Reggae Bloodlines              4/11        8/8.5      34     14
# 16    Reggae Transfusions            4/10        8/8.5      34     14
# 17    Local PM Headlines Spanish      4/8        8/8.2      33              5
# 18    La Lucha Sigue                  4/7        8/8.0      32              6
# 19    Bioneers                        4/8        7/7.5      30              7
# 19    Alternative Radio               4/8        7/7.5      30              7
# 20    Sleepless Nights               4/10        7/7.2      29     15
# 20    Eclipse                        4/11        7/7.2      29     15
# 20    Connections                     5/9        5/5.8      29              8
# 21    The World                       4/9        7/7.0      28              9
# 22    Laura Flanders                  4/8        8/6.8      27             10
# 22    Rising Up with Sonali           4/9        7/6.8      27             10
# 23    Ralph Nader                     5/9        5/5.2      26             11
# 23    Restless Mornings              4/10        6/6.5      26     16
# 23    Under the Floorboards          4/10        7/6.5      26     16
# 23    Electronic Air                 4/12        6/6.5      26     16
# 24    Morning Magazine                3/8        9/8.3      25             12
# 25    Smash It Back                  4/10        6/6.0      24     17
# 25    Musica Mundi                   3/10        8/8.0      24     17
# 25    A Public Affair                 4/9        6/6.0      24             13
# 26    TRENDS                          3/8        9/7.7      23             14
# 26    Pasa La Voz                     3/7        9/7.7      23             14
# 26    Metro Arts                      3/7        7/7.7      23             14
# 26    Swing Shift                    4/10        7/5.8      23     18
# 26    Seolta Gael                    5/10        3/4.6      23     18
# 27    Project Censored                3/7        7/7.0      21             15
# 27    Economic Update                 3/8        7/7.0      21             15
# 27    Making Contact                  3/7        7/7.0      21             15
# 27    Labor Exchange                  3/7        7/7.0      21             15
# 28    Tributaries                     4/8        5/5.0      20             16
# 28    Outsources                      3/7        6/6.7      20             16
# 28    The Heavy Set                  3/10        7/6.7      20     19
# 29    Living Dialogues                3/7        7/6.3      19             17
# 29    Between the Lines               3/8        7/6.3      19             17
# 29    Alan Watts                      3/9        7/6.3      19             17
# 29    Gospel Chime                   4/12        4/4.8      19     20
# 30    Naturally                       3/8        5/6.0      18             18
# 30    Counterspin                     3/9        6/6.0      18             18
# 31    Present Edge                   4/10        3/4.2      17     21
# 32    Col Chinese Radio Network       3/9        6/5.3      16             19
# 32    Terrasonic                     2/11        8/8.0      16     22
# 33    StoryTellers of Color           2/8        7/7.5      15             20
# 34    Weed between                    2/9        7/7.0      14             21
# 34    Metro                           2/7        7/7.0      14             21
# 34    TUC Radio                       3/8        6/4.7      14             21
# 34    Roots of Jazz                   3/9        5/4.7      14     23
# 34    Sprouts                         2/8        7/7.0      14             21
# 35    Peace Talks                     2/7        6/6.5      13             22
# 36    Linea Abierta                   2/7        6/6.0      12             23
# 36    How on Earth                    2/9        6/6.0      12             23
# 36    Indian Voices                   2/8        6/6.0      12             23
# 37    Shortwave Report                2/9        5/5.5      11             24
# 38    Its The Economy                 2/8        5/5.0      10             25
# 38    New Dimensions                  2/8        5/5.0      10             25
# 39    WINGS                           1/8        7/7.0       7             26
# 40    Hemispheres                     1/9        5/5.0       5             27
# 41    Black Talk                      0/9        0/0.0       0             28

# %% [markdown]
# ## Music Shows

# %% [markdown]
# ### A Classic Monday

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'A_Classic_Monday_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 11
# Respondents Familiar with Show: 6
# Percent Familiar with Show: 54.5%
# Median: 6
# Mean: 6.33
# Overall Ranking: 12
# Music-Show Ranking: 10

# %% [markdown]
# ### African Roots

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'African_Roots_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 12
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 58.3%
# Median: 7
# Mean: 6.86
# Overall Ranking: 5
# Music-Show Ranking: 4

# %% [markdown]
# ### Afternoon Sound Alternative

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'ASA_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 12
# Respondents Familiar with Show: 9
# Percent Familiar with Show: 75.0%
# Median: 8
# Mean: 7.44
# Overall Ranking: 1
# Music-Show Ranking: 1

# %% [markdown]
# ### Blues Legacy

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Blues_Legacy_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 12
# Respondents Familiar with Show: 9
# Percent Familiar with Show: 75.0%
# Median: 7
# Mean: 6.89
# Overall Ranking: 2
# Music-Show Ranking: 2

# %% [markdown]
# ### Corriente

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Corriente_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 11
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 72.7%
# Median: 7
# Mean: 6.88
# Overall Ranking: 4
# Music-Show Ranking: 3

# %% [markdown]
# ### Dub Palace

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Dub_Palace_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 11
# Respondents Familiar with Show: 6
# Percent Familiar with Show: 54.5%
# Median: 8
# Mean: 7.33
# Overall Ranking: 7
# Music-Show Ranking: 6

# %% [markdown]
# ### Dusty Grooves

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Dusty_Grooves_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 12
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 66.7%
# Median: 7
# Mean: 6.88
# Overall Ranking: 4
# Music-Show Ranking: 3

# %% [markdown]
# ### Eclipse

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Eclipse_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 11
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 36.4%
# Median: 7
# Mean: 7.25
# Overall Ranking: 20
# Music-Show Ranking: 15

# %% [markdown]
# ### Electronic Air

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Electronic_Air_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 12
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 33.3%
# Median: 6
# Mean: 6.50
# Overall Ranking: 23
# Music-Show Ranking: 16

# %% [markdown]
# ### eTown

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'E_Town_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 12
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 66.7%
# Median: 3
# Mean: 4.38
# Overall Ranking: 15
# Music-Show Ranking: 13

# %% [markdown]
# ### Gospel Chime

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Gospel_Chime_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 12
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 33.3%
# Median: 4
# Mean: 4.75
# Overall Ranking: 29
# Music-Show Ranking: 20

# %% [markdown]
# ### Grateful Dead

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Grateful_Dead_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 12
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 58.3%
# Median: 6
# Mean: 5.43
# Overall Ranking: 12
# Music-Show Ranking: 10

# %% [markdown]
# ### Hwy 322

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'HWY_322_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 11
# Respondents Familiar with Show: 6
# Percent Familiar with Show: 54.5%
# Median: 7
# Mean: 6.67
# Overall Ranking: 10
# Music-Show Ranking: 9

# %% [markdown]
# ### Honky Tonk Heroes

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'HTH_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 12
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 58.3%
# Median: 7
# Mean: 5.29
# Overall Ranking: 13
# Music-Show Ranking: 11

# %% [markdown]
# ### Jazz Lives

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Jazz_Lives_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 11
# Respondents Familiar with Show: 6
# Percent Familiar with Show: 54.5%
# Median: 7
# Mean: 6.00
# Overall Ranking: 14
# Music-Show Ranking: 12

# %% [markdown]
# ### Kaberet

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Kaberet_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 11
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 72.7%
# Median: 6
# Mean: 6.00
# Overall Ranking: 5
# Music-Show Ranking: 4

# %% [markdown]
# ### Morning Sound Alternative

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'MSA_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 11
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 63.6%
# Median: 6
# Mean: 6.00
# Overall Ranking: 8
# Music-Show Ranking: 7

# %% [markdown]
# ### Musica Mundi

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Musica_Mundi_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 10
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 30.0%
# Median: 8
# Mean: 8.00
# Overall Ranking: 25
# Music-Show Ranking: 17

# %% [markdown]
# ### Old Grass Gnu Grass

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'OGGG_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 11
# Respondents Familiar with Show: 6
# Percent Familiar with Show: 54.5%
# Median: 6
# Mean: 5.83
# Overall Ranking: 15
# Music-Show Ranking: 13

# %% [markdown]
# ### The Present Edge

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Present_Edge_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 10
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 40.0%
# Median: 3
# Mean: 4.25
# Overall Ranking: 31
# Music-Show Ranking: 21

# %% [markdown]
# ### Ragtime America

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Ragtime_America_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 10
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 80.0%
# Median: 4
# Mean: 4.75
# Overall Ranking: 12
# Music-Show Ranking: 10

# %% [markdown]
# ### Reggae Bloodlines

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Reggae_Bloodlines_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 11
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 36.4%
# Median: 8
# Mean: 8.50
# Overall Ranking: 16
# Music-Show Ranking: 14

# %% [markdown]
# ### Reggae Transfusions

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Reggae_Transfusions_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 10
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 40.0%
# Median: 8
# Mean: 8.50
# Overall Ranking: 16
# Music-Show Ranking: 14

# %% [markdown]
# ### Restless Mornings

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Restless_Mornings_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 10
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 40.0%
# Median: 6
# Mean: 6.50
# Overall Ranking: 23
# Music-Show Ranking: 16

# %% [markdown]
# ### Roots and Branches

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Roots_and_Branches_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 11
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 63.6%
# Median: 7
# Mean: 6.71
# Overall Ranking: 6
# Music-Show Ranking: 5

# %% [markdown]
# ### Roots of Jazz

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Roots_of_Jazz_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 9
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 33.3%
# Median: 5
# Mean: 4.67
# Overall Ranking: 34
# Music-Show Ranking: 23

# %% [markdown]
# ### Seolta Gael

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Seolta_Gael_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 10
# Respondents Familiar with Show: 5
# Percent Familiar with Show: 50.0%
# Median: 3
# Mean: 4.60
# Overall Ranking: 26
# Music-Show Ranking: 18

# %% [markdown]
# ### Sleepless Nights

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Sleepless_Nights_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 10
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 40.0%
# Median: 7
# Mean: 7.25
# Overall Ranking: 20
# Music-Show Ranking: 15

# %% [markdown]
# ### Smash It Back

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Smash_It_Back_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 10
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 40.0%
# Median: 6
# Mean: 6.00
# Overall Ranking: 25
# Music-Show Ranking: 17

# %% [markdown]
# ### SoundLab

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Soundlab_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 10
# Respondents Familiar with Show: 6
# Percent Familiar with Show: 60.0%
# Median: 6
# Mean: 6.83
# Overall Ranking: 9
# Music-Show Ranking: 8

# %% [markdown]
# ### Swing Shift

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Swing_Shift_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 10
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 40.0%
# Median: 7
# Mean: 5.75
# Overall Ranking: 26
# Music-Show Ranking: 18

# %% [markdown]
# ### Terrasonic

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Terrasonic_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 11
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 18.2%
# Median: 8
# Mean: 8.00
# Overall Ranking: 32
# Music-Show Ranking: 22

# %% [markdown]
# ### The Heavy Set

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_Heavy_Set_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 10
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 30.0%
# Median: 7
# Mean: 6.67
# Overall Ranking: 28
# Music-Show Ranking: 19

# %% [markdown]
# ### The Opera Box

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_Opera_Box_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 10
# Respondents Familiar with Show: 7
# Percent Familiar with Show: 70.0%
# Median: 7
# Mean: 6.00
# Overall Ranking: 8
# Music-Show Ranking: 7

# %% [markdown]
# ### Under the Floorboards

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Under_the_Floorboards_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 10
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 40.0%
# Median: 7
# Mean: 6.50
# Overall Ranking: 23
# Music-Show Ranking: 16

# %% [markdown]
# ## News Shows

# %% [markdown]
# ### A Public Affairs

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'A_Public_Affair_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 9
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 44.4%
# Median: 6
# Mean: 6.00
# Overall Ranking: 25
# News-Show Ranking: 13

# %% [markdown]
# ### Alan Watts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Alan_Watts_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 9
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 33.3%
# Median: 7
# Mean: 6.33
# Overall Ranking: 29
# News-Show Ranking: 17

# %% [markdown]
# ### Alternative Radio

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Alternative_Radio_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 8
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 50.0%
# Median: 7
# Mean: 7.50
# Overall Ranking: 19
# News-Show Ranking: 7

# %% [markdown]
# ### BBC News Hour

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'BBC_News_Hour_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 10
# Respondents Familiar with Show: 8
# Percent Familiar with Show: 80.0%
# Median: 7
# Mean: 7.00
# Overall Ranking: 3
# News-Show Ranking: 1

# %% [markdown]
# ### BBC The Newsroom

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'BBC_The_Newsroom_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 10
# Respondents Familiar with Show: 6
# Percent Familiar with Show: 60.0%
# Median: 7
# Mean: 6.50
# Overall Ranking: 11
# News-Show Ranking: 2

# %% [markdown]
# ### Between the Lines

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Between_the_Lines_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 8
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 37.5%
# Median: 7
# Mean: 6.33
# Overall Ranking: 29
# News-Show Ranking: 17

# %% [markdown]
# ### Bioneers

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Bioneers_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 8
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 50.0%
# Median: 7
# Mean: 7.50
# Overall Ranking: 19
# News-Show Ranking: 7

# %% [markdown]
# ### Black Talk

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Black_Talk_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 9
# Respondents Familiar with Show: 0
# Percent Familiar with Show: 0.0%

# %% [markdown]
# ### Colorado Chinese Radio Network

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Col_Chinese_Radio_Network_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 9
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 33.3%
# Median: 6
# Mean: 5.33
# Overall Ranking: 32
# News-Show Ranking: 19

# %% [markdown]
# ### Connections

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Connections_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 9
# Respondents Familiar with Show: 5
# Percent Familiar with Show: 55.6%
# Median: 5
# Mean: 5.80
# Overall Ranking: 20
# News-Show Ranking: 8

# %% [markdown]
# ### Counterspin

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Counterspin_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 9
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 33.3%
# Median: 6
# Mean: 6.00
# Overall Ranking: 30
# News-Show Ranking: 18

# %% [markdown]
# ### Democracy Now

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Democracy_Now_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 9
# Respondents Familiar with Show: 5
# Percent Familiar with Show: 55.6%
# Median: 7
# Mean: 7.60
# Overall Ranking: 12
# News-Show Ranking: 3

# %% [markdown]
# ### Economic Update

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Economic_Update_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 8
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 37.5%
# Median: 7
# Mean: 7.00
# Overall Ranking: 27
# News-Show Ranking: 15

# %% [markdown]
# ### Hemispheres

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Hemispheres_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 9
# Respondents Familiar with Show: 1
# Percent Familiar with Show: 11.1%
# Median: 5
# Mean: 5.00
# Overall Ranking: 40
# News-Show Ranking: 27

# %% [markdown]
# ### How on Earth

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'How_on_Earth_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 9
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 22.2%
# Median: 6
# Mean: 6.00
# Overall Ranking: 36
# News-Show Ranking: 23

# %% [markdown]
# ### Indian Voices

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Indian_Voices_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 8
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 25.0%
# Median: 6
# Mean: 6.00
# Overall Ranking: 36
# News-Show Ranking: 23

# %% [markdown]
# ### It's the Economy

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Its_The_Economy_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 8
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 25.0%
# Median: 5
# Mean: 5.00
# Overall Ranking: 38
# News-Show Ranking: 25

# %% [markdown]
# ### Jim Hightower

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Jim_Hightower_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 10
# Respondents Familiar with Show: 6
# Percent Familiar with Show: 60.0%
# Median: 6
# Mean: 6.00
# Overall Ranking: 14
# News-Show Ranking: 4

# %% [markdown]
# ### La Lucha Sigue

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'La_Lucha_Sigue_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 7
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 57.1%
# Median: 8
# Mean: 8.00
# Overall Ranking: 18
# News-Show Ranking: 6

# %% [markdown]
# ### Labor Exchange

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Labor_Exchange_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 7
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 42.9%
# Median: 7
# Mean: 7.00
# Overall Ranking: 27
# News-Show Ranking: 15

# %% [markdown]
# ### Linea Abierta

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Linea_Abierta_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 7
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 28.6%
# Median: 6
# Mean: 6.00
# Overall Ranking: 36
# News-Show Ranking: 23

# %% [markdown]
# ### Living Dialogues

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Living_Dialogues_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 7
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 42.9%
# Median: 7
# Mean: 6.33
# Overall Ranking: 29
# News-Show Ranking: 17

# %% [markdown]
# ### Local PM Headlines Spanish

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Local_PM_Headlines_Spanish_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 8
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 50.0%
# Median: 8
# Mean: 8.25
# Overall Ranking: 17
# News-Show Ranking: 5

# %% [markdown]
# ### Making Contact

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Making_Contact_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 7
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 42.9%
# Median: 7
# Mean: 7.00
# Overall Ranking: 27
# News-Show Ranking: 15

# %% [markdown]
# ### Metro

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Metro_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 7
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 28.6%
# Median: 7
# Mean: 7.00
# Overall Ranking: 34
# News-Show Ranking: 21

# %% [markdown]
# ### Metro Arts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Metro_Arts_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 7
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 42.9%
# Median: 7
# Mean: 7.67
# Overall Ranking: 26
# News-Show Ranking: 14

# %% [markdown]
# ### Morning Magazine

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Morning_Magazine_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 8
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 37.5%
# Median: 9
# Mean: 8.33
# Overall Ranking: 24
# News-Show Ranking: 12

# %% [markdown]
# ### Naturally

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Naturally_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 8
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 37.5%
# Median: 5
# Mean: 6.00
# Overall Ranking: 30
# News-Show Ranking: 18

# %% [markdown]
# ### New Dimensions

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'New_Dimensions_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 8
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 25.0%
# Median: 5
# Mean: 5.00
# Overall Ranking: 38
# News-Show Ranking: 25

# %% [markdown]
# ### Outsources

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Outsources_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 7
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 42.9%
# Median: 6
# Mean: 6.67
# Overall Ranking: 28
# News-Show Ranking: 16

# %% [markdown]
# ### Pasa La Voz

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Pasa_La_Voz_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 7
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 42.9%
# Median: 9
# Mean: 7.67
# Overall Ranking: 26
# News-Show Ranking: 14

# %% [markdown]
# ### Peace Talks

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Peace_Talks_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 7
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 28.6%
# Median: 6
# Mean: 6.50
# Overall Ranking: 35
# News-Show Ranking: 22

# %% [markdown]
# ### Project Censored

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Project_Censored_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 7
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 42.9%
# Median: 7
# Mean: 7.00
# Overall Ranking: 27
# News-Show Ranking: 15

# %% [markdown]
# ### Rising Up with Sonali

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Rising_Up_with_Sonali_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 9
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 44.4%
# Median: 7
# Mean: 6.75
# Overall Ranking: 22
# News-Show Ranking: 10

# %% [markdown]
# ### Sprouts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Sprouts_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 8
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 25.0%
# Median: 7
# Mean: 7.00
# Overall Ranking: 34
# News-Show Ranking: 21

# %% [markdown]
# ### StoryTellers of Color

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'StoryTellers_of_Color_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 8
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 25.0%
# Median: 7
# Mean: 7.50
# Overall Ranking: 33
# News-Show Ranking: 20

# %% [markdown]
# ### Laura Flanders

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Laura_Flanders_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 8
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 50.0%
# Median: 8
# Mean: 6.75
# Overall Ranking: 22
# News-Show Ranking: 10

# %% [markdown]
# ### Ralph Nader

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Ralph_Nader_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 9
# Respondents Familiar with Show: 5
# Percent Familiar with Show: 55.6%
# Median: 5
# Mean: 5.20
# Overall Ranking: 23
# News-Show Ranking: 11

# %% [markdown]
# ### Shortwave Report

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Shortwave_Report_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 9
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 22.2%
# Median: 5
# Mean: 5.50
# Overall Ranking: 37
# News-Show Ranking: 24

# %% [markdown]
# ### The World

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_World_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 9
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 44.4%
# Median: 7
# Mean: 7.00
# Overall Ranking: 21
# News-Show Ranking: 9

# %% [markdown]
# ### TRENDS

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'TRENDS_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 8
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 37.5%
# Median: 9
# Mean: 7.67
# Overall Ranking: 26
# News-Show Ranking: 14

# %% [markdown]
# ### Tributaries

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Tributaries_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 8
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 50.0%
# Median: 5
# Mean: 5.00
# Overall Ranking: 28
# News-Show Ranking: 16

# %% [markdown]
# ### TUC Radio

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'TUC_Radio_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 8
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 37.5%
# Median: 6
# Mean: 4.67
# Overall Ranking: 34
# News-Show Ranking: 21

# %% [markdown]
# ### WINGS

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'WINGS_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 8
# Respondents Familiar with Show: 1
# Percent Familiar with Show: 12.5%
# Median: 7
# Mean: 7.00
# Overall Ranking: 39
# News-Show Ranking: 26

# %% [markdown]
# ### Weed Between

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Weed_between_Ratings')
# Out:
# Filter: Ages 31 - 45
# Total Respondents: 9
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 22.2%
# Median: 7
# Mean: 7.00
# Overall Ranking: 34
# News-Show Ranking: 21
