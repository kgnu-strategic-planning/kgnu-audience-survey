# %% [markdown]
# # Prefer to self identify - Random

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import MaxNLocator
from IPython.display import display, Markdown
from functions import *

# %%
df = pd.read_excel('Client Data English-07.15.22.xlsx', sheet_name='English')

# %%
show_ratings_cols = df.columns.tolist()[111:191]
#show_ratings_cols

# %%
filter_col = 'You_Are'
filter_col_val = 'Prefer to self identify:'
filter_col_val_display = 'Filter: Prefer to self identify'

# %% [markdown]
# ## Show Rankings

# %%
create_ranked_table_of_shows(df, True, filter_col, filter_col_val, filter_col_val_display)
# Out:
# Overall      Show               #Ratings/    Median/Mean  Score   Music   News
# Ranking                        #Respondents                       Show    Show
#                                                                  Ranking Ranking
# --------------------------------------------------------------------------------
#  1    Economic Update                 3/7        9/9.0      27              1
#  2    Sprouts                         5/6        5/4.6      23              2
#  3    Morning Magazine                3/6        7/7.0      21              3
#  3    New Dimensions                  4/8        5/5.2      21              3
#  3    Living Dialogues                3/7        7/7.0      21              3
#  4    Its The Economy                 3/7        7/6.7      20              4
#  5    Counterspin                     4/7        5/4.8      19              5
#  6    E Town                          4/8        4/4.2      17      1
#  6    Metro                           3/7        7/5.7      17              6
#  7    Laura Flanders                  3/6        5/5.3      16              7
#  7    WINGS                           3/7        5/5.3      16              7
#  7    HTH                             3/8        5/5.3      16      2
#  7    Musica Mundi                    2/7        8/8.0      16      2
#  8    Indian Voices                   2/7        7/7.5      15              8
#  8    Metro Arts                      3/7        5/5.0      15              8
#  8    Blues Legacy                    4/8        3/3.8      15      3
#  8    Connections                     3/7        5/5.0      15              8
#  8    Black Talk                      3/7        5/5.0      15              8
#  8    MSA                             2/8        7/7.5      15      3
#  8    Under the Floorboards           3/7        6/5.0      15      3
#  8    Bioneers                        3/7        3/5.0      15              8
#  9    Ralph Nader                     2/6        7/7.0      14              9
#  9    Democracy Now                   2/7        7/7.0      14              9
#  9    HWY 322                         3/8        5/4.7      14      4
#  9    Grateful Dead                   4/8        3/3.5      14      4
#  9    Swing Shift                     3/7        4/4.7      14      4
# 10    BBC News Hour                   2/7        6/6.5      13             10
# 10    Alternative Radio               3/7        5/4.3      13             10
# 10    A Public Affair                 3/7        5/4.3      13             10
# 10    Smash It Back                   2/7        6/6.5      13      5
# 10    Electronic Air                  3/8        5/4.3      13      5
# 11    African Roots                   3/8        3/4.0      12      6
# 11    Roots and Branches              2/7        6/6.0      12      6
# 11    Hemispheres                     2/7        6/6.0      12             11
# 11    Project Censored                2/7        6/6.0      12             11
# 11    Ragtime America                 3/7        3/4.0      12      6
# 11    OGGG                            2/7        6/6.0      12      6
# 11    Shortwave Report                2/7        6/6.0      12             11
# 11    Dusty Grooves                   3/8        3/4.0      12      6
# 11    TUC Radio                       2/6        6/6.0      12             11
# 12    Making Contact                  3/6        2/3.7      11             12
# 12    Jazz Lives                      3/8        3/3.7      11      7
# 12    The World                       2/6        5/5.5      11             12
# 13    Local PM Headlines Spanish      3/6        3/3.3      10             13
# 13    Outsources                      3/7        3/3.3      10             13
# 13    Rising Up with Sonali           2/7        5/5.0      10             13
# 13    Tributaries                     2/7        5/5.0      10             13
# 13    Between the Lines               2/7        5/5.0      10             13
# 13    Weed between                    2/7        5/5.0      10             13
# 13    Reggae Bloodlines               2/7        5/5.0      10      8
# 14    Seolta Gael                     3/7        3/3.0       9      9
# 14    Peace Talks                     2/6        4/4.5       9             14
# 14    Jim Hightower                   1/7        9/9.0       9             14
# 14    Labor Exchange                  2/7        4/4.5       9             14
# 14    Corriente                       2/8        4/4.5       9      9
# 15    The Heavy Set                   3/7        3/2.7       8     10
# 15    Restless Mornings               1/7        8/8.0       8     10
# 16    Reggae Transfusions             2/7        3/3.5       7     11
# 16    Dub Palace                      3/8        2/2.3       7     11
# 16    La Lucha Sigue                  1/7        7/7.0       7             15
# 16    Roots of Jazz                   2/7        3/3.5       7     11
# 17    TRENDS                          1/7        6/6.0       6             16
# 17    Terrasonic                      1/6        6/6.0       6     12
# 17    Sleepless Nights                1/7        6/6.0       6     12
# 17    Naturally                       2/7        3/3.0       6             16
# 17    Col Chinese Radio Network       2/7        3/3.0       6             16
# 18    Kaberet                         1/8        5/5.0       5     13
# 18    ASA                             1/8        5/5.0       5     13
# 18    How on Earth                    1/7        5/5.0       5             17
# 18    Pasa La Voz                     2/7        2/2.5       5             17
# 18    Soundlab                        1/7        5/5.0       5     13
# 19    Eclipse                         2/8        2/2.0       4     14
# 20    StoryTellers of Color           1/6        3/3.0       3             18
# 21    Present Edge                    1/7        2/2.0       2     15
# 21    Gospel Chime                    1/8        2/2.0       2     15
# 21    The Opera Box                   1/7        2/2.0       2     15
# 21    Linea Abierta                   1/6        2/2.0       2             19
# 21    A Classic Monday                1/8        2/2.0       2     15
# 22    Alan Watts                      0/7        0/0.0       0             20
# 22    BBC The Newsroom                0/7        0/0.0       0             20

# %% [markdown]
# ## Music Shows

# %% [markdown]
# ### A Classic Monday

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'A_Classic_Monday_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 8
# Respondents Familiar with Show: 1
# Percent Familiar with Show: 12.5%
# Median: 2
# Mean: 2.00
# Overall Ranking: 21
# Music-Show Ranking: 15

# %% [markdown]
# ### African Roots

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'African_Roots_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 8
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 37.5%
# Median: 3
# Mean: 4.00
# Overall Ranking: 11
# Music-Show Ranking: 6

# %% [markdown]
# ### Afternoon Sound Alternative

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'ASA_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 8
# Respondents Familiar with Show: 1
# Percent Familiar with Show: 12.5%
# Median: 5
# Mean: 5.00
# Overall Ranking: 18
# Music-Show Ranking: 13

# %% [markdown]
# ### Blues Legacy

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Blues_Legacy_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 8
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 50.0%
# Median: 3
# Mean: 3.75
# Overall Ranking: 8
# Music-Show Ranking: 3

# %% [markdown]
# ### Corriente

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Corriente_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 8
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 25.0%
# Median: 4
# Mean: 4.50
# Overall Ranking: 14
# Music-Show Ranking: 9

# %% [markdown]
# ### Dub Palace

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Dub_Palace_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 8
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 37.5%
# Median: 2
# Mean: 2.33
# Overall Ranking: 16
# Music-Show Ranking: 11

# %% [markdown]
# ### Dusty Grooves

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Dusty_Grooves_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 8
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 37.5%
# Median: 3
# Mean: 4.00
# Overall Ranking: 11
# Music-Show Ranking: 6

# %% [markdown]
# ### Eclipse

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Eclipse_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 8
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 25.0%
# Median: 2
# Mean: 2.00
# Overall Ranking: 19
# Music-Show Ranking: 14

# %% [markdown]
# ### Electronic Air

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Electronic_Air_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 8
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 37.5%
# Median: 5
# Mean: 4.33
# Overall Ranking: 10
# Music-Show Ranking: 5

# %% [markdown]
# ### eTown

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'E_Town_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 8
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 50.0%
# Median: 4
# Mean: 4.25
# Overall Ranking: 6
# Music-Show Ranking: 1

# %% [markdown]
# ### Gospel Chime

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Gospel_Chime_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 8
# Respondents Familiar with Show: 1
# Percent Familiar with Show: 12.5%
# Median: 2
# Mean: 2.00
# Overall Ranking: 21
# Music-Show Ranking: 15

# %% [markdown]
# ### Grateful Dead

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Grateful_Dead_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 8
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 50.0%
# Median: 3
# Mean: 3.50
# Overall Ranking: 9
# Music-Show Ranking: 4

# %% [markdown]
# ### Hwy 322

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'HWY_322_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 8
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 37.5%
# Median: 5
# Mean: 4.67
# Overall Ranking: 9
# Music-Show Ranking: 4

# %% [markdown]
# ### Honky Tonk Heroes

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'HTH_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 8
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 37.5%
# Median: 5
# Mean: 5.33
# Overall Ranking: 7
# Music-Show Ranking: 2

# %% [markdown]
# ### Jazz Lives

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Jazz_Lives_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 8
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 37.5%
# Median: 3
# Mean: 3.67
# Overall Ranking: 12
# Music-Show Ranking: 7

# %% [markdown]
# ### Kaberet

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Kaberet_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 8
# Respondents Familiar with Show: 1
# Percent Familiar with Show: 12.5%
# Median: 5
# Mean: 5.00
# Overall Ranking: 18
# Music-Show Ranking: 13

# %% [markdown]
# ### Morning Sound Alternative

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'MSA_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 8
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 25.0%
# Median: 7
# Mean: 7.50
# Overall Ranking: 8
# Music-Show Ranking: 3

# %% [markdown]
# ### Musica Mundi

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Musica_Mundi_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 28.6%
# Median: 8
# Mean: 8.00
# Overall Ranking: 7
# Music-Show Ranking: 2

# %% [markdown]
# ### Old Grass Gnu Grass

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'OGGG_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 28.6%
# Median: 6
# Mean: 6.00
# Overall Ranking: 11
# Music-Show Ranking: 6

# %% [markdown]
# ### The Present Edge

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Present_Edge_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 1
# Percent Familiar with Show: 14.3%
# Median: 2
# Mean: 2.00
# Overall Ranking: 21
# Music-Show Ranking: 15

# %% [markdown]
# ### Ragtime America

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Ragtime_America_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 42.9%
# Median: 3
# Mean: 4.00
# Overall Ranking: 11
# Music-Show Ranking: 6

# %% [markdown]
# ### Reggae Bloodlines

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Reggae_Bloodlines_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 28.6%
# Median: 5
# Mean: 5.00
# Overall Ranking: 13
# Music-Show Ranking: 8

# %% [markdown]
# ### Reggae Transfusions

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Reggae_Transfusions_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 28.6%
# Median: 3
# Mean: 3.50
# Overall Ranking: 16
# Music-Show Ranking: 11

# %% [markdown]
# ### Restless Mornings

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Restless_Mornings_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 1
# Percent Familiar with Show: 14.3%
# Median: 8
# Mean: 8.00
# Overall Ranking: 15
# Music-Show Ranking: 10

# %% [markdown]
# ### Roots and Branches

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Roots_and_Branches_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 28.6%
# Median: 6
# Mean: 6.00
# Overall Ranking: 11
# Music-Show Ranking: 6

# %% [markdown]
# ### Roots of Jazz

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Roots_of_Jazz_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 28.6%
# Median: 3
# Mean: 3.50
# Overall Ranking: 16
# Music-Show Ranking: 11

# %% [markdown]
# ### Seolta Gael

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Seolta_Gael_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 42.9%
# Median: 3
# Mean: 3.00
# Overall Ranking: 14
# Music-Show Ranking: 9

# %% [markdown]
# ### Sleepless Nights

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Sleepless_Nights_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 1
# Percent Familiar with Show: 14.3%
# Median: 6
# Mean: 6.00
# Overall Ranking: 17
# Music-Show Ranking: 12

# %% [markdown]
# ### Smash It Back

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Smash_It_Back_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 28.6%
# Median: 6
# Mean: 6.50
# Overall Ranking: 10
# Music-Show Ranking: 5

# %% [markdown]
# ### SoundLab

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Soundlab_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 1
# Percent Familiar with Show: 14.3%
# Median: 5
# Mean: 5.00
# Overall Ranking: 18
# Music-Show Ranking: 13

# %% [markdown]
# ### Swing Shift

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Swing_Shift_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 42.9%
# Median: 4
# Mean: 4.67
# Overall Ranking: 9
# Music-Show Ranking: 4

# %% [markdown]
# ### Terrasonic

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Terrasonic_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 6
# Respondents Familiar with Show: 1
# Percent Familiar with Show: 16.7%
# Median: 6
# Mean: 6.00
# Overall Ranking: 17
# Music-Show Ranking: 12

# %% [markdown]
# ### The Heavy Set

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_Heavy_Set_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 42.9%
# Median: 3
# Mean: 2.67
# Overall Ranking: 15
# Music-Show Ranking: 10

# %% [markdown]
# ### The Opera Box

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_Opera_Box_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 1
# Percent Familiar with Show: 14.3%
# Median: 2
# Mean: 2.00
# Overall Ranking: 21
# Music-Show Ranking: 15

# %% [markdown]
# ### Under the Floorboards

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Under_the_Floorboards_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 42.9%
# Median: 6
# Mean: 5.00
# Overall Ranking: 8
# Music-Show Ranking: 3

# %% [markdown]
# ## News Shows

# %% [markdown]
# ### A Public Affairs

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'A_Public_Affair_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 42.9%
# Median: 5
# Mean: 4.33
# Overall Ranking: 10
# News-Show Ranking: 10

# %% [markdown]
# ### Alan Watts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Alan_Watts_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 0
# Percent Familiar with Show: 0.0%

# %% [markdown]
# ### Alternative Radio

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Alternative_Radio_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 42.9%
# Median: 5
# Mean: 4.33
# Overall Ranking: 10
# News-Show Ranking: 10

# %% [markdown]
# ### BBC News Hour

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'BBC_News_Hour_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 28.6%
# Median: 6
# Mean: 6.50
# Overall Ranking: 10
# News-Show Ranking: 10

# %% [markdown]
# ### BBC The Newsroom

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'BBC_The_Newsroom_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 0
# Percent Familiar with Show: 0.0%

# %% [markdown]
# ### Between the Lines

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Between_the_Lines_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 28.6%
# Median: 5
# Mean: 5.00
# Overall Ranking: 13
# News-Show Ranking: 13

# %% [markdown]
# ### Bioneers

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Bioneers_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 42.9%
# Median: 3
# Mean: 5.00
# Overall Ranking: 8
# News-Show Ranking: 8

# %% [markdown]
# ### Black Talk

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Black_Talk_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 42.9%
# Median: 5
# Mean: 5.00
# Overall Ranking: 8
# News-Show Ranking: 8

# %% [markdown]
# ### Colorado Chinese Radio Network

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Col_Chinese_Radio_Network_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 28.6%
# Median: 3
# Mean: 3.00
# Overall Ranking: 17
# News-Show Ranking: 16

# %% [markdown]
# ### Connections

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Connections_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 42.9%
# Median: 5
# Mean: 5.00
# Overall Ranking: 8
# News-Show Ranking: 8

# %% [markdown]
# ### Counterspin

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Counterspin_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 57.1%
# Median: 5
# Mean: 4.75
# Overall Ranking: 5
# News-Show Ranking: 5

# %% [markdown]
# ### Democracy Now

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Democracy_Now_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 28.6%
# Median: 7
# Mean: 7.00
# Overall Ranking: 9
# News-Show Ranking: 9

# %% [markdown]
# ### Economic Update

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Economic_Update_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 42.9%
# Median: 9
# Mean: 9.00
# Overall Ranking: 1
# News-Show Ranking: 1

# %% [markdown]
# ### Hemispheres

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Hemispheres_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 28.6%
# Median: 6
# Mean: 6.00
# Overall Ranking: 11
# News-Show Ranking: 11

# %% [markdown]
# ### How on Earth

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'How_on_Earth_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 1
# Percent Familiar with Show: 14.3%
# Median: 5
# Mean: 5.00
# Overall Ranking: 18
# News-Show Ranking: 17

# %% [markdown]
# ### Indian Voices

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Indian_Voices_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 28.6%
# Median: 7
# Mean: 7.50
# Overall Ranking: 8
# News-Show Ranking: 8

# %% [markdown]
# ### It's the Economy

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Its_The_Economy_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 42.9%
# Median: 7
# Mean: 6.67
# Overall Ranking: 4
# News-Show Ranking: 4

# %% [markdown]
# ### Jim Hightower

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Jim_Hightower_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 1
# Percent Familiar with Show: 14.3%
# Median: 9
# Mean: 9.00
# Overall Ranking: 14
# News-Show Ranking: 14

# %% [markdown]
# ### La Lucha Sigue

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'La_Lucha_Sigue_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 1
# Percent Familiar with Show: 14.3%
# Median: 7
# Mean: 7.00
# Overall Ranking: 16
# News-Show Ranking: 15

# %% [markdown]
# ### Labor Exchange

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Labor_Exchange_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 28.6%
# Median: 4
# Mean: 4.50
# Overall Ranking: 14
# News-Show Ranking: 14

# %% [markdown]
# ### Linea Abierta

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Linea_Abierta_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 6
# Respondents Familiar with Show: 1
# Percent Familiar with Show: 16.7%
# Median: 2
# Mean: 2.00
# Overall Ranking: 21
# News-Show Ranking: 19

# %% [markdown]
# ### Living Dialogues

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Living_Dialogues_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 42.9%
# Median: 7
# Mean: 7.00
# Overall Ranking: 3
# News-Show Ranking: 3

# %% [markdown]
# ### Local PM Headlines Spanish

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Local_PM_Headlines_Spanish_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 6
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 50.0%
# Median: 3
# Mean: 3.33
# Overall Ranking: 13
# News-Show Ranking: 13

# %% [markdown]
# ### Making Contact

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Making_Contact_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 6
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 50.0%
# Median: 2
# Mean: 3.67
# Overall Ranking: 12
# News-Show Ranking: 12

# %% [markdown]
# ### Metro

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Metro_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 42.9%
# Median: 7
# Mean: 5.67
# Overall Ranking: 6
# News-Show Ranking: 6

# %% [markdown]
# ### Metro Arts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Metro_Arts_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 42.9%
# Median: 5
# Mean: 5.00
# Overall Ranking: 8
# News-Show Ranking: 8

# %% [markdown]
# ### Morning Magazine

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Morning_Magazine_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 6
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 50.0%
# Median: 7
# Mean: 7.00
# Overall Ranking: 3
# News-Show Ranking: 3

# %% [markdown]
# ### Naturally

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Naturally_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 28.6%
# Median: 3
# Mean: 3.00
# Overall Ranking: 17
# News-Show Ranking: 16

# %% [markdown]
# ### New Dimensions

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'New_Dimensions_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 8
# Respondents Familiar with Show: 4
# Percent Familiar with Show: 50.0%
# Median: 5
# Mean: 5.25
# Overall Ranking: 3
# News-Show Ranking: 3

# %% [markdown]
# ### Outsources

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Outsources_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 42.9%
# Median: 3
# Mean: 3.33
# Overall Ranking: 13
# News-Show Ranking: 13

# %% [markdown]
# ### Pasa La Voz

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Pasa_La_Voz_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 28.6%
# Median: 2
# Mean: 2.50
# Overall Ranking: 18
# News-Show Ranking: 17

# %% [markdown]
# ### Peace Talks

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Peace_Talks_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 6
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 33.3%
# Median: 4
# Mean: 4.50
# Overall Ranking: 14
# News-Show Ranking: 14

# %% [markdown]
# ### Project Censored

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Project_Censored_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 28.6%
# Median: 6
# Mean: 6.00
# Overall Ranking: 11
# News-Show Ranking: 11

# %% [markdown]
# ### Rising Up with Sonali

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Rising_Up_with_Sonali_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 28.6%
# Median: 5
# Mean: 5.00
# Overall Ranking: 13
# News-Show Ranking: 13

# %% [markdown]
# ### Sprouts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Sprouts_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 6
# Respondents Familiar with Show: 5
# Percent Familiar with Show: 83.3%
# Median: 5
# Mean: 4.60
# Overall Ranking: 2
# News-Show Ranking: 2

# %% [markdown]
# ### StoryTellers of Color

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'StoryTellers_of_Color_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 6
# Respondents Familiar with Show: 1
# Percent Familiar with Show: 16.7%
# Median: 3
# Mean: 3.00
# Overall Ranking: 20
# News-Show Ranking: 18

# %% [markdown]
# ### Laura Flanders

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Laura_Flanders_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 6
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 50.0%
# Median: 5
# Mean: 5.33
# Overall Ranking: 7
# News-Show Ranking: 7

# %% [markdown]
# ### Ralph Nader

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Ralph_Nader_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 6
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 33.3%
# Median: 7
# Mean: 7.00
# Overall Ranking: 9
# News-Show Ranking: 9

# %% [markdown]
# ### Shortwave Report

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Shortwave_Report_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 28.6%
# Median: 6
# Mean: 6.00
# Overall Ranking: 11
# News-Show Ranking: 11

# %% [markdown]
# ### The World

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_World_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 6
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 33.3%
# Median: 5
# Mean: 5.50
# Overall Ranking: 12
# News-Show Ranking: 12

# %% [markdown]
# ### TRENDS

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'TRENDS_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 1
# Percent Familiar with Show: 14.3%
# Median: 6
# Mean: 6.00
# Overall Ranking: 17
# News-Show Ranking: 16

# %% [markdown]
# ### Tributaries

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Tributaries_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 28.6%
# Median: 5
# Mean: 5.00
# Overall Ranking: 13
# News-Show Ranking: 13

# %% [markdown]
# ### TUC Radio

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'TUC_Radio_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 6
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 33.3%
# Median: 6
# Mean: 6.00
# Overall Ranking: 11
# News-Show Ranking: 11

# %% [markdown]
# ### WINGS

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'WINGS_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 3
# Percent Familiar with Show: 42.9%
# Median: 5
# Mean: 5.33
# Overall Ranking: 7
# News-Show Ranking: 7

# %% [markdown]
# ### Weed Between

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Weed_between_Ratings')
# Out:
# Filter: Prefer to self identify
# Total Respondents: 7
# Respondents Familiar with Show: 2
# Percent Familiar with Show: 28.6%
# Median: 5
# Mean: 5.00
# Overall Ranking: 13
# News-Show Ranking: 13
