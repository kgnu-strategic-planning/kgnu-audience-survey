# %% [markdown]
# # Boulder County

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import MaxNLocator
from IPython.display import display, Markdown
from functions import *

# %%
df = pd.read_excel('KGNU-Member-Data-07.15.22.xlsx', sheet_name='English')

# %%
show_ratings_cols = df.columns.tolist()[111:191]
#show_ratings_cols

# %%
filter_col = 'County'
filter_col_val = 'Boulder'
filter_col_val_display = 'Filter: Boulder County'

# %% [markdown]
# ## Show Rankings

# %%
create_ranked_table_of_shows(df, False, filter_col, filter_col_val, filter_col_val_display)
# Out:
# Overall      Show               #Ratings/    Median/Mean  Score   Music   News
# Ranking                        #Respondents                       Show    Show
#                                                                  Ranking Ranking
# --------------------------------------------------------------------------------
#  1    MSA                         157/168        9/8.3    1306      1
#  2    BBC News Hour               166/168        9/7.8    1287              1
#  3    Democracy Now               157/167        9/8.1    1272              2
#  4    Jim Hightower               145/167       10/8.4    1212              3
#  5    OGGG                        152/168        9/7.8    1188      2
#  6    Roots and Branches          134/168       10/8.4    1131      3
#  7    E Town                      156/167        8/7.2    1121      4
#  8    Alan Watts                  144/168        8/7.7    1102              4
#  9    HTH                         145/168        9/7.6    1098      5
#  9    African Roots               145/166        8/7.6    1098      5
# 10    ASA                         154/167        8/7.1    1097      6
# 11    Reggae Bloodlines           146/168        8/7.4    1082      7
# 12    Blues Legacy                142/169        8/7.5    1060      8
# 13    Counterspin                 124/166        9/8.4    1039              5
# 14    How on Earth                121/167        9/8.4    1021              6
# 14    Hemispheres                 128/167        9/8.0    1021              6
# 15    Alternative Radio           122/164        9/8.3    1015              7
# 16    Morning Magazine            118/163        9/8.3     978              8
# 17    Ralph Nader                 130/164        9/7.5     972              9
# 18    BBC The Newsroom            126/168        8/7.5     947             10
# 19    Terrasonic                  122/168        8/7.6     922      9
# 20    Grateful Dead               146/169        6/6.1     896     10
# 21    Its The Economy             112/167        9/8.0     894             11
# 22    Bioneers                    116/164        8/7.7     890             12
# 23    Economic Update             107/166        9/8.2     881             13
# 24    Indian Voices               112/165        8/7.8     876             14
# 25    Naturally                   112/164        9/7.8     874             15
# 26    Connections                 111/166        8/7.5     836             16
# 27    Dusty Grooves               109/167        8/7.5     817     11
# 28    A Public Affair             109/163        8/7.3     800             17
# 29    HWY 322                     107/166        8/7.4     795     12
# 30    Corriente                   113/166        8/6.9     785     13
# 30    Musica Mundi                105/166        8/7.5     785     13
# 31    Jazz Lives                  115/165        8/6.7     772     14
# 32    Metro                       106/162        7/7.2     764             18
# 33    Ragtime America             123/168        7/6.2     760     15
# 34    New Dimensions              101/163        8/7.5     756             19
# 35    Gospel Chime                126/168        6/5.9     749     16
# 36    Kaberet                     105/166        8/7.0     739     17
# 37    Tributaries                  99/165        8/7.3     723             20
# 38    Metro Arts                   90/161        8/7.6     683             21
# 39    Project Censored             78/161       10/8.5     660             22
# 40    Reggae Transfusions          91/167        8/7.2     655     18
# 41    Labor Exchange               88/163        8/7.4     647             23
# 42    Seolta Gael                  90/166        8/7.1     642     19
# 43    A Classic Monday             94/165        7/6.7     629     20
# 44    Between the Lines            78/165        8/7.8     612             24
# 45    Laura Flanders               83/160        8/7.2     598             25
# 46    Rising Up with Sonali        76/164        8/7.8     595             26
# 47    WINGS                        77/162        8/7.7     592             27
# 47    TUC Radio                    74/162        9/8.0     592             27
# 48    La Lucha Sigue               78/162        8/7.6     591             28
# 49    Living Dialogues             95/164        7/6.2     586             29
# 50    Soundlab                     82/167        7/7.1     584     21
# 51    Peace Talks                  79/163        8/7.4     581             30
# 52    The World                    83/165        8/6.9     575             31
# 53    Eclipse                      86/168        7/6.6     566     22
# 54    Sleepless Nights             82/167        7/6.9     563     23
# 55    Roots of Jazz                77/165        8/7.3     561     24
# 56    Black Talk                   75/166        8/7.4     557             32
# 57    The Opera Box                97/169        6/5.5     538     25
# 58    Dub Palace                   86/167        6/6.2     536     26
# 59    Shortwave Report             73/163        8/7.3     530             33
# 60    Swing Shift                  80/166        7/6.6     528     27
# 61    Restless Mornings            77/164        7/6.6     511     28
# 62    Electronic Air               84/167        6/6.0     503     29
# 63    Making Contact               70/161        7/7.0     492             34
# 64    Weed between                 70/163        8/7.0     487             35
# 65    Local PM Headlines Spanish   74/162        6/6.2     459             36
# 66    Outsources                   66/161        8/6.9     453             37
# 67    Sprouts                      54/161        8/7.2     391             38
# 68    StoryTellers of Color        50/160        8/7.6     378             39
# 69    The Heavy Set                54/167        7/6.8     365     30
# 70    Present Edge                 59/166        6/6.1     361     31
# 70    Under the Floorboards        58/165        6/6.2     361     31
# 71    TRENDS                       46/161        8/7.4     340             40
# 72    Pasa La Voz                  46/156        8/7.1     328             41
# 73    Smash It Back                50/167        6/6.0     300     32
# 74    Col Chinese Radio Network    50/165        5/4.9     244             42
# 75    Linea Abierta                28/163        7/6.7     187             43

# %% [markdown]
# ## Music Shows

# %% [markdown]
# ### A Classic Monday

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'A_Classic_Monday_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 165
# Respondents Familiar with Show: 94
# Percent Familiar with Show: 57.0%
# Median: 7
# Mean: 6.69
# Overall Ranking: 43
# Music-Show Ranking: 20

# %% [markdown]
# ### African Roots

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'African_Roots_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 166
# Respondents Familiar with Show: 145
# Percent Familiar with Show: 87.3%
# Median: 8
# Mean: 7.57
# Overall Ranking: 9
# Music-Show Ranking: 5

# %% [markdown]
# ### Afternoon Sound Alternative

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'ASA_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 167
# Respondents Familiar with Show: 154
# Percent Familiar with Show: 92.2%
# Median: 8
# Mean: 7.12
# Overall Ranking: 10
# Music-Show Ranking: 6

# %% [markdown]
# ### Blues Legacy

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Blues_Legacy_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 169
# Respondents Familiar with Show: 142
# Percent Familiar with Show: 84.0%
# Median: 8
# Mean: 7.46
# Overall Ranking: 12
# Music-Show Ranking: 8

# %% [markdown]
# ### Corriente

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Corriente_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 166
# Respondents Familiar with Show: 113
# Percent Familiar with Show: 68.1%
# Median: 8
# Mean: 6.95
# Overall Ranking: 30
# Music-Show Ranking: 13

# %% [markdown]
# ### Dub Palace

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Dub_Palace_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 167
# Respondents Familiar with Show: 86
# Percent Familiar with Show: 51.5%
# Median: 6
# Mean: 6.23
# Overall Ranking: 58
# Music-Show Ranking: 26

# %% [markdown]
# ### Dusty Grooves

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Dusty_Grooves_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 167
# Respondents Familiar with Show: 109
# Percent Familiar with Show: 65.3%
# Median: 8
# Mean: 7.50
# Overall Ranking: 27
# Music-Show Ranking: 11

# %% [markdown]
# ### Eclipse

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Eclipse_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 168
# Respondents Familiar with Show: 86
# Percent Familiar with Show: 51.2%
# Median: 7
# Mean: 6.58
# Overall Ranking: 53
# Music-Show Ranking: 22

# %% [markdown]
# ### Electronic Air

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Electronic_Air_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 167
# Respondents Familiar with Show: 84
# Percent Familiar with Show: 50.3%
# Median: 6
# Mean: 5.99
# Overall Ranking: 62
# Music-Show Ranking: 29

# %% [markdown]
# ### eTown

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'E_Town_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 167
# Respondents Familiar with Show: 156
# Percent Familiar with Show: 93.4%
# Median: 8
# Mean: 7.19
# Overall Ranking: 7
# Music-Show Ranking: 4

# %% [markdown]
# ### Gospel Chime

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Gospel_Chime_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 168
# Respondents Familiar with Show: 126
# Percent Familiar with Show: 75.0%
# Median: 6
# Mean: 5.94
# Overall Ranking: 35
# Music-Show Ranking: 16

# %% [markdown]
# ### Grateful Dead

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Grateful_Dead_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 169
# Respondents Familiar with Show: 146
# Percent Familiar with Show: 86.4%
# Median: 6
# Mean: 6.14
# Overall Ranking: 20
# Music-Show Ranking: 10

# %% [markdown]
# ### Hwy 322

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'HWY_322_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 166
# Respondents Familiar with Show: 107
# Percent Familiar with Show: 64.5%
# Median: 8
# Mean: 7.43
# Overall Ranking: 29
# Music-Show Ranking: 12

# %% [markdown]
# ### Honky Tonk Heroes

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'HTH_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 168
# Respondents Familiar with Show: 145
# Percent Familiar with Show: 86.3%
# Median: 9
# Mean: 7.57
# Overall Ranking: 9
# Music-Show Ranking: 5

# %% [markdown]
# ### Jazz Lives

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Jazz_Lives_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 165
# Respondents Familiar with Show: 115
# Percent Familiar with Show: 69.7%
# Median: 8
# Mean: 6.71
# Overall Ranking: 31
# Music-Show Ranking: 14

# %% [markdown]
# ### Kaberet

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Kaberet_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 166
# Respondents Familiar with Show: 105
# Percent Familiar with Show: 63.3%
# Median: 8
# Mean: 7.04
# Overall Ranking: 36
# Music-Show Ranking: 17

# %% [markdown]
# ### Morning Sound Alternative

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'MSA_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 168
# Respondents Familiar with Show: 157
# Percent Familiar with Show: 93.5%
# Median: 9
# Mean: 8.32
# Overall Ranking: 1
# Music-Show Ranking: 1

# %% [markdown]
# ### Musica Mundi

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Musica_Mundi_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 166
# Respondents Familiar with Show: 105
# Percent Familiar with Show: 63.3%
# Median: 8
# Mean: 7.48
# Overall Ranking: 30
# Music-Show Ranking: 13

# %% [markdown]
# ### Old Grass Gnu Grass

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'OGGG_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 168
# Respondents Familiar with Show: 152
# Percent Familiar with Show: 90.5%
# Median: 9
# Mean: 7.82
# Overall Ranking: 5
# Music-Show Ranking: 2

# %% [markdown]
# ### The Present Edge

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Present_Edge_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 166
# Respondents Familiar with Show: 59
# Percent Familiar with Show: 35.5%
# Median: 6
# Mean: 6.12
# Overall Ranking: 70
# Music-Show Ranking: 31

# %% [markdown]
# ### Ragtime America

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Ragtime_America_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 168
# Respondents Familiar with Show: 123
# Percent Familiar with Show: 73.2%
# Median: 7
# Mean: 6.18
# Overall Ranking: 33
# Music-Show Ranking: 15

# %% [markdown]
# ### Reggae Bloodlines

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Reggae_Bloodlines_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 168
# Respondents Familiar with Show: 146
# Percent Familiar with Show: 86.9%
# Median: 8
# Mean: 7.41
# Overall Ranking: 11
# Music-Show Ranking: 7

# %% [markdown]
# ### Reggae Transfusions

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Reggae_Transfusions_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 167
# Respondents Familiar with Show: 91
# Percent Familiar with Show: 54.5%
# Median: 8
# Mean: 7.20
# Overall Ranking: 40
# Music-Show Ranking: 18

# %% [markdown]
# ### Restless Mornings

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Restless_Mornings_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 164
# Respondents Familiar with Show: 77
# Percent Familiar with Show: 47.0%
# Median: 7
# Mean: 6.64
# Overall Ranking: 61
# Music-Show Ranking: 28

# %% [markdown]
# ### Roots and Branches

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Roots_and_Branches_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 168
# Respondents Familiar with Show: 134
# Percent Familiar with Show: 79.8%
# Median: 10
# Mean: 8.44
# Overall Ranking: 6
# Music-Show Ranking: 3

# %% [markdown]
# ### Roots of Jazz

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Roots_of_Jazz_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 165
# Respondents Familiar with Show: 77
# Percent Familiar with Show: 46.7%
# Median: 8
# Mean: 7.29
# Overall Ranking: 55
# Music-Show Ranking: 24

# %% [markdown]
# ### Seolta Gael

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Seolta_Gael_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 166
# Respondents Familiar with Show: 90
# Percent Familiar with Show: 54.2%
# Median: 8
# Mean: 7.13
# Overall Ranking: 42
# Music-Show Ranking: 19

# %% [markdown]
# ### Sleepless Nights

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Sleepless_Nights_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 167
# Respondents Familiar with Show: 82
# Percent Familiar with Show: 49.1%
# Median: 7
# Mean: 6.87
# Overall Ranking: 54
# Music-Show Ranking: 23

# %% [markdown]
# ### Smash It Back

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Smash_It_Back_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 167
# Respondents Familiar with Show: 50
# Percent Familiar with Show: 29.9%
# Median: 6
# Mean: 6.00
# Overall Ranking: 73
# Music-Show Ranking: 32

# %% [markdown]
# ### SoundLab

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Soundlab_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 167
# Respondents Familiar with Show: 82
# Percent Familiar with Show: 49.1%
# Median: 7
# Mean: 7.12
# Overall Ranking: 50
# Music-Show Ranking: 21

# %% [markdown]
# ### Swing Shift

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Swing_Shift_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 166
# Respondents Familiar with Show: 80
# Percent Familiar with Show: 48.2%
# Median: 7
# Mean: 6.60
# Overall Ranking: 60
# Music-Show Ranking: 27

# %% [markdown]
# ### Terrasonic

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Terrasonic_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 168
# Respondents Familiar with Show: 122
# Percent Familiar with Show: 72.6%
# Median: 8
# Mean: 7.56
# Overall Ranking: 19
# Music-Show Ranking: 9

# %% [markdown]
# ### The Heavy Set

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_Heavy_Set_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 167
# Respondents Familiar with Show: 54
# Percent Familiar with Show: 32.3%
# Median: 7
# Mean: 6.76
# Overall Ranking: 69
# Music-Show Ranking: 30

# %% [markdown]
# ### The Opera Box

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_Opera_Box_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 169
# Respondents Familiar with Show: 97
# Percent Familiar with Show: 57.4%
# Median: 6
# Mean: 5.55
# Overall Ranking: 57
# Music-Show Ranking: 25

# %% [markdown]
# ### Under the Floorboards

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Under_the_Floorboards_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 165
# Respondents Familiar with Show: 58
# Percent Familiar with Show: 35.2%
# Median: 6
# Mean: 6.22
# Overall Ranking: 70
# Music-Show Ranking: 31

# %% [markdown]
# ## News Shows

# %% [markdown]
# ### A Public Affairs

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'A_Public_Affair_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 163
# Respondents Familiar with Show: 109
# Percent Familiar with Show: 66.9%
# Median: 8
# Mean: 7.34
# Overall Ranking: 28
# News-Show Ranking: 17

# %% [markdown]
# ### Alan Watts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Alan_Watts_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 168
# Respondents Familiar with Show: 144
# Percent Familiar with Show: 85.7%
# Median: 8
# Mean: 7.65
# Overall Ranking: 8
# News-Show Ranking: 4

# %% [markdown]
# ### Alternative Radio

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Alternative_Radio_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 164
# Respondents Familiar with Show: 122
# Percent Familiar with Show: 74.4%
# Median: 9
# Mean: 8.32
# Overall Ranking: 15
# News-Show Ranking: 7

# %% [markdown]
# ### BBC News Hour

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'BBC_News_Hour_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 168
# Respondents Familiar with Show: 166
# Percent Familiar with Show: 98.8%
# Median: 9
# Mean: 7.75
# Overall Ranking: 2
# News-Show Ranking: 1

# %% [markdown]
# ### BBC The Newsroom

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'BBC_The_Newsroom_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 168
# Respondents Familiar with Show: 126
# Percent Familiar with Show: 75.0%
# Median: 8
# Mean: 7.52
# Overall Ranking: 18
# News-Show Ranking: 10

# %% [markdown]
# ### Between the Lines

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Between_the_Lines_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 165
# Respondents Familiar with Show: 78
# Percent Familiar with Show: 47.3%
# Median: 8
# Mean: 7.85
# Overall Ranking: 44
# News-Show Ranking: 24

# %% [markdown]
# ### Bioneers

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Bioneers_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 164
# Respondents Familiar with Show: 116
# Percent Familiar with Show: 70.7%
# Median: 8
# Mean: 7.67
# Overall Ranking: 22
# News-Show Ranking: 12

# %% [markdown]
# ### Black Talk

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Black_Talk_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 166
# Respondents Familiar with Show: 75
# Percent Familiar with Show: 45.2%
# Median: 8
# Mean: 7.43
# Overall Ranking: 56
# News-Show Ranking: 32

# %% [markdown]
# ### Colorado Chinese Radio Network

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Col_Chinese_Radio_Network_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 165
# Respondents Familiar with Show: 50
# Percent Familiar with Show: 30.3%
# Median: 5
# Mean: 4.88
# Overall Ranking: 74
# News-Show Ranking: 42

# %% [markdown]
# ### Connections

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Connections_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 166
# Respondents Familiar with Show: 111
# Percent Familiar with Show: 66.9%
# Median: 8
# Mean: 7.53
# Overall Ranking: 26
# News-Show Ranking: 16

# %% [markdown]
# ### Counterspin

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Counterspin_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 166
# Respondents Familiar with Show: 124
# Percent Familiar with Show: 74.7%
# Median: 9
# Mean: 8.38
# Overall Ranking: 13
# News-Show Ranking: 5

# %% [markdown]
# ### Democracy Now

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Democracy_Now_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 167
# Respondents Familiar with Show: 157
# Percent Familiar with Show: 94.0%
# Median: 9
# Mean: 8.10
# Overall Ranking: 3
# News-Show Ranking: 2

# %% [markdown]
# ### Economic Update

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Economic_Update_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 166
# Respondents Familiar with Show: 107
# Percent Familiar with Show: 64.5%
# Median: 9
# Mean: 8.23
# Overall Ranking: 23
# News-Show Ranking: 13

# %% [markdown]
# ### Hemispheres

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Hemispheres_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 167
# Respondents Familiar with Show: 128
# Percent Familiar with Show: 76.6%
# Median: 9
# Mean: 7.98
# Overall Ranking: 14
# News-Show Ranking: 6

# %% [markdown]
# ### How on Earth

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'How_on_Earth_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 167
# Respondents Familiar with Show: 121
# Percent Familiar with Show: 72.5%
# Median: 9
# Mean: 8.44
# Overall Ranking: 14
# News-Show Ranking: 6

# %% [markdown]
# ### Indian Voices

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Indian_Voices_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 165
# Respondents Familiar with Show: 112
# Percent Familiar with Show: 67.9%
# Median: 8
# Mean: 7.82
# Overall Ranking: 24
# News-Show Ranking: 14

# %% [markdown]
# ### It's the Economy

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Its_The_Economy_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 167
# Respondents Familiar with Show: 112
# Percent Familiar with Show: 67.1%
# Median: 9
# Mean: 7.98
# Overall Ranking: 21
# News-Show Ranking: 11

# %% [markdown]
# ### Jim Hightower

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Jim_Hightower_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 167
# Respondents Familiar with Show: 145
# Percent Familiar with Show: 86.8%
# Median: 10
# Mean: 8.36
# Overall Ranking: 4
# News-Show Ranking: 3

# %% [markdown]
# ### La Lucha Sigue

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'La_Lucha_Sigue_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 162
# Respondents Familiar with Show: 78
# Percent Familiar with Show: 48.1%
# Median: 8
# Mean: 7.58
# Overall Ranking: 48
# News-Show Ranking: 28

# %% [markdown]
# ### Labor Exchange

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Labor_Exchange_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 163
# Respondents Familiar with Show: 88
# Percent Familiar with Show: 54.0%
# Median: 8
# Mean: 7.35
# Overall Ranking: 41
# News-Show Ranking: 23

# %% [markdown]
# ### Linea Abierta

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Linea_Abierta_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 163
# Respondents Familiar with Show: 28
# Percent Familiar with Show: 17.2%
# Median: 7
# Mean: 6.68
# Overall Ranking: 75
# News-Show Ranking: 43

# %% [markdown]
# ### Living Dialogues

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Living_Dialogues_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 164
# Respondents Familiar with Show: 95
# Percent Familiar with Show: 57.9%
# Median: 7
# Mean: 6.17
# Overall Ranking: 49
# News-Show Ranking: 29

# %% [markdown]
# ### Local PM Headlines Spanish

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Local_PM_Headlines_Spanish_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 162
# Respondents Familiar with Show: 74
# Percent Familiar with Show: 45.7%
# Median: 6
# Mean: 6.20
# Overall Ranking: 65
# News-Show Ranking: 36

# %% [markdown]
# ### Making Contact

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Making_Contact_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 161
# Respondents Familiar with Show: 70
# Percent Familiar with Show: 43.5%
# Median: 7
# Mean: 7.03
# Overall Ranking: 63
# News-Show Ranking: 34

# %% [markdown]
# ### Metro

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Metro_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 162
# Respondents Familiar with Show: 106
# Percent Familiar with Show: 65.4%
# Median: 7
# Mean: 7.21
# Overall Ranking: 32
# News-Show Ranking: 18

# %% [markdown]
# ### Metro Arts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Metro_Arts_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 161
# Respondents Familiar with Show: 90
# Percent Familiar with Show: 55.9%
# Median: 8
# Mean: 7.59
# Overall Ranking: 38
# News-Show Ranking: 21

# %% [markdown]
# ### Morning Magazine

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Morning_Magazine_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 163
# Respondents Familiar with Show: 118
# Percent Familiar with Show: 72.4%
# Median: 9
# Mean: 8.29
# Overall Ranking: 16
# News-Show Ranking: 8

# %% [markdown]
# ### Naturally

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Naturally_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 164
# Respondents Familiar with Show: 112
# Percent Familiar with Show: 68.3%
# Median: 9
# Mean: 7.80
# Overall Ranking: 25
# News-Show Ranking: 15

# %% [markdown]
# ### New Dimensions

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'New_Dimensions_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 163
# Respondents Familiar with Show: 101
# Percent Familiar with Show: 62.0%
# Median: 8
# Mean: 7.49
# Overall Ranking: 34
# News-Show Ranking: 19

# %% [markdown]
# ### Outsources

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Outsources_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 161
# Respondents Familiar with Show: 66
# Percent Familiar with Show: 41.0%
# Median: 8
# Mean: 6.86
# Overall Ranking: 66
# News-Show Ranking: 37

# %% [markdown]
# ### Pasa La Voz

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Pasa_La_Voz_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 156
# Respondents Familiar with Show: 46
# Percent Familiar with Show: 29.5%
# Median: 8
# Mean: 7.13
# Overall Ranking: 72
# News-Show Ranking: 41

# %% [markdown]
# ### Peace Talks

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Peace_Talks_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 163
# Respondents Familiar with Show: 79
# Percent Familiar with Show: 48.5%
# Median: 8
# Mean: 7.35
# Overall Ranking: 51
# News-Show Ranking: 30

# %% [markdown]
# ### Project Censored

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Project_Censored_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 161
# Respondents Familiar with Show: 78
# Percent Familiar with Show: 48.4%
# Median: 10
# Mean: 8.46
# Overall Ranking: 39
# News-Show Ranking: 22

# %% [markdown]
# ### Rising Up with Sonali

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Rising_Up_with_Sonali_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 164
# Respondents Familiar with Show: 76
# Percent Familiar with Show: 46.3%
# Median: 8
# Mean: 7.83
# Overall Ranking: 46
# News-Show Ranking: 26

# %% [markdown]
# ### Sprouts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Sprouts_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 161
# Respondents Familiar with Show: 54
# Percent Familiar with Show: 33.5%
# Median: 8
# Mean: 7.24
# Overall Ranking: 67
# News-Show Ranking: 38

# %% [markdown]
# ### StoryTellers of Color

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'StoryTellers_of_Color_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 160
# Respondents Familiar with Show: 50
# Percent Familiar with Show: 31.2%
# Median: 8
# Mean: 7.56
# Overall Ranking: 68
# News-Show Ranking: 39

# %% [markdown]
# ### Laura Flanders

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Laura_Flanders_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 160
# Respondents Familiar with Show: 83
# Percent Familiar with Show: 51.9%
# Median: 8
# Mean: 7.20
# Overall Ranking: 45
# News-Show Ranking: 25

# %% [markdown]
# ### Ralph Nader

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Ralph_Nader_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 164
# Respondents Familiar with Show: 130
# Percent Familiar with Show: 79.3%
# Median: 9
# Mean: 7.48
# Overall Ranking: 17
# News-Show Ranking: 9

# %% [markdown]
# ### Shortwave Report

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Shortwave_Report_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 163
# Respondents Familiar with Show: 73
# Percent Familiar with Show: 44.8%
# Median: 8
# Mean: 7.26
# Overall Ranking: 59
# News-Show Ranking: 33

# %% [markdown]
# ### The World

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_World_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 165
# Respondents Familiar with Show: 83
# Percent Familiar with Show: 50.3%
# Median: 8
# Mean: 6.93
# Overall Ranking: 52
# News-Show Ranking: 31

# %% [markdown]
# ### TRENDS

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'TRENDS_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 161
# Respondents Familiar with Show: 46
# Percent Familiar with Show: 28.6%
# Median: 8
# Mean: 7.39
# Overall Ranking: 71
# News-Show Ranking: 40

# %% [markdown]
# ### Tributaries

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Tributaries_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 165
# Respondents Familiar with Show: 99
# Percent Familiar with Show: 60.0%
# Median: 8
# Mean: 7.30
# Overall Ranking: 37
# News-Show Ranking: 20

# %% [markdown]
# ### TUC Radio

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'TUC_Radio_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 162
# Respondents Familiar with Show: 74
# Percent Familiar with Show: 45.7%
# Median: 9
# Mean: 8.00
# Overall Ranking: 47
# News-Show Ranking: 27

# %% [markdown]
# ### WINGS

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'WINGS_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 162
# Respondents Familiar with Show: 77
# Percent Familiar with Show: 47.5%
# Median: 8
# Mean: 7.69
# Overall Ranking: 47
# News-Show Ranking: 27

# %% [markdown]
# ### Weed Between

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Weed_between_Ratings')
# Out:
# Filter: Boulder County
# Total Respondents: 163
# Respondents Familiar with Show: 70
# Percent Familiar with Show: 42.9%
# Median: 8
# Mean: 6.96
# Overall Ranking: 64
# News-Show Ranking: 35
