# %% [markdown]
# # White - Random

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import MaxNLocator
from IPython.display import display, Markdown
from functions import *

# %%
df = pd.read_excel('Client Data English-07.15.22.xlsx', sheet_name='English')

# %%
show_ratings_cols = df.columns.tolist()[97:177]
#show_ratings_cols

# %%
filter_col = 'You_Are'
filter_col_val = 'White'
filter_col_val_display = 'Filter: White'

# %% [markdown]
# ## Show Rankings

# %%
create_ranked_table_of_shows(df, True, filter_col, filter_col_val, filter_col_val_display)
# Out:
# Overall      Show               #Ratings/    Median/Mean  Score   Music   News
# Ranking                        #Respondents                       Show    Show
#                                                                  Ranking Ranking
# --------------------------------------------------------------------------------
#  1    Blues Legacy                  56/95        7/6.8     381      1
#  2    BBC News Hour                 51/91        7/7.0     356              1
#  3    E Town                        56/96        7/6.2     347      2
#  4    Connections                   46/89        8/7.3     337              2
#  5    Roots and Branches            46/96        8/7.3     336      3
#  6    ASA                           52/96        7/6.4     334      4
#  7    Bioneers                      44/88        8/7.2     315              3
#  8    African Roots                 50/93        6/6.3     314      5
#  9    HWY 322                       44/94        7/7.0     308      6
# 10    HTH                           48/95        7/6.4     306      7
# 11    Gospel Chime                  50/95        7/6.1     305      8
# 12    Grateful Dead                 50/96        6/5.9     294      9
# 13    Ragtime America               49/93        6/6.0     292     10
# 14    Reggae Bloodlines             46/94        7/6.3     291     11
# 15    Corriente                     47/95        7/6.1     288     12
# 16    Kaberet                       43/92        7/6.6     282     13
# 17    Jazz Lives                    46/93        7/6.1     280     14
# 18    The Opera Box                 45/93        7/6.1     274     15
# 19    Dusty Grooves                 41/96        7/6.6     269     16
# 20    Swing Shift                   38/94        8/7.0     266     17
# 21    Soundlab                      40/93        7/6.6     265     18
# 22    MSA                           39/96        8/6.8     264     19
# 23    A Classic Monday              44/93        6/6.0     263     20
# 24    BBC The Newsroom              37/90        7/6.9     257              4
# 25    Alan Watts                    41/90        7/6.2     256              5
# 25    OGGG                          44/96        6/5.8     256     21
# 26    A Public Affair               37/89        7/6.8     253              6
# 27    Tributaries                   35/90        7/7.2     252              7
# 28    Democracy Now                 35/90        7/7.1     249              8
# 29    Ralph Nader                   39/91        6/6.3     244              9
# 29    Jim Hightower                 34/91        7/7.2     244              9
# 29    Terrasonic                    35/95        8/7.0     244     22
# 30    Hemispheres                   34/90        7/7.1     241             10
# 31    Counterspin                   32/89        8/7.5     240             11
# 32    Living Dialogues              38/87        7/6.3     239             12
# 33    Reggae Transfusions           35/94        7/6.7     236     23
# 34    Roots of Jazz                 34/91        7/6.9     233     24
# 35    Metro                         35/86        7/6.6     232             13
# 36    Its The Economy               35/89        7/6.6     231             14
# 37    Laura Flanders                34/89        7/6.7     228             15
# 38    The World                     34/90        7/6.7     227             16
# 39    Alternative Radio             33/89        7/6.8     225             17
# 40    New Dimensions                33/87        7/6.8     223             18
# 40    Seolta Gael                   35/94        7/6.4     223     25
# 41    Morning Magazine              31/87        8/7.1     220             19
# 41    Indian Voices                 31/88        7/7.1     220             19
# 42    How on Earth                  30/89        8/7.3     219             20
# 43    Electronic Air                37/96        6/5.9     218     26
# 44    Musica Mundi                  32/92        7/6.6     212     27
# 45    Making Contact                28/85        8/7.4     208             21
# 46    Dub Palace                    35/95        6/5.8     204     28
# 47    Rising Up with Sonali         27/90        8/7.5     202             22
# 48    Restless Mornings             29/91        7/6.9     199     29
# 48    WINGS                         28/88        8/7.1     199             23
# 49    Economic Update               27/89        8/7.1     193             24
# 50    Between the Lines             27/88        7/7.0     188             25
# 51    Metro Arts                    27/84        8/6.9     187             26
# 52    Sleepless Nights              27/93        7/6.9     185     30
# 53    Project Censored              23/86        8/8.0     184             27
# 54    Under the Floorboards         27/93        7/6.7     182     31
# 54    Black Talk                    29/89        6/6.3     182             28
# 55    La Lucha Sigue                27/87        7/6.7     181             29
# 56    Eclipse                       32/95        5/5.6     179     32
# 56    TUC Radio                     23/88        9/7.8     179             30
# 57    Naturally                     27/86        7/6.6     178             31
# 58    Shortwave Report              26/89        7/6.7     175             32
# 59    Local PM Headlines Spanish    25/87        7/7.0     174             33
# 60    Present Edge                  25/93        7/6.7     167     33
# 61    Labor Exchange                26/86        6/6.3     164             34
# 62    Weed between                  23/90        8/6.8     156             35
# 63    Smash It Back                 23/94        7/6.5     149     34
# 64    Outsources                    22/86        8/6.7     148             36
# 65    Sprouts                       21/89        8/7.0     147             37
# 66    Peace Talks                   22/86        7/6.2     137             38
# 67    The Heavy Set                 19/92        8/6.9     132     35
# 68    StoryTellers of Color         17/88        7/6.6     113             39
# 69    TRENDS                        14/88        6/7.1      99             40
# 70    Col Chinese Radio Network     16/89        5/5.8      92             41
# 71    Pasa La Voz                   11/84        8/7.0      77             42
# 72    Linea Abierta                 12/87        6/6.2      74             43

# %% [markdown]
# ## Music Shows

# %% [markdown]
# ### A Classic Monday

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'A_Classic_Monday_Ratings')
# Out:
# Filter: White
# Total Respondents: 93
# Respondents Familiar with Show: 44
# Percent Familiar with Show: 47.3%
# Median: 6
# Mean: 5.98
# Overall Ranking: 23
# Music-Show Ranking: 20

# %% [markdown]
# ### African Roots

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'African_Roots_Ratings')
# Out:
# Filter: White
# Total Respondents: 93
# Respondents Familiar with Show: 50
# Percent Familiar with Show: 53.8%
# Median: 6
# Mean: 6.28
# Overall Ranking: 8
# Music-Show Ranking: 5

# %% [markdown]
# ### Afternoon Sound Alternative

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'ASA_Ratings')
# Out:
# Filter: White
# Total Respondents: 96
# Respondents Familiar with Show: 52
# Percent Familiar with Show: 54.2%
# Median: 7
# Mean: 6.42
# Overall Ranking: 6
# Music-Show Ranking: 4

# %% [markdown]
# ### Blues Legacy

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Blues_Legacy_Ratings')
# Out:
# Filter: White
# Total Respondents: 95
# Respondents Familiar with Show: 56
# Percent Familiar with Show: 58.9%
# Median: 7
# Mean: 6.80
# Overall Ranking: 1
# Music-Show Ranking: 1

# %% [markdown]
# ### Corriente

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Corriente_Ratings')
# Out:
# Filter: White
# Total Respondents: 95
# Respondents Familiar with Show: 47
# Percent Familiar with Show: 49.5%
# Median: 7
# Mean: 6.13
# Overall Ranking: 15
# Music-Show Ranking: 12

# %% [markdown]
# ### Dub Palace

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Dub_Palace_Ratings')
# Out:
# Filter: White
# Total Respondents: 95
# Respondents Familiar with Show: 35
# Percent Familiar with Show: 36.8%
# Median: 6
# Mean: 5.83
# Overall Ranking: 46
# Music-Show Ranking: 28

# %% [markdown]
# ### Dusty Grooves

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Dusty_Grooves_Ratings')
# Out:
# Filter: White
# Total Respondents: 96
# Respondents Familiar with Show: 41
# Percent Familiar with Show: 42.7%
# Median: 7
# Mean: 6.56
# Overall Ranking: 19
# Music-Show Ranking: 16

# %% [markdown]
# ### Eclipse

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Eclipse_Ratings')
# Out:
# Filter: White
# Total Respondents: 95
# Respondents Familiar with Show: 32
# Percent Familiar with Show: 33.7%
# Median: 5
# Mean: 5.59
# Overall Ranking: 56
# Music-Show Ranking: 32

# %% [markdown]
# ### Electronic Air

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Electronic_Air_Ratings')
# Out:
# Filter: White
# Total Respondents: 96
# Respondents Familiar with Show: 37
# Percent Familiar with Show: 38.5%
# Median: 6
# Mean: 5.89
# Overall Ranking: 43
# Music-Show Ranking: 26

# %% [markdown]
# ### eTown

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'E_Town_Ratings')
# Out:
# Filter: White
# Total Respondents: 96
# Respondents Familiar with Show: 56
# Percent Familiar with Show: 58.3%
# Median: 7
# Mean: 6.20
# Overall Ranking: 3
# Music-Show Ranking: 2

# %% [markdown]
# ### Gospel Chime

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Gospel_Chime_Ratings')
# Out:
# Filter: White
# Total Respondents: 95
# Respondents Familiar with Show: 50
# Percent Familiar with Show: 52.6%
# Median: 7
# Mean: 6.10
# Overall Ranking: 11
# Music-Show Ranking: 8

# %% [markdown]
# ### Grateful Dead

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Grateful_Dead_Ratings')
# Out:
# Filter: White
# Total Respondents: 96
# Respondents Familiar with Show: 50
# Percent Familiar with Show: 52.1%
# Median: 6
# Mean: 5.88
# Overall Ranking: 12
# Music-Show Ranking: 9

# %% [markdown]
# ### Hwy 322

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'HWY_322_Ratings')
# Out:
# Filter: White
# Total Respondents: 94
# Respondents Familiar with Show: 44
# Percent Familiar with Show: 46.8%
# Median: 7
# Mean: 7.00
# Overall Ranking: 9
# Music-Show Ranking: 6

# %% [markdown]
# ### Honky Tonk Heroes

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'HTH_Ratings')
# Out:
# Filter: White
# Total Respondents: 95
# Respondents Familiar with Show: 48
# Percent Familiar with Show: 50.5%
# Median: 7
# Mean: 6.38
# Overall Ranking: 10
# Music-Show Ranking: 7

# %% [markdown]
# ### Jazz Lives

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Jazz_Lives_Ratings')
# Out:
# Filter: White
# Total Respondents: 93
# Respondents Familiar with Show: 46
# Percent Familiar with Show: 49.5%
# Median: 7
# Mean: 6.09
# Overall Ranking: 17
# Music-Show Ranking: 14

# %% [markdown]
# ### Kaberet

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Kaberet_Ratings')
# Out:
# Filter: White
# Total Respondents: 92
# Respondents Familiar with Show: 43
# Percent Familiar with Show: 46.7%
# Median: 7
# Mean: 6.56
# Overall Ranking: 16
# Music-Show Ranking: 13

# %% [markdown]
# ### Morning Sound Alternative

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'MSA_Ratings')
# Out:
# Filter: White
# Total Respondents: 96
# Respondents Familiar with Show: 39
# Percent Familiar with Show: 40.6%
# Median: 8
# Mean: 6.77
# Overall Ranking: 22
# Music-Show Ranking: 19

# %% [markdown]
# ### Musica Mundi

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Musica_Mundi_Ratings')
# Out:
# Filter: White
# Total Respondents: 92
# Respondents Familiar with Show: 32
# Percent Familiar with Show: 34.8%
# Median: 7
# Mean: 6.62
# Overall Ranking: 44
# Music-Show Ranking: 27

# %% [markdown]
# ### Old Grass Gnu Grass

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'OGGG_Ratings')
# Out:
# Filter: White
# Total Respondents: 96
# Respondents Familiar with Show: 44
# Percent Familiar with Show: 45.8%
# Median: 6
# Mean: 5.82
# Overall Ranking: 25
# Music-Show Ranking: 21

# %% [markdown]
# ### The Present Edge

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Present_Edge_Ratings')
# Out:
# Filter: White
# Total Respondents: 93
# Respondents Familiar with Show: 25
# Percent Familiar with Show: 26.9%
# Median: 7
# Mean: 6.68
# Overall Ranking: 60
# Music-Show Ranking: 33

# %% [markdown]
# ### Ragtime America

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Ragtime_America_Ratings')
# Out:
# Filter: White
# Total Respondents: 93
# Respondents Familiar with Show: 49
# Percent Familiar with Show: 52.7%
# Median: 6
# Mean: 5.96
# Overall Ranking: 13
# Music-Show Ranking: 10

# %% [markdown]
# ### Reggae Bloodlines

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Reggae_Bloodlines_Ratings')
# Out:
# Filter: White
# Total Respondents: 94
# Respondents Familiar with Show: 46
# Percent Familiar with Show: 48.9%
# Median: 7
# Mean: 6.33
# Overall Ranking: 14
# Music-Show Ranking: 11

# %% [markdown]
# ### Reggae Transfusions

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Reggae_Transfusions_Ratings')
# Out:
# Filter: White
# Total Respondents: 94
# Respondents Familiar with Show: 35
# Percent Familiar with Show: 37.2%
# Median: 7
# Mean: 6.74
# Overall Ranking: 33
# Music-Show Ranking: 23

# %% [markdown]
# ### Restless Mornings

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Restless_Mornings_Ratings')
# Out:
# Filter: White
# Total Respondents: 91
# Respondents Familiar with Show: 29
# Percent Familiar with Show: 31.9%
# Median: 7
# Mean: 6.86
# Overall Ranking: 48
# Music-Show Ranking: 29

# %% [markdown]
# ### Roots and Branches

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Roots_and_Branches_Ratings')
# Out:
# Filter: White
# Total Respondents: 96
# Respondents Familiar with Show: 46
# Percent Familiar with Show: 47.9%
# Median: 8
# Mean: 7.30
# Overall Ranking: 5
# Music-Show Ranking: 3

# %% [markdown]
# ### Roots of Jazz

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Roots_of_Jazz_Ratings')
# Out:
# Filter: White
# Total Respondents: 91
# Respondents Familiar with Show: 34
# Percent Familiar with Show: 37.4%
# Median: 7
# Mean: 6.85
# Overall Ranking: 34
# Music-Show Ranking: 24

# %% [markdown]
# ### Seolta Gael

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Seolta_Gael_Ratings')
# Out:
# Filter: White
# Total Respondents: 94
# Respondents Familiar with Show: 35
# Percent Familiar with Show: 37.2%
# Median: 7
# Mean: 6.37
# Overall Ranking: 40
# Music-Show Ranking: 25

# %% [markdown]
# ### Sleepless Nights

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Sleepless_Nights_Ratings')
# Out:
# Filter: White
# Total Respondents: 93
# Respondents Familiar with Show: 27
# Percent Familiar with Show: 29.0%
# Median: 7
# Mean: 6.85
# Overall Ranking: 52
# Music-Show Ranking: 30

# %% [markdown]
# ### Smash It Back

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Smash_It_Back_Ratings')
# Out:
# Filter: White
# Total Respondents: 94
# Respondents Familiar with Show: 23
# Percent Familiar with Show: 24.5%
# Median: 7
# Mean: 6.48
# Overall Ranking: 63
# Music-Show Ranking: 34

# %% [markdown]
# ### SoundLab

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Soundlab_Ratings')
# Out:
# Filter: White
# Total Respondents: 93
# Respondents Familiar with Show: 40
# Percent Familiar with Show: 43.0%
# Median: 7
# Mean: 6.62
# Overall Ranking: 21
# Music-Show Ranking: 18

# %% [markdown]
# ### Swing Shift

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Swing_Shift_Ratings')
# Out:
# Filter: White
# Total Respondents: 94
# Respondents Familiar with Show: 38
# Percent Familiar with Show: 40.4%
# Median: 8
# Mean: 7.00
# Overall Ranking: 20
# Music-Show Ranking: 17

# %% [markdown]
# ### Terrasonic

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Terrasonic_Ratings')
# Out:
# Filter: White
# Total Respondents: 95
# Respondents Familiar with Show: 35
# Percent Familiar with Show: 36.8%
# Median: 8
# Mean: 6.97
# Overall Ranking: 29
# Music-Show Ranking: 22

# %% [markdown]
# ### The Heavy Set

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_Heavy_Set_Ratings')
# Out:
# Filter: White
# Total Respondents: 92
# Respondents Familiar with Show: 19
# Percent Familiar with Show: 20.7%
# Median: 8
# Mean: 6.95
# Overall Ranking: 67
# Music-Show Ranking: 35

# %% [markdown]
# ### The Opera Box

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_Opera_Box_Ratings')
# Out:
# Filter: White
# Total Respondents: 93
# Respondents Familiar with Show: 45
# Percent Familiar with Show: 48.4%
# Median: 7
# Mean: 6.09
# Overall Ranking: 18
# Music-Show Ranking: 15

# %% [markdown]
# ### Under the Floorboards

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Under_the_Floorboards_Ratings')
# Out:
# Filter: White
# Total Respondents: 93
# Respondents Familiar with Show: 27
# Percent Familiar with Show: 29.0%
# Median: 7
# Mean: 6.74
# Overall Ranking: 54
# Music-Show Ranking: 31

# %% [markdown]
# ## News Shows

# %% [markdown]
# ### A Public Affairs

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'A_Public_Affair_Ratings')
# Out:
# Filter: White
# Total Respondents: 89
# Respondents Familiar with Show: 37
# Percent Familiar with Show: 41.6%
# Median: 7
# Mean: 6.84
# Overall Ranking: 26
# News-Show Ranking: 6

# %% [markdown]
# ### Alan Watts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Alan_Watts_Ratings')
# Out:
# Filter: White
# Total Respondents: 90
# Respondents Familiar with Show: 41
# Percent Familiar with Show: 45.6%
# Median: 7
# Mean: 6.24
# Overall Ranking: 25
# News-Show Ranking: 5

# %% [markdown]
# ### Alternative Radio

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Alternative_Radio_Ratings')
# Out:
# Filter: White
# Total Respondents: 89
# Respondents Familiar with Show: 33
# Percent Familiar with Show: 37.1%
# Median: 7
# Mean: 6.82
# Overall Ranking: 39
# News-Show Ranking: 17

# %% [markdown]
# ### BBC News Hour

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'BBC_News_Hour_Ratings')
# Out:
# Filter: White
# Total Respondents: 91
# Respondents Familiar with Show: 51
# Percent Familiar with Show: 56.0%
# Median: 7
# Mean: 6.98
# Overall Ranking: 2
# News-Show Ranking: 1

# %% [markdown]
# ### BBC The Newsroom

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'BBC_The_Newsroom_Ratings')
# Out:
# Filter: White
# Total Respondents: 90
# Respondents Familiar with Show: 37
# Percent Familiar with Show: 41.1%
# Median: 7
# Mean: 6.95
# Overall Ranking: 24
# News-Show Ranking: 4

# %% [markdown]
# ### Between the Lines

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Between_the_Lines_Ratings')
# Out:
# Filter: White
# Total Respondents: 88
# Respondents Familiar with Show: 27
# Percent Familiar with Show: 30.7%
# Median: 7
# Mean: 6.96
# Overall Ranking: 50
# News-Show Ranking: 25

# %% [markdown]
# ### Bioneers

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Bioneers_Ratings')
# Out:
# Filter: White
# Total Respondents: 88
# Respondents Familiar with Show: 44
# Percent Familiar with Show: 50.0%
# Median: 8
# Mean: 7.16
# Overall Ranking: 7
# News-Show Ranking: 3

# %% [markdown]
# ### Black Talk

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Black_Talk_Ratings')
# Out:
# Filter: White
# Total Respondents: 89
# Respondents Familiar with Show: 29
# Percent Familiar with Show: 32.6%
# Median: 6
# Mean: 6.28
# Overall Ranking: 54
# News-Show Ranking: 28

# %% [markdown]
# ### Colorado Chinese Radio Network

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Col_Chinese_Radio_Network_Ratings')
# Out:
# Filter: White
# Total Respondents: 89
# Respondents Familiar with Show: 16
# Percent Familiar with Show: 18.0%
# Median: 5
# Mean: 5.75
# Overall Ranking: 70
# News-Show Ranking: 41

# %% [markdown]
# ### Connections

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Connections_Ratings')
# Out:
# Filter: White
# Total Respondents: 89
# Respondents Familiar with Show: 46
# Percent Familiar with Show: 51.7%
# Median: 8
# Mean: 7.33
# Overall Ranking: 4
# News-Show Ranking: 2

# %% [markdown]
# ### Counterspin

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Counterspin_Ratings')
# Out:
# Filter: White
# Total Respondents: 89
# Respondents Familiar with Show: 32
# Percent Familiar with Show: 36.0%
# Median: 8
# Mean: 7.50
# Overall Ranking: 31
# News-Show Ranking: 11

# %% [markdown]
# ### Democracy Now

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Democracy_Now_Ratings')
# Out:
# Filter: White
# Total Respondents: 90
# Respondents Familiar with Show: 35
# Percent Familiar with Show: 38.9%
# Median: 7
# Mean: 7.11
# Overall Ranking: 28
# News-Show Ranking: 8

# %% [markdown]
# ### Economic Update

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Economic_Update_Ratings')
# Out:
# Filter: White
# Total Respondents: 89
# Respondents Familiar with Show: 27
# Percent Familiar with Show: 30.3%
# Median: 8
# Mean: 7.15
# Overall Ranking: 49
# News-Show Ranking: 24

# %% [markdown]
# ### Hemispheres

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Hemispheres_Ratings')
# Out:
# Filter: White
# Total Respondents: 90
# Respondents Familiar with Show: 34
# Percent Familiar with Show: 37.8%
# Median: 7
# Mean: 7.09
# Overall Ranking: 30
# News-Show Ranking: 10

# %% [markdown]
# ### How on Earth

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'How_on_Earth_Ratings')
# Out:
# Filter: White
# Total Respondents: 89
# Respondents Familiar with Show: 30
# Percent Familiar with Show: 33.7%
# Median: 8
# Mean: 7.30
# Overall Ranking: 42
# News-Show Ranking: 20

# %% [markdown]
# ### Indian Voices

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Indian_Voices_Ratings')
# Out:
# Filter: White
# Total Respondents: 88
# Respondents Familiar with Show: 31
# Percent Familiar with Show: 35.2%
# Median: 7
# Mean: 7.10
# Overall Ranking: 41
# News-Show Ranking: 19

# %% [markdown]
# ### It's the Economy

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Its_The_Economy_Ratings')
# Out:
# Filter: White
# Total Respondents: 89
# Respondents Familiar with Show: 35
# Percent Familiar with Show: 39.3%
# Median: 7
# Mean: 6.60
# Overall Ranking: 36
# News-Show Ranking: 14

# %% [markdown]
# ### Jim Hightower

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Jim_Hightower_Ratings')
# Out:
# Filter: White
# Total Respondents: 91
# Respondents Familiar with Show: 34
# Percent Familiar with Show: 37.4%
# Median: 7
# Mean: 7.18
# Overall Ranking: 29
# News-Show Ranking: 9

# %% [markdown]
# ### La Lucha Sigue

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'La_Lucha_Sigue_Ratings')
# Out:
# Filter: White
# Total Respondents: 87
# Respondents Familiar with Show: 27
# Percent Familiar with Show: 31.0%
# Median: 7
# Mean: 6.70
# Overall Ranking: 55
# News-Show Ranking: 29

# %% [markdown]
# ### Labor Exchange

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Labor_Exchange_Ratings')
# Out:
# Filter: White
# Total Respondents: 86
# Respondents Familiar with Show: 26
# Percent Familiar with Show: 30.2%
# Median: 6
# Mean: 6.31
# Overall Ranking: 61
# News-Show Ranking: 34

# %% [markdown]
# ### Linea Abierta

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Linea_Abierta_Ratings')
# Out:
# Filter: White
# Total Respondents: 87
# Respondents Familiar with Show: 12
# Percent Familiar with Show: 13.8%
# Median: 6
# Mean: 6.17
# Overall Ranking: 72
# News-Show Ranking: 43

# %% [markdown]
# ### Living Dialogues

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Living_Dialogues_Ratings')
# Out:
# Filter: White
# Total Respondents: 87
# Respondents Familiar with Show: 38
# Percent Familiar with Show: 43.7%
# Median: 7
# Mean: 6.29
# Overall Ranking: 32
# News-Show Ranking: 12

# %% [markdown]
# ### Local PM Headlines Spanish

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Local_PM_Headlines_Spanish_Ratings')
# Out:
# Filter: White
# Total Respondents: 87
# Respondents Familiar with Show: 25
# Percent Familiar with Show: 28.7%
# Median: 7
# Mean: 6.96
# Overall Ranking: 59
# News-Show Ranking: 33

# %% [markdown]
# ### Making Contact

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Making_Contact_Ratings')
# Out:
# Filter: White
# Total Respondents: 85
# Respondents Familiar with Show: 28
# Percent Familiar with Show: 32.9%
# Median: 8
# Mean: 7.43
# Overall Ranking: 45
# News-Show Ranking: 21

# %% [markdown]
# ### Metro

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Metro_Ratings')
# Out:
# Filter: White
# Total Respondents: 86
# Respondents Familiar with Show: 35
# Percent Familiar with Show: 40.7%
# Median: 7
# Mean: 6.63
# Overall Ranking: 35
# News-Show Ranking: 13

# %% [markdown]
# ### Metro Arts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Metro_Arts_Ratings')
# Out:
# Filter: White
# Total Respondents: 84
# Respondents Familiar with Show: 27
# Percent Familiar with Show: 32.1%
# Median: 8
# Mean: 6.93
# Overall Ranking: 51
# News-Show Ranking: 26

# %% [markdown]
# ### Morning Magazine

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Morning_Magazine_Ratings')
# Out:
# Filter: White
# Total Respondents: 87
# Respondents Familiar with Show: 31
# Percent Familiar with Show: 35.6%
# Median: 8
# Mean: 7.10
# Overall Ranking: 41
# News-Show Ranking: 19

# %% [markdown]
# ### Naturally

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Naturally_Ratings')
# Out:
# Filter: White
# Total Respondents: 86
# Respondents Familiar with Show: 27
# Percent Familiar with Show: 31.4%
# Median: 7
# Mean: 6.59
# Overall Ranking: 57
# News-Show Ranking: 31

# %% [markdown]
# ### New Dimensions

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'New_Dimensions_Ratings')
# Out:
# Filter: White
# Total Respondents: 87
# Respondents Familiar with Show: 33
# Percent Familiar with Show: 37.9%
# Median: 7
# Mean: 6.76
# Overall Ranking: 40
# News-Show Ranking: 18

# %% [markdown]
# ### Outsources

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Outsources_Ratings')
# Out:
# Filter: White
# Total Respondents: 86
# Respondents Familiar with Show: 22
# Percent Familiar with Show: 25.6%
# Median: 8
# Mean: 6.73
# Overall Ranking: 64
# News-Show Ranking: 36

# %% [markdown]
# ### Pasa La Voz

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Pasa_La_Voz_Ratings')
# Out:
# Filter: White
# Total Respondents: 84
# Respondents Familiar with Show: 11
# Percent Familiar with Show: 13.1%
# Median: 8
# Mean: 7.00
# Overall Ranking: 71
# News-Show Ranking: 42

# %% [markdown]
# ### Peace Talks

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Peace_Talks_Ratings')
# Out:
# Filter: White
# Total Respondents: 86
# Respondents Familiar with Show: 22
# Percent Familiar with Show: 25.6%
# Median: 7
# Mean: 6.23
# Overall Ranking: 66
# News-Show Ranking: 38

# %% [markdown]
# ### Project Censored

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Project_Censored_Ratings')
# Out:
# Filter: White
# Total Respondents: 86
# Respondents Familiar with Show: 23
# Percent Familiar with Show: 26.7%
# Median: 8
# Mean: 8.00
# Overall Ranking: 53
# News-Show Ranking: 27

# %% [markdown]
# ### Rising Up with Sonali

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Rising_Up_with_Sonali_Ratings')
# Out:
# Filter: White
# Total Respondents: 90
# Respondents Familiar with Show: 27
# Percent Familiar with Show: 30.0%
# Median: 8
# Mean: 7.48
# Overall Ranking: 47
# News-Show Ranking: 22

# %% [markdown]
# ### Sprouts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Sprouts_Ratings')
# Out:
# Filter: White
# Total Respondents: 89
# Respondents Familiar with Show: 21
# Percent Familiar with Show: 23.6%
# Median: 8
# Mean: 7.00
# Overall Ranking: 65
# News-Show Ranking: 37

# %% [markdown]
# ### StoryTellers of Color

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'StoryTellers_of_Color_Ratings')
# Out:
# Filter: White
# Total Respondents: 88
# Respondents Familiar with Show: 17
# Percent Familiar with Show: 19.3%
# Median: 7
# Mean: 6.65
# Overall Ranking: 68
# News-Show Ranking: 39

# %% [markdown]
# ### Laura Flanders

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Laura_Flanders_Ratings')
# Out:
# Filter: White
# Total Respondents: 89
# Respondents Familiar with Show: 34
# Percent Familiar with Show: 38.2%
# Median: 7
# Mean: 6.71
# Overall Ranking: 37
# News-Show Ranking: 15

# %% [markdown]
# ### Ralph Nader

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Ralph_Nader_Ratings')
# Out:
# Filter: White
# Total Respondents: 91
# Respondents Familiar with Show: 39
# Percent Familiar with Show: 42.9%
# Median: 6
# Mean: 6.26
# Overall Ranking: 29
# News-Show Ranking: 9

# %% [markdown]
# ### Shortwave Report

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Shortwave_Report_Ratings')
# Out:
# Filter: White
# Total Respondents: 89
# Respondents Familiar with Show: 26
# Percent Familiar with Show: 29.2%
# Median: 7
# Mean: 6.73
# Overall Ranking: 58
# News-Show Ranking: 32

# %% [markdown]
# ### The World

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_World_Ratings')
# Out:
# Filter: White
# Total Respondents: 90
# Respondents Familiar with Show: 34
# Percent Familiar with Show: 37.8%
# Median: 7
# Mean: 6.68
# Overall Ranking: 38
# News-Show Ranking: 16

# %% [markdown]
# ### TRENDS

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'TRENDS_Ratings')
# Out:
# Filter: White
# Total Respondents: 88
# Respondents Familiar with Show: 14
# Percent Familiar with Show: 15.9%
# Median: 6
# Mean: 7.07
# Overall Ranking: 69
# News-Show Ranking: 40

# %% [markdown]
# ### Tributaries

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Tributaries_Ratings')
# Out:
# Filter: White
# Total Respondents: 90
# Respondents Familiar with Show: 35
# Percent Familiar with Show: 38.9%
# Median: 7
# Mean: 7.20
# Overall Ranking: 27
# News-Show Ranking: 7

# %% [markdown]
# ### TUC Radio

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'TUC_Radio_Ratings')
# Out:
# Filter: White
# Total Respondents: 88
# Respondents Familiar with Show: 23
# Percent Familiar with Show: 26.1%
# Median: 9
# Mean: 7.78
# Overall Ranking: 56
# News-Show Ranking: 30

# %% [markdown]
# ### WINGS

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'WINGS_Ratings')
# Out:
# Filter: White
# Total Respondents: 88
# Respondents Familiar with Show: 28
# Percent Familiar with Show: 31.8%
# Median: 8
# Mean: 7.11
# Overall Ranking: 48
# News-Show Ranking: 23

# %% [markdown]
# ### Weed Between

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Weed_between_Ratings')
# Out:
# Filter: White
# Total Respondents: 90
# Respondents Familiar with Show: 23
# Percent Familiar with Show: 25.6%
# Median: 8
# Mean: 6.78
# Overall Ranking: 62
# News-Show Ranking: 35
