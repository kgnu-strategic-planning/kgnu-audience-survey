# %% [markdown]
# # All Respondents

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import MaxNLocator
from IPython.display import display, Markdown
from functions import *

# %%
df = pd.read_excel('KGNU-Member-Data-05.12.22-v1.xlsx', sheet_name='English')

# %%
show_ratings_cols = df.columns.tolist()[111:191]
#show_ratings_cols

# %%
filter_col = 'all_respondents'
filter_col_val = ''
filter_col_val_display = 'Filter: None'

# %% [markdown]
# ## Music Shows

# %% [markdown]
# ### A Classic Monday

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'A_Classic_Monday_Ratings')
# Out:
# Filter: None
# Total Respondents: 330
# Respondents Familiar with Show: 175
# Percent Familiar with Show: 53.0%
# Median: 6
# Mean: 6.33

# %% [markdown]
# ### African Roots

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'African_Roots_Ratings')
# Out:
# Filter: None
# Total Respondents: 333
# Respondents Familiar with Show: 276
# Percent Familiar with Show: 82.9%
# Median: 8
# Mean: 7.28

# %% [markdown]
# ### Afternoon Sound Alternative

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'ASA_Ratings')
# Out:
# Filter: None
# Total Respondents: 336
# Respondents Familiar with Show: 294
# Percent Familiar with Show: 87.5%
# Median: 8
# Mean: 7.36

# %% [markdown]
# ### Blues Legacy

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Blues_Legacy_Ratings')
# Out:
# Filter: None
# Total Respondents: 335
# Respondents Familiar with Show: 271
# Percent Familiar with Show: 80.9%
# Median: 8
# Mean: 7.44

# %% [markdown]
# ### Corriente

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Corriente_Ratings')
# Out:
# Filter: None
# Total Respondents: 334
# Respondents Familiar with Show: 197
# Percent Familiar with Show: 59.0%
# Median: 8
# Mean: 6.99

# %% [markdown]
# ### Dub Palace

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Dub_Palace_Ratings')
# Out:
# Filter: None
# Total Respondents: 332
# Respondents Familiar with Show: 171
# Percent Familiar with Show: 51.5%
# Median: 6
# Mean: 6.15

# %% [markdown]
# ### Dusty Grooves

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Dusty_Grooves_Ratings')
# Out:
# Filter: None
# Total Respondents: 336
# Respondents Familiar with Show: 211
# Percent Familiar with Show: 62.8%
# Median: 8
# Mean: 7.61

# %% [markdown]
# ### Eclipse

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Eclipse_Ratings')
# Out:
# Filter: None
# Total Respondents: 335
# Respondents Familiar with Show: 157
# Percent Familiar with Show: 46.9%
# Median: 7
# Mean: 6.89

# %% [markdown]
# ### Electronic Air

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Electronic_Air_Ratings')
# Out:
# Filter: None
# Total Respondents: 335
# Respondents Familiar with Show: 169
# Percent Familiar with Show: 50.4%
# Median: 6
# Mean: 6.07

# %% [markdown]
# ### eTown

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'E_Town_Ratings')
# Out:
# Filter: None
# Total Respondents: 338
# Respondents Familiar with Show: 291
# Percent Familiar with Show: 86.1%
# Median: 8
# Mean: 7.32

# %% [markdown]
# ### Gospel Chime

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Gospel_Chime_Ratings')
# Out:
# Filter: None
# Total Respondents: 336
# Respondents Familiar with Show: 237
# Percent Familiar with Show: 70.5%
# Median: 6
# Mean: 6.10

# %% [markdown]
# ### Grateful Dead

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Grateful_Dead_Ratings')
# Out:
# Filter: None
# Total Respondents: 339
# Respondents Familiar with Show: 268
# Percent Familiar with Show: 79.1%
# Median: 7
# Mean: 6.25

# %% [markdown]
# ### Hwy 322

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'HWY_322_Ratings')
# Out:
# Filter: None
# Total Respondents: 333
# Respondents Familiar with Show: 198
# Percent Familiar with Show: 59.5%
# Median: 8
# Mean: 7.46

# %% [markdown]
# ### Honky Tonk Heroes

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'HTH_Ratings')
# Out:
# Filter: None
# Total Respondents: 336
# Respondents Familiar with Show: 273
# Percent Familiar with Show: 81.2%
# Median: 9
# Mean: 7.64

# %% [markdown]
# ### Jazz Lives

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Jazz_Lives_Ratings')
# Out:
# Filter: None
# Total Respondents: 331
# Respondents Familiar with Show: 225
# Percent Familiar with Show: 68.0%
# Median: 8
# Mean: 6.84

# %% [markdown]
# ### Kaberet

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Kaberet_Ratings')
# Out:
# Filter: None
# Total Respondents: 334
# Respondents Familiar with Show: 192
# Percent Familiar with Show: 57.5%
# Median: 7
# Mean: 6.82

# %% [markdown]
# ### Morning Sound Alternative

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'MSA_Ratings')
# Out:
# Filter: None
# Total Respondents: 339
# Respondents Familiar with Show: 295
# Percent Familiar with Show: 87.0%
# Median: 9
# Mean: 8.22

# %% [markdown]
# ### Musica Mundi

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Musica_Mundi_Ratings')
# Out:
# Filter: None
# Total Respondents: 333
# Respondents Familiar with Show: 185
# Percent Familiar with Show: 55.6%
# Median: 8
# Mean: 7.43

# %% [markdown]
# ### Old Grass Gnu Grass

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'OGGG_Ratings')
# Out:
# Filter: None
# Total Respondents: 339
# Respondents Familiar with Show: 292
# Percent Familiar with Show: 86.1%
# Median: 9
# Mean: 7.65

# %% [markdown]
# ### The Present Edge

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Present_Edge_Ratings')
# Out:
# Filter: None
# Total Respondents: 333
# Respondents Familiar with Show: 104
# Percent Familiar with Show: 31.2%
# Median: 6
# Mean: 6.24

# %% [markdown]
# ### Ragtime America

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Ragtime_America_Ratings')
# Out:
# Filter: None
# Total Respondents: 336
# Respondents Familiar with Show: 221
# Percent Familiar with Show: 65.8%
# Median: 6
# Mean: 6.10

# %% [markdown]
# ### Reggae Bloodlines

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Reggae_Bloodlines_Ratings')
# Out:
# Filter: None
# Total Respondents: 336
# Respondents Familiar with Show: 273
# Percent Familiar with Show: 81.2%
# Median: 8
# Mean: 7.38

# %% [markdown]
# ### Reggae Transfusions

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Reggae_Transfusions_Ratings')
# Out:
# Filter: None
# Total Respondents: 334
# Respondents Familiar with Show: 175
# Percent Familiar with Show: 52.4%
# Median: 8
# Mean: 7.04

# %% [markdown]
# ### Restless Mornings

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Restless_Mornings_Ratings')
# Out:
# Filter: None
# Total Respondents: 329
# Respondents Familiar with Show: 148
# Percent Familiar with Show: 45.0%
# Median: 7
# Mean: 6.84

# %% [markdown]
# ### Roots and Branches

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Roots_and_Branches_Ratings')
# Out:
# Filter: None
# Total Respondents: 337
# Respondents Familiar with Show: 251
# Percent Familiar with Show: 74.5%
# Median: 9
# Mean: 8.25

# %% [markdown]
# ### Roots of Jazz

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Roots_of_Jazz_Ratings')
# Out:
# Filter: None
# Total Respondents: 331
# Respondents Familiar with Show: 149
# Percent Familiar with Show: 45.0%
# Median: 8
# Mean: 7.17

# %% [markdown]
# ### Seolta Gael

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Seolta_Gael_Ratings')
# Out:
# Filter: None
# Total Respondents: 333
# Respondents Familiar with Show: 168
# Percent Familiar with Show: 50.5%
# Median: 8
# Mean: 6.98

# %% [markdown]
# ### Sleepless Nights

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Sleepless_Nights_Ratings')
# Out:
# Filter: None
# Total Respondents: 333
# Respondents Familiar with Show: 156
# Percent Familiar with Show: 46.8%
# Median: 8
# Mean: 7.09

# %% [markdown]
# ### Smash It Back

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Smash_It_Back_Ratings')
# Out:
# Filter: None
# Total Respondents: 334
# Respondents Familiar with Show: 100
# Percent Familiar with Show: 29.9%
# Median: 7
# Mean: 6.69

# %% [markdown]
# ### SoundLab

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Soundlab_Ratings')
# Out:
# Filter: None
# Total Respondents: 333
# Respondents Familiar with Show: 148
# Percent Familiar with Show: 44.4%
# Median: 7
# Mean: 7.17

# %% [markdown]
# ### Swing Shift

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Swing_Shift_Ratings')
# Out:
# Filter: None
# Total Respondents: 333
# Respondents Familiar with Show: 155
# Percent Familiar with Show: 46.5%
# Median: 7
# Mean: 6.85

# %% [markdown]
# ### Terrasonic

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Terrasonic_Ratings')
# Out:
# Filter: None
# Total Respondents: 337
# Respondents Familiar with Show: 230
# Percent Familiar with Show: 68.2%
# Median: 8
# Mean: 7.50

# %% [markdown]
# ### The Heavy Set

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_Heavy_Set_Ratings')
# Out:
# Filter: None
# Total Respondents: 333
# Respondents Familiar with Show: 105
# Percent Familiar with Show: 31.5%
# Median: 7
# Mean: 6.65

# %% [markdown]
# ### The Opera Box

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_Opera_Box_Ratings')
# Out:
# Filter: None
# Total Respondents: 336
# Respondents Familiar with Show: 179
# Percent Familiar with Show: 53.3%
# Median: 5
# Mean: 5.33

# %% [markdown]
# ### Under the Floorboards

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Under_the_Floorboards_Ratings')
# Out:
# Filter: None
# Total Respondents: 331
# Respondents Familiar with Show: 126
# Percent Familiar with Show: 38.1%
# Median: 7
# Mean: 6.53

# %% [markdown]
# ## News Shows

# %% [markdown]
# ### A Public Affairs

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'A_Public_Affair_Ratings')
# Out:
# Filter: None
# Total Respondents: 332
# Respondents Familiar with Show: 204
# Percent Familiar with Show: 61.4%
# Median: 8
# Mean: 7.31

# %% [markdown]
# ### Alan Watts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Alan_Watts_Ratings')
# Out:
# Filter: None
# Total Respondents: 337
# Respondents Familiar with Show: 263
# Percent Familiar with Show: 78.0%
# Median: 8
# Mean: 7.49

# %% [markdown]
# ### Alternative Radio

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Alternative_Radio_Ratings')
# Out:
# Filter: None
# Total Respondents: 330
# Respondents Familiar with Show: 231
# Percent Familiar with Show: 70.0%
# Median: 9
# Mean: 8.10

# %% [markdown]
# ### BBC News Hour

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'BBC_New_Hour_Ratings')
# Out:
# Filter: None
# Total Respondents: 337
# Respondents Familiar with Show: 313
# Percent Familiar with Show: 92.9%
# Median: 9
# Mean: 7.76

# %% [markdown]
# ### BBC The Newsroom

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'BBC_The_Newsroom_Ratings')
# Out:
# Filter: None
# Total Respondents: 337
# Respondents Familiar with Show: 246
# Percent Familiar with Show: 73.0%
# Median: 8
# Mean: 7.50

# %% [markdown]
# ### Between the Lines

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Between_the_Lines_Ratings')
# Out:
# Filter: None
# Total Respondents: 331
# Respondents Familiar with Show: 158
# Percent Familiar with Show: 47.7%
# Median: 8
# Mean: 7.80

# %% [markdown]
# ### Bioneers

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Bioneers_Ratings')
# Out:
# Filter: None
# Total Respondents: 332
# Respondents Familiar with Show: 203
# Percent Familiar with Show: 61.1%
# Median: 8
# Mean: 7.76

# %% [markdown]
# ### Black Talk

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Black_Talk_Ratings')
# Out:
# Filter: None
# Total Respondents: 333
# Respondents Familiar with Show: 139
# Percent Familiar with Show: 41.7%
# Median: 8
# Mean: 7.23

# %% [markdown]
# ### Colorado Chinese Radio Network

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Colorado_Chineses_Radio_Network_Ratings')
# Out:
# Filter: None
# Total Respondents: 330
# Respondents Familiar with Show: 93
# Percent Familiar with Show: 28.2%
# Median: 5
# Mean: 4.83

# %% [markdown]
# ### Connections

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Connections_Ratings')
# Out:
# Filter: None
# Total Respondents: 329
# Respondents Familiar with Show: 194
# Percent Familiar with Show: 59.0%
# Median: 8
# Mean: 7.60

# %% [markdown]
# ### Counterspin

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Counterspin_Ratings')
# Out:
# Filter: None
# Total Respondents: 332
# Respondents Familiar with Show: 220
# Percent Familiar with Show: 66.3%
# Median: 9
# Mean: 8.22

# %% [markdown]
# ### Democracy Now

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Democracy_Now_Ratings')
# Out:
# Filter: None
# Total Respondents: 334
# Respondents Familiar with Show: 295
# Percent Familiar with Show: 88.3%
# Median: 9
# Mean: 7.90

# %% [markdown]
# ### Economic Update

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Economic_Update_Ratings')
# Out:
# Filter: None
# Total Respondents: 332
# Respondents Familiar with Show: 201
# Percent Familiar with Show: 60.5%
# Median: 9
# Mean: 8.18

# %% [markdown]
# ### Hemispheres

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Hemispheres_Ratings')
# Out:
# Filter: None
# Total Respondents: 332
# Respondents Familiar with Show: 226
# Percent Familiar with Show: 68.1%
# Median: 9
# Mean: 8.07

# %% [markdown]
# ### How on Earth

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'How_on_Earth_Ratings')
# Out:
# Filter: None
# Total Respondents: 333
# Respondents Familiar with Show: 224
# Percent Familiar with Show: 67.3%
# Median: 9
# Mean: 8.29

# %% [markdown]
# ### Indian Voices

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Indian_Voices_Ratings')
# Out:
# Filter: None
# Total Respondents: 331
# Respondents Familiar with Show: 208
# Percent Familiar with Show: 62.8%
# Median: 8
# Mean: 7.66

# %% [markdown]
# ### It's the Economy

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Its_The_Economy_Ratings')
# Out:
# Filter: None
# Total Respondents: 333
# Respondents Familiar with Show: 210
# Percent Familiar with Show: 63.1%
# Median: 9
# Mean: 7.84

# %% [markdown]
# ### Jim Hightower

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Jim_Hightower_Ratings')
# Out:
# Filter: None
# Total Respondents: 331
# Respondents Familiar with Show: 259
# Percent Familiar with Show: 78.2%
# Median: 10
# Mean: 8.32

# %% [markdown]
# ### La Lucha Sigue

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'La_Lucha_Sigue_Ratings')
# Out:
# Filter: None
# Total Respondents: 326
# Respondents Familiar with Show: 148
# Percent Familiar with Show: 45.4%
# Median: 8
# Mean: 7.61

# %% [markdown]
# ### Labor Exchange

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Labor_Exchange_Ratings')
# Out:
# Filter: None
# Total Respondents: 326
# Respondents Familiar with Show: 163
# Percent Familiar with Show: 50.0%
# Median: 8
# Mean: 7.42

# %% [markdown]
# ### Linea Abierta

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Linea_Abierta_Ratings')
# Out:
# Filter: None
# Total Respondents: 325
# Respondents Familiar with Show: 59
# Percent Familiar with Show: 18.2%
# Median: 7
# Mean: 6.46

# %% [markdown]
# ### Living Dialogues

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Living_Dialogues_Ratings')
# Out:
# Filter: None
# Total Respondents: 328
# Respondents Familiar with Show: 164
# Percent Familiar with Show: 50.0%
# Median: 7
# Mean: 6.35

# %% [markdown]
# ### Local PM Headlines Spanish

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Local_PM_Headlines_Spanish_Ratings')
# Out:
# Filter: None
# Total Respondents: 323
# Respondents Familiar with Show: 142
# Percent Familiar with Show: 44.0%
# Median: 7
# Mean: 6.39

# %% [markdown]
# ### Making Contact

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Making_Contact_Ratings')
# Out:
# Filter: None
# Total Respondents: 321
# Respondents Familiar with Show: 130
# Percent Familiar with Show: 40.5%
# Median: 7
# Mean: 7.02

# %% [markdown]
# ### Metro

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Metro_Ratings')
# Out:
# Filter: None
# Total Respondents: 326
# Respondents Familiar with Show: 197
# Percent Familiar with Show: 60.4%
# Median: 8
# Mean: 7.25

# %% [markdown]
# ### Metro Arts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Metro_Arts_Ratings')
# Out:
# Filter: None
# Total Respondents: 324
# Respondents Familiar with Show: 167
# Percent Familiar with Show: 51.5%
# Median: 8
# Mean: 7.33

# %% [markdown]
# ### Morning Magazine

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Morning_Magazine_Ratings')
# Out:
# Filter: None
# Total Respondents: 325
# Respondents Familiar with Show: 205
# Percent Familiar with Show: 63.1%
# Median: 9
# Mean: 8.23

# %% [markdown]
# ### Naturally

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Naturally_Ratings')
# Out:
# Filter: None
# Total Respondents: 326
# Respondents Familiar with Show: 187
# Percent Familiar with Show: 57.4%
# Median: 9
# Mean: 7.88

# %% [markdown]
# ### New Dimensions

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'New_Dimensions_Ratings')
# Out:
# Filter: None
# Total Respondents: 328
# Respondents Familiar with Show: 178
# Percent Familiar with Show: 54.3%
# Median: 8
# Mean: 7.22

# %% [markdown]
# ### Outsources

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Outsources_Ratings')
# Out:
# Filter: None
# Total Respondents: 325
# Respondents Familiar with Show: 121
# Percent Familiar with Show: 37.2%
# Median: 8
# Mean: 6.96

# %% [markdown]
# ### Pasa La Voz

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Pasa_La_Voz_Ratings')
# Out:
# Filter: None
# Total Respondents: 321
# Respondents Familiar with Show: 85
# Percent Familiar with Show: 26.5%
# Median: 7
# Mean: 6.68

# %% [markdown]
# ### Peace Talks

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Peace_Talks_Ratings')
# Out:
# Filter: None
# Total Respondents: 326
# Respondents Familiar with Show: 152
# Percent Familiar with Show: 46.6%
# Median: 8
# Mean: 7.47

# %% [markdown]
# ### Project Censored

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Project_Censored_Ratings')
# Out:
# Filter: None
# Total Respondents: 325
# Respondents Familiar with Show: 146
# Percent Familiar with Show: 44.9%
# Median: 9
# Mean: 8.38

# %% [markdown]
# ### Rising Up with Sonali

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Rising_Up_with_Sonali_Ratings')
# Out:
# Filter: None
# Total Respondents: 328
# Respondents Familiar with Show: 133
# Percent Familiar with Show: 40.5%
# Median: 8
# Mean: 7.71

# %% [markdown]
# ### Sprouts

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Sprouts_Ratings')
# Out:
# Filter: None
# Total Respondents: 325
# Respondents Familiar with Show: 101
# Percent Familiar with Show: 31.1%
# Median: 8
# Mean: 6.86

# %% [markdown]
# ### StoryTellers of Color

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'StoryTellers_of_Color_Ratings')
# Out:
# Filter: None
# Total Respondents: 324
# Respondents Familiar with Show: 86
# Percent Familiar with Show: 26.5%
# Median: 8
# Mean: 7.22

# %% [markdown]
# ### Laura Flanders

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Laura_Flanders_Ratings')
# Out:
# Filter: None
# Total Respondents: 324
# Respondents Familiar with Show: 153
# Percent Familiar with Show: 47.2%
# Median: 7
# Mean: 6.89

# %% [markdown]
# ### Ralph Nader

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Ralph_Nader_Ratings')
# Out:
# Filter: None
# Total Respondents: 327
# Respondents Familiar with Show: 237
# Percent Familiar with Show: 72.5%
# Median: 8
# Mean: 7.36

# %% [markdown]
# ### Shortwave Report

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Shortwave_Report_Ratings')
# Out:
# Filter: None
# Total Respondents: 327
# Respondents Familiar with Show: 144
# Percent Familiar with Show: 44.0%
# Median: 8
# Mean: 7.44

# %% [markdown]
# ### The World

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'The_World_Ratings')
# Out:
# Filter: None
# Total Respondents: 328
# Respondents Familiar with Show: 159
# Percent Familiar with Show: 48.5%
# Median: 8
# Mean: 7.07

# %% [markdown]
# ### TRENDS

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'TRENDS_Ratings')
# Out:
# Filter: None
# Total Respondents: 324
# Respondents Familiar with Show: 72
# Percent Familiar with Show: 22.2%
# Median: 8
# Mean: 6.86

# %% [markdown]
# ### Tributaries

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Tributaries_Ratings')
# Out:
# Filter: None
# Total Respondents: 329
# Respondents Familiar with Show: 170
# Percent Familiar with Show: 51.7%
# Median: 8
# Mean: 7.31

# %% [markdown]
# ### TUC Radio

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'TUC_Radio_Ratings')
# Out:
# Filter: None
# Total Respondents: 325
# Respondents Familiar with Show: 122
# Percent Familiar with Show: 37.5%
# Median: 9
# Mean: 7.79

# %% [markdown]
# ### WINGS

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'WINGS_Ratings')
# Out:
# Filter: None
# Total Respondents: 327
# Respondents Familiar with Show: 128
# Percent Familiar with Show: 39.1%
# Median: 8
# Mean: 7.34

# %% [markdown]
# ### Weed Between

# %%
create_hist_and_stats(df, filter_col, filter_col_val, filter_col_val_display, 'Weed_between_Ratings')
# Out:
# Filter: None
# Total Respondents: 326
# Respondents Familiar with Show: 108
# Percent Familiar with Show: 33.1%
# Median: 8
# Mean: 7.19
